# %% [markdown]
# <a href="https://colab.research.google.com/github/tyronecheng07/Energy-Consumption-Forecast/blob/main/LSTM_ANN_model_energy_consumption_forecast_china.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Total Energy Consumption Forecast of China - LSTM-ANN-Model Multivariate**
#
# ##**Goal and Description**
# A good prediction of the energy data allows stateholders, researcher and politician make better decision and to be well informed with the future possible scenarios. The main focus of this study is to forecast the total energy consumption of China for the next 6 years. Using a set of different variables as inputs and the energy consumption as output with a period of 20 years from 2000 to 2019 to perform the timeseries forecasting.
#
# **Deutsch:**
# #**Vorhersage des Gesamtenergieverbrauchs Chinas- LSTM-KNN-Modell Multivariate**
#
# ##**Zielsetzung und Beschreibung**
#
# Eine gute Vorhersage der Energiedaten ermöglicht es Entscheidungsträgern, Forschern und auch Politikern, bessere Entscheidungen zu treffen und über die möglichen zukünftigen Entwicklungen gut informiert zu sein. Das Schwerpunktthema dieser Studie ist die Vorhersage des Gesamtenergieverbrauchs von China für die nächsten 6 Jahre. Die Zeitreihenprognose wird mit einer Reihe von verschiedenen Variablen als Eingaben und dem Energieverbrauch als Ausgabe mit einem Zeitraum von 20 Jahren von 2000 bis 2019 durchgeführt.

# %% [markdown]
# Prepared by Kuan Yew Cheng, 2021
#
# Raw data collected from China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# and from the database: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics and https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
#
# **Deutsch:**
#
# Vorbereitet von Kuan Yew Cheng, 2021
#
# Rohdaten entnommen aus China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# auch von der Datenbank: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics und https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html

# %% [markdown]
# **Import the libraries**
#
# **Deutsch:**
#
# **Importieren der Pythonbibliotheken**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import TimeDistributed
from tensorflow.keras.layers import Dropout
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.layers.core import Activation
import tensorflow as tf
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras import backend
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import LeakyReLU
from keras.backend import set_epsilon
from scipy.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# **Convert data from Excel worksheet to CSV format**
#
# **Deutsch:**
#
# **Konvertieren von Daten aus einem Excel-Arbeitsblatt in das CSV-Format**

# %%
#energy_df = pd.read_excel('Energy_Dataset_China.xlsx', sheet_name=None)
#energy_df['for_processing4'].to_csv('final_energy_data_4.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
energy_df = pd.read_excel('/content/drive/MyDrive/Energy China/Dataset for Bachelorarbeit/Energy_Dataset_China.xlsx', sheet_name=None)
energy_df['for_processing4'].to_csv('final_energy_data_4.csv')

# %% [markdown]
# **Reading and preprocessing the CSV file**
#
# **Deutsch:**
#
# **Lesen und Vorverarbeiten der CSV-Datei**

# %%
energy_df = pd.read_csv('final_energy_data_4.csv', index_col=[0])

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Dataset of total energy Consumption(Mtoe) and other variables of China**
#
# **Deutsch:**
#
# **Datensatz des Gesamtenergieverbrauchs (Mtoe) und anderer Variablen von China**

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           20 non-null     int64
#  1   total_energy_consumption_mtoe  20 non-null     float64
#  2   coal_consumption_mtoe          20 non-null     float64
#  3   oil_consumption_mtoe           20 non-null     float64
#  4   gas_consumption_mtoe           20 non-null     float64
#  5   non_fossil_consumption_mtoe    20 non-null     float64
#  6   imports_mtoe                   20 non-null     float64
#  7   tpes_mtoe                      20 non-null     float64
#  8   population_million             20 non-null     float64
#  9   gdp_billion_yuan               20 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 1.7 KB

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualise data of years against each column**
#
# **Deutsch:**
#
# **Visualisierung der Jahresdaten gegenüber jeder Spalte**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']


plt.figure()
plt.title("total_energy_consumption_mtoe 2000 to 2019")
plt.plot(x, y1, 'g-')
plt.xlabel("Years")
plt.ylabel("Energy comsumption mtoe")

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")

plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.show()

# %% [markdown]
# Comment: Some of the plots showed abnormal drops since there were missing values in the dataset which displayed as 0.
#
# **Deutsch:**
#
# Kommentar: Einige der Grafiken zeigten abnormale Absenkungen, da es fehlende Werte im Datensatz gab, die als 0 angezeigt wurden.

# %% [markdown]
# **Arrange the columns**
#
# Shifting the ***year*** column to the last column and adding a new column ***prediction*** into the energy_df
#
# **Deutsch:**
#
# **Anordnen der Spalten**
#
# Verschieben der **Jahres**-Spalte in die letzte Spalte und Hinzufügung einer neuen **Vorhersage**-spalte in der energy_df

# %%
features = ['total_energy_consumption_mtoe', 'coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe', 'imports_mtoe','tpes_mtoe', 'population_million', 'gdp_billion_yuan', 'year']
energy_df = energy_df[features]
energy_df_ext = energy_df.copy()
energy_df_ext['prediction'] = energy_df_ext['total_energy_consumption_mtoe']
energy_df_ext.tail()
# Out:
#     total_energy_consumption_mtoe  coal_consumption_mtoe  ...  year  prediction
# 15                       3038.791            1920.657806  ...  2015    3038.791
# 16                       3090.444            1895.791743  ...  2016    3090.444
# 17                       3190.789            1899.784264  ...  2017    3190.789
# 18                       3303.475            1912.999927  ...  2018    3303.475
# 19                       3409.000            1956.940885  ...  2019    3409.000
#
# [5 rows x 11 columns]

# %% [markdown]
# **Check zero values**
#
# **Deutsch:**
#
# **0-werte überprüfen**

# %%
energy_df.isin([0]).sum()
# Out:
# total_energy_consumption_mtoe    0
# coal_consumption_mtoe            0
# oil_consumption_mtoe             0
# gas_consumption_mtoe             0
# non_fossil_consumption_mtoe      0
# imports_mtoe                     1
# tpes_mtoe                        1
# population_million               0
# gdp_billion_yuan                 0
# year                             0
# dtype: int64

# %% [markdown]
# **Replace the zero values with null**
#
# **Deutsch:**
#
# **Ersetzen Sie die 0-Werte durch Nullwerte**

# %%
cols = ["imports_mtoe","tpes_mtoe"]
energy_df[cols] = energy_df[cols].replace(['0', 0], np.nan)

# %% [markdown]
# **Interpolate the missing values by using linear interpolation**
#
# **Deutsch:**
#
# **Interpolierung der fehlenden Werte mit Hilfe der linearen Interpolation**

# %%
energy_df.interpolate(method='linear', limit_direction ='both', inplace=True)

energy_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                        1028.748  ...  2000
# 1                        1088.829  ...  2001
# 2                        1187.039  ...  2002
# 3                        1379.581  ...  2003
# 4                        1611.967  ...  2004
# 5                        1829.583  ...  2005
# 6                        2005.269  ...  2006
# 7                        2180.094  ...  2007
# 8                        2244.277  ...  2008
# 9                        2352.882  ...  2009
# 10                       2524.536  ...  2010
# 11                       2709.301  ...  2011
# 12                       2814.966  ...  2012
# 13                       2918.391  ...  2013
# 14                       2998.338  ...  2014
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualize data of years against each column after interpolation**
#
# **Deutsch:**
#
# **Visualisierung der Daten von Jahren gegenüber jeder Spalte nach der Interpolation**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']

plt.figure()
plt.title("total_energy_consumption_mtoe 2000 to 2019")
plt.plot(x, y1, 'g-')
plt.xlabel("Years")
plt.ylabel("Energy comsumption mtoe")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")

plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.show()

# %% [markdown]
# **Check Correlations**
#
# **Deutsch:**
#
# **Korrelationen prüfen**

# %%
pearsoncorr = energy_df.corr(method='pearson')
pearsoncorr
# Out:
#                                total_energy_consumption_mtoe  ...      year
# total_energy_consumption_mtoe                       1.000000  ...  0.987076
# coal_consumption_mtoe                               0.967508  ...  0.915922
# oil_consumption_mtoe                                0.982699  ...  0.997376
# gas_consumption_mtoe                                0.930097  ...  0.971747
# non_fossil_consumption_mtoe                         0.919665  ...  0.968318
# imports_mtoe                                        0.957505  ...  0.986707
# tpes_mtoe                                           0.997467  ...  0.981646
# population_million                                  0.989195  ...  0.999361
# gdp_billion_yuan                                    0.945927  ...  0.982514
# year                                                0.987076  ...  1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# **Correlation Matrix with Pearson coefficient**
#
# **Deutsch:**
#
# **Korrelations-Matrix mit Pearson-Korrelationskoeffizient**

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# **Calculation of P-value**
#
# **Deutsch:**
#
# **Berechnung vom P-Wert**

# %%
def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 12)
    return pvalues

# %%
calculate_pvalues(energy_df)
# Out:
#                               total_energy_consumption_mtoe  ...        year
# total_energy_consumption_mtoe                             0  ...           0
# coal_consumption_mtoe                                 3e-12  ...  1.4652e-08
# oil_consumption_mtoe                                      0  ...           0
# gas_consumption_mtoe                              2.932e-09  ...       1e-12
# non_fossil_consumption_mtoe                       9.861e-09  ...       3e-12
# imports_mtoe                                        3.7e-11  ...           0
# tpes_mtoe                                                 0  ...           0
# population_million                                        0  ...           0
# gdp_billion_yuan                                   3.08e-10  ...           0
# year                                                      0  ...           0
#
# [10 rows x 10 columns]

# %% [markdown]
# All the values are with a  p-value < 0.01, the variables are statistically significant and the null hypothese can be rejected
#
# **Deutsch:**
#
# Alle Werte wurden mit dem P-Wert < 0,01 berechnet. Dieses Variablen waren statistisch signifikant und die Nullhypothese lässt sich ablehnen.

# %% [markdown]
# **Create a new DataFrame without exports_mtoe and year**
#
# **Deutsch:**
#
# **Erstellung eines neuen DataFrames ohne exports_mtoe und Jahr**

# %%
input_df = energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']]

# %%
input_df
# Out:
#     total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                        1028.748  ...          10028.01
# 1                        1088.829  ...          11086.31
# 2                        1187.039  ...          12171.74
# 3                        1379.581  ...          13742.20
# 4                        1611.967  ...          16184.02
# 5                        1829.583  ...          18731.89
# 6                        2005.269  ...          21943.85
# 7                        2180.094  ...          27009.23
# 8                        2244.277  ...          31924.46
# 9                        2352.882  ...          34851.77
# 10                       2524.536  ...          41211.93
# 11                       2709.301  ...          48794.02
# 12                       2814.966  ...          53858.00
# 13                       2918.391  ...          59296.32
# 14                       2998.338  ...          64356.31
# 15                       3038.791  ...          68885.82
# 16                       3090.444  ...          74639.51
# 17                       3190.789  ...          83203.59
# 18                       3303.475  ...          91928.11
# 19                       3409.000  ...          99086.51
#
# [20 rows x 9 columns]

# %% [markdown]
# **Display our feature column: total_energy_consumption_mtoe**
#
# **Deutsch:**
#
# **Feature-Spalte anzeigen: total_energy_consumption_mtoe**

# %%
input_df.iloc[:,0]
# Out:
# 0     1028.748
# 1     1088.829
# 2     1187.039
# 3     1379.581
# 4     1611.967
# 5     1829.583
# 6     2005.269
# 7     2180.094
# 8     2244.277
# 9     2352.882
# 10    2524.536
# 11    2709.301
# 12    2814.966
# 13    2918.391
# 14    2998.338
# 15    3038.791
# 16    3090.444
# 17    3190.789
# 18    3303.475
# 19    3409.000
# Name: total_energy_consumption_mtoe, dtype: float64

# %%
input_df.iloc[:,-1]
# Out:
# 0     10028.01
# 1     11086.31
# 2     12171.74
# 3     13742.20
# 4     16184.02
# 5     18731.89
# 6     21943.85
# 7     27009.23
# 8     31924.46
# 9     34851.77
# 10    41211.93
# 11    48794.02
# 12    53858.00
# 13    59296.32
# 14    64356.31
# 15    68885.82
# 16    74639.51
# 17    83203.59
# 18    91928.11
# 19    99086.51
# Name: gdp_billion_yuan, dtype: float64

# %% [markdown]
# **Basic Statistics**
#
# **Deutsch:**
#
# **Basis-Statistik**

# %%
input_df.describe()
# Out:
#        total_energy_consumption_mtoe  ...  gdp_billion_yuan
# count                      20.000000  ...         20.000000
# mean                     2345.315000  ...      44146.680000
# std                       777.438682  ...      28823.738016
# min                      1028.748000  ...      10028.010000
# 25%                      1775.179000  ...      18094.922500
# 50%                      2438.709000  ...      38031.850000
# 75%                      3008.451250  ...      65488.687500
# max                      3409.000000  ...      99086.510000
#
# [8 rows x 9 columns]

# %% [markdown]
# **Feature Scaling: Min Max Scaling**
#
# **Deutsch:**
#
# **Feature-Skalierung: Min Max Scaling**

# %%
# Calculate the number of rows in the data
nrows = input_df.shape[0]
input_df_unscaled = np.array(input_df)
input_df_unscaled = np.reshape(input_df_unscaled, (nrows, -1))
print(input_df_unscaled.shape)

#Feature Scaling
# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
final_df = scaler.fit_transform(input_df_unscaled)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_prediction = MinMaxScaler()
#consumption_df = pd.DataFrame(energy_df_ext['total_energy_consumption_mtoe'])
consumption_df = pd.DataFrame(energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']])
consumption_df_scaled = scaler_prediction.fit_transform(consumption_df)
# Out:
# (20, 9)

# %%
final_df[:,0]
# Out:
# array([0.        , 0.02524145, 0.06650178, 0.14739322, 0.24502406,
#        0.33644967, 0.4102595 , 0.48370761, 0.5106724 , 0.55629992,
#        0.62841581, 0.70603995, 0.75043231, 0.79388359, 0.82747121,
#        0.84446647, 0.86616711, 0.90832441, 0.95566646, 1.        ])

# %% [markdown]
# **Convert into a supervised learning problem**
#
# **Deutsch:**
#
# **In ein Format des überwachten Lernens umwandeln**

# %%
###
*    Dieser Teil des Codes geändert aus dem ipynb-Dokument von JonJae:
*    Titel: FeedInMngmt_LSTM_NN
*    Autor: JonJae
*    Datum: 2020
*    Verfügbarkeit: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb
*   (Quelle: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb abgerufen am Februar 2021)
###

#Global Settings
sequence_length = 3   # Number of past years that we want to predict the future values
n_out = 1            # Number of years that we wamt to forecast into the future

# Split the training data into x_train and y_train data sets
# Get the number of rows to train the model on 80% of the data 
train_data_len = math.ceil(final_df.shape[0] * 0.8) #16 train data point

# Create the training data
train_data = final_df[0:train_data_len, :]
X_train, y_train = [], []
in_start = 0
# step over the entire history five time step at a time
for _ in range(train_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(train_data):
		X_train.append(train_data[in_start:in_end, :])
		y_train.append(train_data[in_end:out_end, :])
	# move along one batch
	in_start += 1
    
# Convert the X_train and y_train into numpy arrays
X_train, y_train = np.array(X_train), np.array(y_train)

# Create the test data
test_data = final_df[train_data_len - sequence_length:, :]

# Seperate the test data into X_test and y_test
X_test, y_test = [], []
test_data_len = test_data.shape[0]
in_start = 0
# step over the entire history five time step at a time
for _ in range(test_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(test_data):
		X_test.append(test_data[in_start:in_end, :])
		y_test.append(test_data[in_end:out_end, :])
	# move along one batch
	in_start += 1

X_test, y_test = np.array(X_test), np.array(y_test)

# Convert the X_train and y_train to numpy arrays
X_test = np.array(X_test); y_test = np.array(y_test)
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13, 3, 9) (13, 1, 9)
# (4, 3, 9) (4, 1, 9)

# %% [markdown]
# **Take a look on test and train data after transformation**
#
# **Deutsch:**
#
# **Schauen wir nun, wie die Training- und Testdaten nach der Transformation aussiehen.**

# %%
X_train
# Out:
# array([[[0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.00879609, 0.        , 0.        , 0.        ],
#         [0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103]],
#
#        [[0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]]])

# %%
y_train
# Out:
# array([[[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]]])

# %%
X_test
# Out:
# array([[[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#         [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]]])

# %% [markdown]
# **Let's see how y_test looks like**
#
# **Deutsch:**
#
# **Schauen wir uns an, wie y_test aussieht**

# %%
y_test
# Out:
# array([[[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]],
#
#        [[1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#          1.        , 1.        , 1.        , 1.        ]]])

# %% [markdown]
# **Build the LSTM Model**
#
# **Deutsch:**
#
# **Aufbau des LSTM-Modells**

# %%
# set the denominator of mape function permanently as 1 to ensure mathematical operation error free  
set_epsilon(1)

# define model
model = Sequential()

# Custom fuction of root mean square error
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# Initializing the Neural Network based on LSTM
# Adding 1st LSTM layer
model.add(LSTM(70, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh',
               return_sequences=False))
# Adding Dropout
model.add(Dropout(0.17))

# Adding 2nd LSTM layer
#model.add(LSTM(70, return_sequences=False, activation='tanh')) 
# Adding Dropout
#model.add(Dropout(0.24))

# Adding 3rd LSTM layer
#model.add(LSTM(9, activation='tanh', return_sequences=False)) 
# Adding Dropout
#model.add(Dropout(0.24))

# Adding a hidden dense layer
model.add(Dense(units=70, activation='tanh'))
model.add(Dropout(0.23))

#model.add(TimeDistributed(Dense(30)))
#model.add(Dropout(0.23))
#model.add(Activation('relu'))
#model.add(LeakyReLU(alpha=0.3))
#model.add(Dense(15, activation='relu'))

# Output layer
model.add(Dense(9))

#model.add(Dense(n_steps_out, activation='relu'))

# Compiling the Neural Network
model.compile(optimizer=Adam(learning_rate=0.0005), loss=rmse, metrics='mean_absolute_percentage_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 70)                22400
# _________________________________________________________________
# dropout (Dropout)            (None, 70)                0
# _________________________________________________________________
# dense (Dense)                (None, 70)                4970
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 70)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 639
# =================================================================
# Total params: 28,009
# Trainable params: 28,009
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Start training with max 2000 epochs**
#
# **Deutsch:**
#
# **Training mit max. 2000 Epochen**

# %%
epochs = 2000
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=120, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),  batch_size=2,
                    epochs=epochs, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/2000
# 7/7 [==============================] - 3s 193ms/step - loss: 0.3423 - mean_absolute_percentage_error: 31.8677 - val_loss: 0.8067 - val_mean_absolute_percentage_error: 80.0201
# Epoch 2/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2886 - mean_absolute_percentage_error: 26.4554 - val_loss: 0.6743 - val_mean_absolute_percentage_error: 66.5062
# Epoch 3/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2212 - mean_absolute_percentage_error: 19.8637 - val_loss: 0.5276 - val_mean_absolute_percentage_error: 50.9235
# Epoch 4/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1658 - mean_absolute_percentage_error: 14.0999 - val_loss: 0.3677 - val_mean_absolute_percentage_error: 32.2365
# Epoch 5/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1075 - mean_absolute_percentage_error: 8.6228 - val_loss: 0.2551 - val_mean_absolute_percentage_error: 21.8973
# Epoch 6/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0968 - mean_absolute_percentage_error: 7.6471 - val_loss: 0.2177 - val_mean_absolute_percentage_error: 19.1623
# Epoch 7/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1054 - mean_absolute_percentage_error: 8.7483 - val_loss: 0.2024 - val_mean_absolute_percentage_error: 17.2689
# Epoch 8/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0978 - mean_absolute_percentage_error: 7.9151 - val_loss: 0.2211 - val_mean_absolute_percentage_error: 18.6485
# Epoch 9/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1016 - mean_absolute_percentage_error: 8.2982 - val_loss: 0.2268 - val_mean_absolute_percentage_error: 19.9686
# Epoch 10/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1095 - mean_absolute_percentage_error: 9.0819 - val_loss: 0.2132 - val_mean_absolute_percentage_error: 18.4763
# Epoch 11/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0921 - mean_absolute_percentage_error: 7.6131 - val_loss: 0.1986 - val_mean_absolute_percentage_error: 16.9932
# Epoch 12/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0914 - mean_absolute_percentage_error: 7.3295 - val_loss: 0.2060 - val_mean_absolute_percentage_error: 18.4359
# Epoch 13/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0956 - mean_absolute_percentage_error: 7.7307 - val_loss: 0.2089 - val_mean_absolute_percentage_error: 18.5532
# Epoch 14/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0947 - mean_absolute_percentage_error: 7.9096 - val_loss: 0.2173 - val_mean_absolute_percentage_error: 18.4757
# Epoch 15/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0874 - mean_absolute_percentage_error: 7.2918 - val_loss: 0.2077 - val_mean_absolute_percentage_error: 17.7436
# Epoch 16/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0857 - mean_absolute_percentage_error: 6.9084 - val_loss: 0.1986 - val_mean_absolute_percentage_error: 17.0675
# Epoch 17/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0877 - mean_absolute_percentage_error: 7.2404 - val_loss: 0.2217 - val_mean_absolute_percentage_error: 19.3793
# Epoch 18/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0758 - mean_absolute_percentage_error: 6.3189 - val_loss: 0.2246 - val_mean_absolute_percentage_error: 19.2226
# Epoch 19/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0817 - mean_absolute_percentage_error: 6.7867 - val_loss: 0.1883 - val_mean_absolute_percentage_error: 15.9263
# Epoch 20/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0936 - mean_absolute_percentage_error: 7.6735 - val_loss: 0.1507 - val_mean_absolute_percentage_error: 13.2496
# Epoch 21/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0817 - mean_absolute_percentage_error: 6.8685 - val_loss: 0.1493 - val_mean_absolute_percentage_error: 12.7578
# Epoch 22/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0811 - mean_absolute_percentage_error: 6.8040 - val_loss: 0.1814 - val_mean_absolute_percentage_error: 15.1254
# Epoch 23/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0845 - mean_absolute_percentage_error: 7.1595 - val_loss: 0.2038 - val_mean_absolute_percentage_error: 17.1445
# Epoch 24/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0768 - mean_absolute_percentage_error: 6.3713 - val_loss: 0.1793 - val_mean_absolute_percentage_error: 15.0037
# Epoch 25/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0808 - mean_absolute_percentage_error: 6.6017 - val_loss: 0.1710 - val_mean_absolute_percentage_error: 14.3033
# Epoch 26/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0734 - mean_absolute_percentage_error: 6.2189 - val_loss: 0.1839 - val_mean_absolute_percentage_error: 15.5006
# Epoch 27/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0744 - mean_absolute_percentage_error: 6.1581 - val_loss: 0.1801 - val_mean_absolute_percentage_error: 15.0365
# Epoch 28/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0703 - mean_absolute_percentage_error: 5.7316 - val_loss: 0.1735 - val_mean_absolute_percentage_error: 14.7931
# Epoch 29/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0779 - mean_absolute_percentage_error: 6.4806 - val_loss: 0.1603 - val_mean_absolute_percentage_error: 14.3019
# Epoch 30/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0772 - mean_absolute_percentage_error: 6.3902 - val_loss: 0.1550 - val_mean_absolute_percentage_error: 13.8037
# Epoch 31/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0795 - mean_absolute_percentage_error: 6.4940 - val_loss: 0.1437 - val_mean_absolute_percentage_error: 13.0116
# Epoch 32/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0750 - mean_absolute_percentage_error: 6.2632 - val_loss: 0.1306 - val_mean_absolute_percentage_error: 11.7016
# Epoch 33/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0797 - mean_absolute_percentage_error: 6.4603 - val_loss: 0.1345 - val_mean_absolute_percentage_error: 11.1537
# Epoch 34/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0741 - mean_absolute_percentage_error: 5.9772 - val_loss: 0.1568 - val_mean_absolute_percentage_error: 12.3085
# Epoch 35/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0712 - mean_absolute_percentage_error: 5.9096 - val_loss: 0.1463 - val_mean_absolute_percentage_error: 11.8161
# Epoch 36/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0721 - mean_absolute_percentage_error: 6.0132 - val_loss: 0.1240 - val_mean_absolute_percentage_error: 10.5041
# Epoch 37/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0769 - mean_absolute_percentage_error: 6.5421 - val_loss: 0.1108 - val_mean_absolute_percentage_error: 9.8944
# Epoch 38/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0785 - mean_absolute_percentage_error: 6.5420 - val_loss: 0.1216 - val_mean_absolute_percentage_error: 10.6900
# Epoch 39/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0744 - mean_absolute_percentage_error: 6.1676 - val_loss: 0.1320 - val_mean_absolute_percentage_error: 11.2123
# Epoch 40/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0676 - mean_absolute_percentage_error: 5.4984 - val_loss: 0.1476 - val_mean_absolute_percentage_error: 11.9842
# Epoch 41/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0812 - mean_absolute_percentage_error: 6.8380 - val_loss: 0.1257 - val_mean_absolute_percentage_error: 9.9726
# Epoch 42/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0694 - mean_absolute_percentage_error: 5.7143 - val_loss: 0.1298 - val_mean_absolute_percentage_error: 11.0850
# Epoch 43/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0685 - mean_absolute_percentage_error: 5.7143 - val_loss: 0.1291 - val_mean_absolute_percentage_error: 11.0997
# Epoch 44/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0778 - mean_absolute_percentage_error: 6.5533 - val_loss: 0.1171 - val_mean_absolute_percentage_error: 9.8178
# Epoch 45/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0790 - mean_absolute_percentage_error: 6.7020 - val_loss: 0.1473 - val_mean_absolute_percentage_error: 12.2088
# Epoch 46/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0816 - mean_absolute_percentage_error: 6.9522 - val_loss: 0.1598 - val_mean_absolute_percentage_error: 14.0299
# Epoch 47/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0695 - mean_absolute_percentage_error: 5.6282 - val_loss: 0.1341 - val_mean_absolute_percentage_error: 11.4793
# Epoch 48/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0716 - mean_absolute_percentage_error: 5.9006 - val_loss: 0.1184 - val_mean_absolute_percentage_error: 10.6220
# Epoch 49/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0708 - mean_absolute_percentage_error: 5.7409 - val_loss: 0.1242 - val_mean_absolute_percentage_error: 10.6669
# Epoch 50/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0717 - mean_absolute_percentage_error: 5.9795 - val_loss: 0.1029 - val_mean_absolute_percentage_error: 9.1219
# Epoch 51/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0789 - mean_absolute_percentage_error: 6.4437 - val_loss: 0.1173 - val_mean_absolute_percentage_error: 10.2308
# Epoch 52/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0691 - mean_absolute_percentage_error: 5.8626 - val_loss: 0.1762 - val_mean_absolute_percentage_error: 16.8759
# Epoch 53/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0808 - mean_absolute_percentage_error: 6.8957 - val_loss: 0.1376 - val_mean_absolute_percentage_error: 12.3592
# Epoch 54/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0686 - mean_absolute_percentage_error: 5.6164 - val_loss: 0.1049 - val_mean_absolute_percentage_error: 8.4654
# Epoch 55/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0695 - mean_absolute_percentage_error: 5.7491 - val_loss: 0.1192 - val_mean_absolute_percentage_error: 9.8965
# Epoch 56/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0730 - mean_absolute_percentage_error: 6.1062 - val_loss: 0.1622 - val_mean_absolute_percentage_error: 13.4882
# Epoch 57/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0694 - mean_absolute_percentage_error: 5.7119 - val_loss: 0.1551 - val_mean_absolute_percentage_error: 13.0873
# Epoch 58/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0729 - mean_absolute_percentage_error: 6.0721 - val_loss: 0.1409 - val_mean_absolute_percentage_error: 12.0584
# Epoch 59/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0651 - mean_absolute_percentage_error: 5.3376 - val_loss: 0.1115 - val_mean_absolute_percentage_error: 9.4910
# Epoch 60/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0773 - mean_absolute_percentage_error: 6.3644 - val_loss: 0.1011 - val_mean_absolute_percentage_error: 8.3964
# Epoch 61/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0742 - mean_absolute_percentage_error: 6.2790 - val_loss: 0.1208 - val_mean_absolute_percentage_error: 10.1679
# Epoch 62/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0709 - mean_absolute_percentage_error: 5.6194 - val_loss: 0.1237 - val_mean_absolute_percentage_error: 10.4348
# Epoch 63/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0758 - mean_absolute_percentage_error: 6.2448 - val_loss: 0.1086 - val_mean_absolute_percentage_error: 9.1983
# Epoch 64/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0661 - mean_absolute_percentage_error: 5.4285 - val_loss: 0.1011 - val_mean_absolute_percentage_error: 8.5778
# Epoch 65/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0708 - mean_absolute_percentage_error: 5.8559 - val_loss: 0.1071 - val_mean_absolute_percentage_error: 9.2189
# Epoch 66/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0724 - mean_absolute_percentage_error: 6.2064 - val_loss: 0.1207 - val_mean_absolute_percentage_error: 10.1555
# Epoch 67/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0748 - mean_absolute_percentage_error: 6.4279 - val_loss: 0.1198 - val_mean_absolute_percentage_error: 10.2486
# Epoch 68/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0648 - mean_absolute_percentage_error: 5.3574 - val_loss: 0.1197 - val_mean_absolute_percentage_error: 10.6189
# Epoch 69/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0677 - mean_absolute_percentage_error: 5.5954 - val_loss: 0.0959 - val_mean_absolute_percentage_error: 8.2998
# Epoch 70/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0738 - mean_absolute_percentage_error: 6.0840 - val_loss: 0.0851 - val_mean_absolute_percentage_error: 7.1200
# Epoch 71/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0639 - mean_absolute_percentage_error: 5.1408 - val_loss: 0.1045 - val_mean_absolute_percentage_error: 9.1087
# Epoch 72/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0722 - mean_absolute_percentage_error: 5.9240 - val_loss: 0.1097 - val_mean_absolute_percentage_error: 9.6823
# Epoch 73/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0772 - mean_absolute_percentage_error: 6.5839 - val_loss: 0.1002 - val_mean_absolute_percentage_error: 8.7589
# Epoch 74/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0634 - mean_absolute_percentage_error: 5.2833 - val_loss: 0.0956 - val_mean_absolute_percentage_error: 8.2161
# Epoch 75/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0642 - mean_absolute_percentage_error: 5.4018 - val_loss: 0.1042 - val_mean_absolute_percentage_error: 8.7536
# Epoch 76/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0711 - mean_absolute_percentage_error: 6.0670 - val_loss: 0.0957 - val_mean_absolute_percentage_error: 7.8808
# Epoch 77/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0699 - mean_absolute_percentage_error: 5.9546 - val_loss: 0.1038 - val_mean_absolute_percentage_error: 8.8450
# Epoch 78/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0678 - mean_absolute_percentage_error: 5.5208 - val_loss: 0.1251 - val_mean_absolute_percentage_error: 10.7713
# Epoch 79/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0677 - mean_absolute_percentage_error: 5.7059 - val_loss: 0.1140 - val_mean_absolute_percentage_error: 9.4911
# Epoch 80/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0688 - mean_absolute_percentage_error: 5.8193 - val_loss: 0.1242 - val_mean_absolute_percentage_error: 10.2956
# Epoch 81/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0757 - mean_absolute_percentage_error: 6.2697 - val_loss: 0.1240 - val_mean_absolute_percentage_error: 10.2959
# Epoch 82/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0569 - mean_absolute_percentage_error: 4.7420 - val_loss: 0.1067 - val_mean_absolute_percentage_error: 8.8597
# Epoch 83/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0701 - mean_absolute_percentage_error: 6.0134 - val_loss: 0.1174 - val_mean_absolute_percentage_error: 9.8347
# Epoch 84/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0704 - mean_absolute_percentage_error: 6.0982 - val_loss: 0.1244 - val_mean_absolute_percentage_error: 11.0966
# Epoch 85/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0707 - mean_absolute_percentage_error: 5.8718 - val_loss: 0.1350 - val_mean_absolute_percentage_error: 12.6341
# Epoch 86/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0640 - mean_absolute_percentage_error: 5.2709 - val_loss: 0.1314 - val_mean_absolute_percentage_error: 12.0055
# Epoch 87/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0707 - mean_absolute_percentage_error: 5.9776 - val_loss: 0.1257 - val_mean_absolute_percentage_error: 11.3193
# Epoch 88/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0636 - mean_absolute_percentage_error: 5.4456 - val_loss: 0.1094 - val_mean_absolute_percentage_error: 10.0410
# Epoch 89/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0727 - mean_absolute_percentage_error: 6.1761 - val_loss: 0.1005 - val_mean_absolute_percentage_error: 9.1184
# Epoch 90/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0622 - mean_absolute_percentage_error: 5.1999 - val_loss: 0.1161 - val_mean_absolute_percentage_error: 10.0572
# Epoch 91/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0734 - mean_absolute_percentage_error: 6.2896 - val_loss: 0.1167 - val_mean_absolute_percentage_error: 10.0912
# Epoch 92/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0625 - mean_absolute_percentage_error: 5.0873 - val_loss: 0.1195 - val_mean_absolute_percentage_error: 10.1479
# Epoch 93/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0634 - mean_absolute_percentage_error: 5.1870 - val_loss: 0.1258 - val_mean_absolute_percentage_error: 11.1382
# Epoch 94/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0702 - mean_absolute_percentage_error: 5.7529 - val_loss: 0.0966 - val_mean_absolute_percentage_error: 8.1789
# Epoch 95/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0599 - mean_absolute_percentage_error: 4.9429 - val_loss: 0.0861 - val_mean_absolute_percentage_error: 7.2262
# Epoch 96/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0657 - mean_absolute_percentage_error: 5.4999 - val_loss: 0.0833 - val_mean_absolute_percentage_error: 7.1654
# Epoch 97/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0783 - mean_absolute_percentage_error: 6.7520 - val_loss: 0.0828 - val_mean_absolute_percentage_error: 7.1488
# Epoch 98/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0717 - mean_absolute_percentage_error: 6.0187 - val_loss: 0.0902 - val_mean_absolute_percentage_error: 7.8402
# Epoch 99/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0636 - mean_absolute_percentage_error: 5.3414 - val_loss: 0.0926 - val_mean_absolute_percentage_error: 8.0909
# Epoch 100/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0643 - mean_absolute_percentage_error: 5.2903 - val_loss: 0.0862 - val_mean_absolute_percentage_error: 7.2781
# Epoch 101/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.0686 - val_loss: 0.0949 - val_mean_absolute_percentage_error: 7.9771
# Epoch 102/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0656 - mean_absolute_percentage_error: 5.4755 - val_loss: 0.1076 - val_mean_absolute_percentage_error: 9.2358
# Epoch 103/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0660 - mean_absolute_percentage_error: 5.3710 - val_loss: 0.0972 - val_mean_absolute_percentage_error: 8.1788
# Epoch 104/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0657 - mean_absolute_percentage_error: 5.6686 - val_loss: 0.0776 - val_mean_absolute_percentage_error: 6.4354
# Epoch 105/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0692 - mean_absolute_percentage_error: 5.7899 - val_loss: 0.0838 - val_mean_absolute_percentage_error: 7.1207
# Epoch 106/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0656 - mean_absolute_percentage_error: 5.6851 - val_loss: 0.1251 - val_mean_absolute_percentage_error: 11.4326
# Epoch 107/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0622 - mean_absolute_percentage_error: 5.2494 - val_loss: 0.1065 - val_mean_absolute_percentage_error: 9.4079
# Epoch 108/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0600 - mean_absolute_percentage_error: 4.9955 - val_loss: 0.0877 - val_mean_absolute_percentage_error: 7.5105
# Epoch 109/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0647 - mean_absolute_percentage_error: 5.5432 - val_loss: 0.1042 - val_mean_absolute_percentage_error: 9.0237
# Epoch 110/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0574 - mean_absolute_percentage_error: 4.8449 - val_loss: 0.1079 - val_mean_absolute_percentage_error: 9.4902
# Epoch 111/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0690 - mean_absolute_percentage_error: 5.8952 - val_loss: 0.1003 - val_mean_absolute_percentage_error: 8.8092
# Epoch 112/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0624 - mean_absolute_percentage_error: 5.3089 - val_loss: 0.0832 - val_mean_absolute_percentage_error: 7.0080
# Epoch 113/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0657 - mean_absolute_percentage_error: 5.4864 - val_loss: 0.0885 - val_mean_absolute_percentage_error: 7.4569
# Epoch 114/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0607 - mean_absolute_percentage_error: 5.0140 - val_loss: 0.1201 - val_mean_absolute_percentage_error: 10.4935
# Epoch 115/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0663 - mean_absolute_percentage_error: 5.7087 - val_loss: 0.1321 - val_mean_absolute_percentage_error: 12.3064
# Epoch 116/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0700 - mean_absolute_percentage_error: 5.9262 - val_loss: 0.1104 - val_mean_absolute_percentage_error: 9.9577
# Epoch 117/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0635 - mean_absolute_percentage_error: 5.3382 - val_loss: 0.1120 - val_mean_absolute_percentage_error: 9.7879
# Epoch 118/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0653 - mean_absolute_percentage_error: 5.6469 - val_loss: 0.1123 - val_mean_absolute_percentage_error: 9.5204
# Epoch 119/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0638 - mean_absolute_percentage_error: 5.3578 - val_loss: 0.0908 - val_mean_absolute_percentage_error: 7.5621
# Epoch 120/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0644 - mean_absolute_percentage_error: 5.4942 - val_loss: 0.1007 - val_mean_absolute_percentage_error: 8.8497
# Epoch 121/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0679 - mean_absolute_percentage_error: 5.9254 - val_loss: 0.1240 - val_mean_absolute_percentage_error: 11.2492
# Epoch 122/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0626 - mean_absolute_percentage_error: 5.3731 - val_loss: 0.0996 - val_mean_absolute_percentage_error: 8.7527
# Epoch 123/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0567 - mean_absolute_percentage_error: 4.7399 - val_loss: 0.0748 - val_mean_absolute_percentage_error: 6.2096
# Epoch 124/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0621 - mean_absolute_percentage_error: 5.2850 - val_loss: 0.0628 - val_mean_absolute_percentage_error: 5.1310
# Epoch 125/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0595 - mean_absolute_percentage_error: 4.9559 - val_loss: 0.0599 - val_mean_absolute_percentage_error: 5.0006
# Epoch 126/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0677 - mean_absolute_percentage_error: 5.9270 - val_loss: 0.0973 - val_mean_absolute_percentage_error: 8.6841
# Epoch 127/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0562 - mean_absolute_percentage_error: 4.7974 - val_loss: 0.1014 - val_mean_absolute_percentage_error: 8.7481
# Epoch 128/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0683 - mean_absolute_percentage_error: 5.8828 - val_loss: 0.0892 - val_mean_absolute_percentage_error: 7.5948
# Epoch 129/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0571 - mean_absolute_percentage_error: 4.8778 - val_loss: 0.0809 - val_mean_absolute_percentage_error: 6.7555
# Epoch 130/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.6318 - val_loss: 0.0948 - val_mean_absolute_percentage_error: 8.1740
# Epoch 131/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0618 - mean_absolute_percentage_error: 5.1929 - val_loss: 0.1200 - val_mean_absolute_percentage_error: 11.2073
# Epoch 132/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.1361 - val_loss: 0.0796 - val_mean_absolute_percentage_error: 6.8502
# Epoch 133/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0667 - mean_absolute_percentage_error: 5.5897 - val_loss: 0.0757 - val_mean_absolute_percentage_error: 6.4096
# Epoch 134/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0520 - mean_absolute_percentage_error: 4.4008 - val_loss: 0.1060 - val_mean_absolute_percentage_error: 9.1890
# Epoch 135/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0637 - mean_absolute_percentage_error: 5.6011 - val_loss: 0.1072 - val_mean_absolute_percentage_error: 9.1628
# Epoch 136/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0508 - mean_absolute_percentage_error: 4.1541 - val_loss: 0.0917 - val_mean_absolute_percentage_error: 7.7463
# Epoch 137/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.6745 - val_loss: 0.0760 - val_mean_absolute_percentage_error: 6.4556
# Epoch 138/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0587 - mean_absolute_percentage_error: 4.9664 - val_loss: 0.0647 - val_mean_absolute_percentage_error: 5.3485
# Epoch 139/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0687 - mean_absolute_percentage_error: 5.8370 - val_loss: 0.0788 - val_mean_absolute_percentage_error: 6.4597
# Epoch 140/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0611 - mean_absolute_percentage_error: 5.1925 - val_loss: 0.1177 - val_mean_absolute_percentage_error: 10.2699
# Epoch 141/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0586 - mean_absolute_percentage_error: 5.0478 - val_loss: 0.0922 - val_mean_absolute_percentage_error: 7.5684
# Epoch 142/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0589 - mean_absolute_percentage_error: 4.9879 - val_loss: 0.0767 - val_mean_absolute_percentage_error: 6.3923
# Epoch 143/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0639 - mean_absolute_percentage_error: 5.5262 - val_loss: 0.0707 - val_mean_absolute_percentage_error: 5.8925
# Epoch 144/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0583 - mean_absolute_percentage_error: 4.9659 - val_loss: 0.1077 - val_mean_absolute_percentage_error: 10.0845
# Epoch 145/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0544 - mean_absolute_percentage_error: 4.5435 - val_loss: 0.1067 - val_mean_absolute_percentage_error: 10.0005
# Epoch 146/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7428 - val_loss: 0.0984 - val_mean_absolute_percentage_error: 9.1009
# Epoch 147/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0571 - mean_absolute_percentage_error: 4.7473 - val_loss: 0.0732 - val_mean_absolute_percentage_error: 6.3552
# Epoch 148/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0645 - mean_absolute_percentage_error: 5.4454 - val_loss: 0.0650 - val_mean_absolute_percentage_error: 5.4345
# Epoch 149/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0610 - mean_absolute_percentage_error: 5.1073 - val_loss: 0.0802 - val_mean_absolute_percentage_error: 6.6586
# Epoch 150/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0608 - mean_absolute_percentage_error: 5.1670 - val_loss: 0.0695 - val_mean_absolute_percentage_error: 5.7468
# Epoch 151/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0625 - mean_absolute_percentage_error: 5.2746 - val_loss: 0.0773 - val_mean_absolute_percentage_error: 6.4711
# Epoch 152/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0652 - mean_absolute_percentage_error: 5.6196 - val_loss: 0.0757 - val_mean_absolute_percentage_error: 6.3495
# Epoch 153/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0553 - mean_absolute_percentage_error: 4.6689 - val_loss: 0.0754 - val_mean_absolute_percentage_error: 6.2891
# Epoch 154/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0567 - mean_absolute_percentage_error: 4.7311 - val_loss: 0.0743 - val_mean_absolute_percentage_error: 6.2939
# Epoch 155/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.6302 - val_loss: 0.0774 - val_mean_absolute_percentage_error: 6.6619
# Epoch 156/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0608 - mean_absolute_percentage_error: 5.2336 - val_loss: 0.0800 - val_mean_absolute_percentage_error: 6.8236
# Epoch 157/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0667 - mean_absolute_percentage_error: 5.6346 - val_loss: 0.0858 - val_mean_absolute_percentage_error: 7.1180
# Epoch 158/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0656 - mean_absolute_percentage_error: 5.7879 - val_loss: 0.0832 - val_mean_absolute_percentage_error: 7.2072
# Epoch 159/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0650 - mean_absolute_percentage_error: 5.5166 - val_loss: 0.0837 - val_mean_absolute_percentage_error: 7.2778
# Epoch 160/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0636 - mean_absolute_percentage_error: 5.5077 - val_loss: 0.0944 - val_mean_absolute_percentage_error: 7.7598
# Epoch 161/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0610 - mean_absolute_percentage_error: 5.2389 - val_loss: 0.1000 - val_mean_absolute_percentage_error: 8.3902
# Epoch 162/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0611 - mean_absolute_percentage_error: 5.4213 - val_loss: 0.1091 - val_mean_absolute_percentage_error: 9.3946
# Epoch 163/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0615 - mean_absolute_percentage_error: 5.2747 - val_loss: 0.1144 - val_mean_absolute_percentage_error: 10.0740
# Epoch 164/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0632 - mean_absolute_percentage_error: 5.4856 - val_loss: 0.1234 - val_mean_absolute_percentage_error: 11.2237
# Epoch 165/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0613 - mean_absolute_percentage_error: 5.3287 - val_loss: 0.1002 - val_mean_absolute_percentage_error: 8.7026
# Epoch 166/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0567 - mean_absolute_percentage_error: 4.8795 - val_loss: 0.0748 - val_mean_absolute_percentage_error: 6.4279
# Epoch 167/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0639 - mean_absolute_percentage_error: 5.4644 - val_loss: 0.0823 - val_mean_absolute_percentage_error: 6.9843
# Epoch 168/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0595 - mean_absolute_percentage_error: 5.0407 - val_loss: 0.0726 - val_mean_absolute_percentage_error: 6.2162
# Epoch 169/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0605 - mean_absolute_percentage_error: 5.1044 - val_loss: 0.1162 - val_mean_absolute_percentage_error: 10.4867
# Epoch 170/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0690 - mean_absolute_percentage_error: 6.0700 - val_loss: 0.1452 - val_mean_absolute_percentage_error: 13.8912
# Epoch 171/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0616 - mean_absolute_percentage_error: 5.1753 - val_loss: 0.0831 - val_mean_absolute_percentage_error: 7.2280
# Epoch 172/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0602 - mean_absolute_percentage_error: 5.0614 - val_loss: 0.0638 - val_mean_absolute_percentage_error: 5.4272
# Epoch 173/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0634 - mean_absolute_percentage_error: 5.4251 - val_loss: 0.0857 - val_mean_absolute_percentage_error: 7.4589
# Epoch 174/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0716 - mean_absolute_percentage_error: 6.2002 - val_loss: 0.1340 - val_mean_absolute_percentage_error: 12.3626
# Epoch 175/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0559 - mean_absolute_percentage_error: 4.7086 - val_loss: 0.0866 - val_mean_absolute_percentage_error: 7.2375
# Epoch 176/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0564 - mean_absolute_percentage_error: 4.8545 - val_loss: 0.0732 - val_mean_absolute_percentage_error: 6.1736
# Epoch 177/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0530 - mean_absolute_percentage_error: 4.5008 - val_loss: 0.0809 - val_mean_absolute_percentage_error: 6.8512
# Epoch 178/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0582 - mean_absolute_percentage_error: 4.9006 - val_loss: 0.0686 - val_mean_absolute_percentage_error: 5.9203
# Epoch 179/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0652 - mean_absolute_percentage_error: 5.7399 - val_loss: 0.0615 - val_mean_absolute_percentage_error: 5.2009
# Epoch 180/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0551 - mean_absolute_percentage_error: 4.6676 - val_loss: 0.0748 - val_mean_absolute_percentage_error: 6.5371
# Epoch 181/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0567 - mean_absolute_percentage_error: 4.9196 - val_loss: 0.0807 - val_mean_absolute_percentage_error: 7.1019
# Epoch 182/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0509 - mean_absolute_percentage_error: 4.2606 - val_loss: 0.1062 - val_mean_absolute_percentage_error: 9.3742
# Epoch 183/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0591 - mean_absolute_percentage_error: 5.2066 - val_loss: 0.0948 - val_mean_absolute_percentage_error: 8.0437
# Epoch 184/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0569 - mean_absolute_percentage_error: 4.7851 - val_loss: 0.0707 - val_mean_absolute_percentage_error: 5.8818
# Epoch 185/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0653 - mean_absolute_percentage_error: 5.5471 - val_loss: 0.0638 - val_mean_absolute_percentage_error: 5.4310
# Epoch 186/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0619 - mean_absolute_percentage_error: 5.3835 - val_loss: 0.0654 - val_mean_absolute_percentage_error: 5.5228
# Epoch 187/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0573 - mean_absolute_percentage_error: 4.8520 - val_loss: 0.0721 - val_mean_absolute_percentage_error: 6.0468
# Epoch 188/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0513 - mean_absolute_percentage_error: 4.3070 - val_loss: 0.0774 - val_mean_absolute_percentage_error: 6.5237
# Epoch 189/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0551 - mean_absolute_percentage_error: 4.7563 - val_loss: 0.0776 - val_mean_absolute_percentage_error: 6.4179
# Epoch 190/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7471 - val_loss: 0.0750 - val_mean_absolute_percentage_error: 6.2979
# Epoch 191/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0532 - mean_absolute_percentage_error: 4.4995 - val_loss: 0.0770 - val_mean_absolute_percentage_error: 6.4715
# Epoch 192/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0537 - mean_absolute_percentage_error: 4.5936 - val_loss: 0.0688 - val_mean_absolute_percentage_error: 5.7471
# Epoch 193/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0619 - mean_absolute_percentage_error: 5.4259 - val_loss: 0.0641 - val_mean_absolute_percentage_error: 5.3539
# Epoch 194/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.7245 - val_loss: 0.0682 - val_mean_absolute_percentage_error: 5.9492
# Epoch 195/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0643 - mean_absolute_percentage_error: 5.5163 - val_loss: 0.0613 - val_mean_absolute_percentage_error: 5.1013
# Epoch 196/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.2637 - val_loss: 0.0650 - val_mean_absolute_percentage_error: 5.3977
# Epoch 197/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.8137 - val_loss: 0.0850 - val_mean_absolute_percentage_error: 7.5896
# Epoch 198/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0575 - mean_absolute_percentage_error: 5.0424 - val_loss: 0.0939 - val_mean_absolute_percentage_error: 8.5263
# Epoch 199/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0573 - mean_absolute_percentage_error: 4.8124 - val_loss: 0.0707 - val_mean_absolute_percentage_error: 6.1025
# Epoch 200/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0525 - mean_absolute_percentage_error: 4.5655 - val_loss: 0.0787 - val_mean_absolute_percentage_error: 6.8242
# Epoch 201/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0602 - mean_absolute_percentage_error: 5.2860 - val_loss: 0.0895 - val_mean_absolute_percentage_error: 7.8165
# Epoch 202/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0662 - mean_absolute_percentage_error: 5.9104 - val_loss: 0.0929 - val_mean_absolute_percentage_error: 8.2626
# Epoch 203/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0575 - mean_absolute_percentage_error: 4.8770 - val_loss: 0.0749 - val_mean_absolute_percentage_error: 6.3710
# Epoch 204/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0615 - mean_absolute_percentage_error: 5.4511 - val_loss: 0.0999 - val_mean_absolute_percentage_error: 8.6454
# Epoch 205/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0535 - mean_absolute_percentage_error: 4.6391 - val_loss: 0.0849 - val_mean_absolute_percentage_error: 6.9887
# Epoch 206/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0503 - mean_absolute_percentage_error: 4.2561 - val_loss: 0.0708 - val_mean_absolute_percentage_error: 5.8141
# Epoch 207/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0618 - mean_absolute_percentage_error: 5.4842 - val_loss: 0.0636 - val_mean_absolute_percentage_error: 5.2971
# Epoch 208/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0593 - mean_absolute_percentage_error: 5.1314 - val_loss: 0.0659 - val_mean_absolute_percentage_error: 5.6149
# Epoch 209/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0558 - mean_absolute_percentage_error: 4.8382 - val_loss: 0.0626 - val_mean_absolute_percentage_error: 5.2833
# Epoch 210/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0539 - mean_absolute_percentage_error: 4.6791 - val_loss: 0.0630 - val_mean_absolute_percentage_error: 5.3269
# Epoch 211/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0512 - mean_absolute_percentage_error: 4.3575 - val_loss: 0.0643 - val_mean_absolute_percentage_error: 5.3902
# Epoch 212/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0618 - mean_absolute_percentage_error: 5.3330 - val_loss: 0.0708 - val_mean_absolute_percentage_error: 6.0284
# Epoch 213/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0576 - mean_absolute_percentage_error: 4.9648 - val_loss: 0.0649 - val_mean_absolute_percentage_error: 5.4853
# Epoch 214/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0539 - mean_absolute_percentage_error: 4.6131 - val_loss: 0.0664 - val_mean_absolute_percentage_error: 5.5615
# Epoch 215/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0541 - mean_absolute_percentage_error: 4.6740 - val_loss: 0.0724 - val_mean_absolute_percentage_error: 6.0213
# Epoch 216/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0560 - mean_absolute_percentage_error: 4.8242 - val_loss: 0.0684 - val_mean_absolute_percentage_error: 5.6862
# Epoch 217/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0573 - mean_absolute_percentage_error: 5.0622 - val_loss: 0.0645 - val_mean_absolute_percentage_error: 5.4772
# Epoch 218/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0547 - mean_absolute_percentage_error: 4.6971 - val_loss: 0.0731 - val_mean_absolute_percentage_error: 6.2076
# Epoch 219/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0533 - mean_absolute_percentage_error: 4.5610 - val_loss: 0.0768 - val_mean_absolute_percentage_error: 6.3484
# Epoch 220/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0643 - mean_absolute_percentage_error: 5.6027 - val_loss: 0.0767 - val_mean_absolute_percentage_error: 6.4164
# Epoch 221/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0474 - mean_absolute_percentage_error: 3.9654 - val_loss: 0.0651 - val_mean_absolute_percentage_error: 5.3743
# Epoch 222/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0574 - mean_absolute_percentage_error: 4.8279 - val_loss: 0.0577 - val_mean_absolute_percentage_error: 4.8666
# Epoch 223/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7890 - val_loss: 0.0636 - val_mean_absolute_percentage_error: 5.3349
# Epoch 224/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0571 - mean_absolute_percentage_error: 4.9116 - val_loss: 0.0647 - val_mean_absolute_percentage_error: 5.4797
# Epoch 225/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0572 - mean_absolute_percentage_error: 5.0551 - val_loss: 0.0779 - val_mean_absolute_percentage_error: 6.6137
# Epoch 226/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0585 - mean_absolute_percentage_error: 5.0444 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 6.1623
# Epoch 227/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0557 - mean_absolute_percentage_error: 4.8669 - val_loss: 0.0627 - val_mean_absolute_percentage_error: 5.2491
# Epoch 228/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0610 - mean_absolute_percentage_error: 5.3799 - val_loss: 0.0600 - val_mean_absolute_percentage_error: 5.0986
# Epoch 229/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0574 - mean_absolute_percentage_error: 4.8831 - val_loss: 0.0680 - val_mean_absolute_percentage_error: 5.6685
# Epoch 230/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0545 - mean_absolute_percentage_error: 4.6901 - val_loss: 0.0801 - val_mean_absolute_percentage_error: 6.7683
# Epoch 231/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.2173 - val_loss: 0.0779 - val_mean_absolute_percentage_error: 6.4599
# Epoch 232/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0543 - mean_absolute_percentage_error: 4.7120 - val_loss: 0.0795 - val_mean_absolute_percentage_error: 6.5828
# Epoch 233/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0572 - mean_absolute_percentage_error: 4.8641 - val_loss: 0.0646 - val_mean_absolute_percentage_error: 5.3614
# Epoch 234/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0585 - mean_absolute_percentage_error: 5.0678 - val_loss: 0.0661 - val_mean_absolute_percentage_error: 5.4558
# Epoch 235/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0597 - mean_absolute_percentage_error: 5.1265 - val_loss: 0.0870 - val_mean_absolute_percentage_error: 7.6741
# Epoch 236/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0561 - mean_absolute_percentage_error: 4.8757 - val_loss: 0.1021 - val_mean_absolute_percentage_error: 9.3408
# Epoch 237/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0471 - mean_absolute_percentage_error: 3.9402 - val_loss: 0.0750 - val_mean_absolute_percentage_error: 6.3908
# Epoch 238/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0543 - mean_absolute_percentage_error: 4.7120 - val_loss: 0.0673 - val_mean_absolute_percentage_error: 5.6632
# Epoch 239/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0536 - mean_absolute_percentage_error: 4.7731 - val_loss: 0.0804 - val_mean_absolute_percentage_error: 6.8032
# Epoch 240/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0482 - mean_absolute_percentage_error: 4.1123 - val_loss: 0.0885 - val_mean_absolute_percentage_error: 7.7242
# Epoch 241/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0553 - mean_absolute_percentage_error: 4.7654 - val_loss: 0.0704 - val_mean_absolute_percentage_error: 5.9704
# Epoch 242/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0539 - mean_absolute_percentage_error: 4.7325 - val_loss: 0.0684 - val_mean_absolute_percentage_error: 5.8212
# Epoch 243/2000
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0512 - mean_absolute_percentage_error: 4.5671 - val_loss: 0.0706 - val_mean_absolute_percentage_error: 5.8312
# Epoch 244/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0500 - mean_absolute_percentage_error: 4.3335 - val_loss: 0.0728 - val_mean_absolute_percentage_error: 5.9963
# Epoch 245/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0535 - mean_absolute_percentage_error: 4.6363 - val_loss: 0.0782 - val_mean_absolute_percentage_error: 6.6541
# Epoch 246/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0519 - mean_absolute_percentage_error: 4.5065 - val_loss: 0.0782 - val_mean_absolute_percentage_error: 6.7229
# Epoch 247/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0557 - mean_absolute_percentage_error: 4.8817 - val_loss: 0.0905 - val_mean_absolute_percentage_error: 7.8915
# Epoch 248/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0583 - mean_absolute_percentage_error: 5.2986 - val_loss: 0.1286 - val_mean_absolute_percentage_error: 11.8483
# Epoch 249/2000
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0621 - mean_absolute_percentage_error: 5.4469 - val_loss: 0.1297 - val_mean_absolute_percentage_error: 12.0045
# Epoch 250/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0564 - mean_absolute_percentage_error: 4.8918 - val_loss: 0.0770 - val_mean_absolute_percentage_error: 6.4430
# Epoch 251/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0564 - mean_absolute_percentage_error: 4.8736 - val_loss: 0.0695 - val_mean_absolute_percentage_error: 5.8712
# Epoch 252/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0677 - mean_absolute_percentage_error: 6.0140 - val_loss: 0.0788 - val_mean_absolute_percentage_error: 6.5697
# Epoch 253/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0615 - mean_absolute_percentage_error: 5.3931 - val_loss: 0.1014 - val_mean_absolute_percentage_error: 8.8160
# Epoch 254/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0526 - mean_absolute_percentage_error: 4.5755 - val_loss: 0.0789 - val_mean_absolute_percentage_error: 6.6106
# Epoch 255/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0549 - mean_absolute_percentage_error: 4.7507 - val_loss: 0.0703 - val_mean_absolute_percentage_error: 5.8743
# Epoch 256/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0549 - mean_absolute_percentage_error: 4.7065 - val_loss: 0.0703 - val_mean_absolute_percentage_error: 5.7980
# Epoch 257/2000
# ...
# Epoch 258/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0569 - mean_absolute_percentage_error: 4.8876 - val_loss: 0.0681 - val_mean_absolute_percentage_error: 5.7249
# Epoch 259/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0544 - mean_absolute_percentage_error: 4.7415 - val_loss: 0.0832 - val_mean_absolute_percentage_error: 7.1785
# Epoch 260/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0556 - mean_absolute_percentage_error: 4.7640 - val_loss: 0.0739 - val_mean_absolute_percentage_error: 6.0552
# Epoch 261/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.4983 - val_loss: 0.1307 - val_mean_absolute_percentage_error: 12.1555
# Epoch 262/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0661 - mean_absolute_percentage_error: 5.9732 - val_loss: 0.1281 - val_mean_absolute_percentage_error: 11.9274
# Epoch 263/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0502 - mean_absolute_percentage_error: 4.3678 - val_loss: 0.1020 - val_mean_absolute_percentage_error: 9.1614
# Epoch 264/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0561 - mean_absolute_percentage_error: 4.8905 - val_loss: 0.0704 - val_mean_absolute_percentage_error: 5.8863
# Epoch 265/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0647 - mean_absolute_percentage_error: 5.8499 - val_loss: 0.0700 - val_mean_absolute_percentage_error: 5.9313
# Epoch 266/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0632 - mean_absolute_percentage_error: 5.5057 - val_loss: 0.0779 - val_mean_absolute_percentage_error: 6.8257
# Epoch 267/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0595 - mean_absolute_percentage_error: 5.2926 - val_loss: 0.0720 - val_mean_absolute_percentage_error: 6.1610
# Epoch 268/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7825 - val_loss: 0.0710 - val_mean_absolute_percentage_error: 5.9551
# Epoch 269/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0515 - mean_absolute_percentage_error: 4.5230 - val_loss: 0.0719 - val_mean_absolute_percentage_error: 5.9937
# Epoch 270/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.7783 - val_loss: 0.0671 - val_mean_absolute_percentage_error: 5.6763
# Epoch 271/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0529 - mean_absolute_percentage_error: 4.5764 - val_loss: 0.0840 - val_mean_absolute_percentage_error: 7.4731
# Epoch 272/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0578 - mean_absolute_percentage_error: 5.1443 - val_loss: 0.0702 - val_mean_absolute_percentage_error: 5.9519
# Epoch 273/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0536 - mean_absolute_percentage_error: 4.5401 - val_loss: 0.0678 - val_mean_absolute_percentage_error: 5.6654
# Epoch 274/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0539 - mean_absolute_percentage_error: 4.6157 - val_loss: 0.0810 - val_mean_absolute_percentage_error: 6.7668
# Epoch 275/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0508 - mean_absolute_percentage_error: 4.2124 - val_loss: 0.0829 - val_mean_absolute_percentage_error: 6.8486
# Epoch 276/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.6647 - val_loss: 0.0993 - val_mean_absolute_percentage_error: 8.7041
# Epoch 277/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0452 - mean_absolute_percentage_error: 3.9523 - val_loss: 0.0777 - val_mean_absolute_percentage_error: 6.6560
# Epoch 278/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0465 - mean_absolute_percentage_error: 3.9987 - val_loss: 0.0760 - val_mean_absolute_percentage_error: 6.5975
# Epoch 279/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0567 - mean_absolute_percentage_error: 4.9458 - val_loss: 0.0929 - val_mean_absolute_percentage_error: 8.3723
# Epoch 280/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0558 - mean_absolute_percentage_error: 4.6640 - val_loss: 0.1004 - val_mean_absolute_percentage_error: 9.2158
# Epoch 281/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0522 - mean_absolute_percentage_error: 4.5948 - val_loss: 0.1130 - val_mean_absolute_percentage_error: 10.4260
# Epoch 282/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0515 - mean_absolute_percentage_error: 4.4362 - val_loss: 0.0988 - val_mean_absolute_percentage_error: 8.7014
# Epoch 283/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0538 - mean_absolute_percentage_error: 4.6937 - val_loss: 0.1063 - val_mean_absolute_percentage_error: 9.5585
# Epoch 284/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0556 - mean_absolute_percentage_error: 4.8927 - val_loss: 0.0792 - val_mean_absolute_percentage_error: 6.9225
# Epoch 285/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0569 - mean_absolute_percentage_error: 5.0296 - val_loss: 0.0727 - val_mean_absolute_percentage_error: 6.2450
# Epoch 286/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0491 - mean_absolute_percentage_error: 4.2149 - val_loss: 0.0792 - val_mean_absolute_percentage_error: 6.8788
# Epoch 287/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0556 - mean_absolute_percentage_error: 4.7988 - val_loss: 0.0741 - val_mean_absolute_percentage_error: 6.2491
# Epoch 288/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0514 - mean_absolute_percentage_error: 4.5012 - val_loss: 0.0833 - val_mean_absolute_percentage_error: 7.1573
# Epoch 289/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0590 - mean_absolute_percentage_error: 5.1347 - val_loss: 0.1156 - val_mean_absolute_percentage_error: 10.4876
# Epoch 290/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0494 - mean_absolute_percentage_error: 4.3252 - val_loss: 0.1139 - val_mean_absolute_percentage_error: 10.1482
# Epoch 291/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0460 - mean_absolute_percentage_error: 3.9684 - val_loss: 0.1176 - val_mean_absolute_percentage_error: 10.5280
# Epoch 292/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0514 - mean_absolute_percentage_error: 4.4339 - val_loss: 0.0983 - val_mean_absolute_percentage_error: 8.5509
# Epoch 293/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0505 - mean_absolute_percentage_error: 4.3123 - val_loss: 0.0926 - val_mean_absolute_percentage_error: 8.0343
# Epoch 294/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0523 - mean_absolute_percentage_error: 4.5356 - val_loss: 0.0798 - val_mean_absolute_percentage_error: 6.6118
# Epoch 295/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0507 - mean_absolute_percentage_error: 4.3939 - val_loss: 0.1040 - val_mean_absolute_percentage_error: 9.2578
# Epoch 296/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0494 - mean_absolute_percentage_error: 4.2324 - val_loss: 0.1063 - val_mean_absolute_percentage_error: 9.6217
# Epoch 297/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0563 - mean_absolute_percentage_error: 4.7157 - val_loss: 0.0902 - val_mean_absolute_percentage_error: 8.0285
# Epoch 298/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0566 - mean_absolute_percentage_error: 5.0553 - val_loss: 0.0927 - val_mean_absolute_percentage_error: 8.2984
# Epoch 299/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0506 - mean_absolute_percentage_error: 4.4185 - val_loss: 0.0966 - val_mean_absolute_percentage_error: 8.6846
# Epoch 300/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0564 - mean_absolute_percentage_error: 4.8761 - val_loss: 0.0821 - val_mean_absolute_percentage_error: 7.0444
# Epoch 301/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0512 - mean_absolute_percentage_error: 4.4330 - val_loss: 0.0893 - val_mean_absolute_percentage_error: 7.7741
# Epoch 302/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0496 - mean_absolute_percentage_error: 4.1875 - val_loss: 0.0684 - val_mean_absolute_percentage_error: 5.7652
# Epoch 303/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0593 - mean_absolute_percentage_error: 5.1405 - val_loss: 0.0708 - val_mean_absolute_percentage_error: 6.0394
# Epoch 304/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0605 - mean_absolute_percentage_error: 5.2802 - val_loss: 0.1022 - val_mean_absolute_percentage_error: 9.2134
# Epoch 305/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.6996 - val_loss: 0.0865 - val_mean_absolute_percentage_error: 7.4213
# Epoch 306/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0524 - mean_absolute_percentage_error: 4.4781 - val_loss: 0.0735 - val_mean_absolute_percentage_error: 6.1046
# Epoch 307/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0561 - mean_absolute_percentage_error: 4.8383 - val_loss: 0.0670 - val_mean_absolute_percentage_error: 5.6967
# Epoch 308/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0524 - mean_absolute_percentage_error: 4.5897 - val_loss: 0.0894 - val_mean_absolute_percentage_error: 7.6312
# Epoch 309/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.7785 - val_loss: 0.1157 - val_mean_absolute_percentage_error: 10.0557
# Epoch 310/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0506 - mean_absolute_percentage_error: 4.4467 - val_loss: 0.1133 - val_mean_absolute_percentage_error: 9.9635
# Epoch 311/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0481 - mean_absolute_percentage_error: 4.2568 - val_loss: 0.0994 - val_mean_absolute_percentage_error: 8.6035
# Epoch 312/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0518 - mean_absolute_percentage_error: 4.5529 - val_loss: 0.1002 - val_mean_absolute_percentage_error: 8.6051
# Epoch 313/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0465 - mean_absolute_percentage_error: 3.9496 - val_loss: 0.0960 - val_mean_absolute_percentage_error: 8.0148
# Epoch 314/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0531 - mean_absolute_percentage_error: 4.6163 - val_loss: 0.1004 - val_mean_absolute_percentage_error: 8.3757
# Epoch 315/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0538 - mean_absolute_percentage_error: 4.6464 - val_loss: 0.0815 - val_mean_absolute_percentage_error: 6.6877
# Epoch 316/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0519 - mean_absolute_percentage_error: 4.4702 - val_loss: 0.0769 - val_mean_absolute_percentage_error: 6.3564
# Epoch 317/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0534 - mean_absolute_percentage_error: 4.6546 - val_loss: 0.0890 - val_mean_absolute_percentage_error: 7.4009
# Epoch 318/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.8231 - val_loss: 0.1046 - val_mean_absolute_percentage_error: 8.9635
# Epoch 319/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0502 - mean_absolute_percentage_error: 4.2580 - val_loss: 0.1132 - val_mean_absolute_percentage_error: 9.8023
# Epoch 320/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0529 - mean_absolute_percentage_error: 4.6176 - val_loss: 0.0838 - val_mean_absolute_percentage_error: 7.0697
# Epoch 321/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0519 - mean_absolute_percentage_error: 4.5031 - val_loss: 0.0765 - val_mean_absolute_percentage_error: 6.3963
# Epoch 322/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0529 - mean_absolute_percentage_error: 4.6173 - val_loss: 0.0836 - val_mean_absolute_percentage_error: 7.1651
# Epoch 323/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0474 - mean_absolute_percentage_error: 4.0154 - val_loss: 0.0713 - val_mean_absolute_percentage_error: 6.0020
# Epoch 324/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0530 - mean_absolute_percentage_error: 4.6597 - val_loss: 0.0809 - val_mean_absolute_percentage_error: 6.9049
# Epoch 325/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0523 - mean_absolute_percentage_error: 4.5072 - val_loss: 0.0725 - val_mean_absolute_percentage_error: 6.1620
# Epoch 326/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0569 - mean_absolute_percentage_error: 4.9038 - val_loss: 0.0775 - val_mean_absolute_percentage_error: 6.5661
# Epoch 327/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.8085 - val_loss: 0.1050 - val_mean_absolute_percentage_error: 9.4347
# Epoch 328/2000
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0585 - mean_absolute_percentage_error: 5.1422 - val_loss: 0.0861 - val_mean_absolute_percentage_error: 7.4619
# Epoch 329/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0516 - mean_absolute_percentage_error: 4.4605 - val_loss: 0.0690 - val_mean_absolute_percentage_error: 5.8299
# Epoch 330/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0597 - mean_absolute_percentage_error: 5.2477 - val_loss: 0.0741 - val_mean_absolute_percentage_error: 6.2060
# Epoch 331/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0593 - mean_absolute_percentage_error: 5.2713 - val_loss: 0.1015 - val_mean_absolute_percentage_error: 8.8292
# Epoch 332/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0567 - mean_absolute_percentage_error: 4.8971 - val_loss: 0.1068 - val_mean_absolute_percentage_error: 9.3352
# Epoch 333/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0489 - mean_absolute_percentage_error: 4.3026 - val_loss: 0.0763 - val_mean_absolute_percentage_error: 6.4164
# Epoch 334/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0541 - mean_absolute_percentage_error: 4.8497 - val_loss: 0.0728 - val_mean_absolute_percentage_error: 6.1746
# Epoch 335/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0513 - mean_absolute_percentage_error: 4.4345 - val_loss: 0.0832 - val_mean_absolute_percentage_error: 7.2186
# Epoch 336/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0605 - mean_absolute_percentage_error: 5.2260 - val_loss: 0.0886 - val_mean_absolute_percentage_error: 7.6301
# Epoch 337/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0489 - mean_absolute_percentage_error: 4.2605 - val_loss: 0.1175 - val_mean_absolute_percentage_error: 10.6902
# Epoch 338/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.5566 - val_loss: 0.0948 - val_mean_absolute_percentage_error: 8.5297
# Epoch 339/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0503 - mean_absolute_percentage_error: 4.3669 - val_loss: 0.0716 - val_mean_absolute_percentage_error: 6.1290
# Epoch 340/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0490 - mean_absolute_percentage_error: 4.2430 - val_loss: 0.0761 - val_mean_absolute_percentage_error: 6.4942
# Epoch 341/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0503 - mean_absolute_percentage_error: 4.5102 - val_loss: 0.0698 - val_mean_absolute_percentage_error: 5.8204
# Epoch 342/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0512 - mean_absolute_percentage_error: 4.4553 - val_loss: 0.0806 - val_mean_absolute_percentage_error: 6.7597
# Restoring model weights from the end of the best epoch.
# Epoch 00342: early stopping

# %% [markdown]
# **Performance plot of the model: RMSE and MAPE**
#
# **Deutsch:**
#
# **Erstellung des Diagramms der Modellleistung: RMSE und MAPE**

# %%
 # Plot training & validation loss values
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %%
# Plot tht training and validation's MAPE
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history.history["mean_absolute_percentage_error"])
plt.plot(history.history["val_mean_absolute_percentage_error"])
plt.title("Model Accuracy with MAPE")
plt.ylabel("Loss (%)")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# **Predict the train dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Trainingdatensatzes**

# %%
predictions_train = model.predict(X_train)
predictions_train
# Out:
# array([[0.19102746, 0.2551823 , 0.16591364, 0.03096957, 0.06432498,
#         0.08192274, 0.1640528 , 0.21085906, 0.039637  ],
#        [0.24529222, 0.33172297, 0.19971262, 0.05906068, 0.08767933,
#         0.11605516, 0.22489518, 0.2494865 , 0.07310934],
#        [0.3198477 , 0.43326628, 0.24750051, 0.09874474, 0.1210032 ,
#         0.16377321, 0.3062386 , 0.30433154, 0.12048192],
#        [0.3932979 , 0.5382077 , 0.2881238 , 0.13488358, 0.14840983,
#         0.20825443, 0.3851754 , 0.3549466 , 0.16248882],
#        [0.46306926, 0.6324302 , 0.33105826, 0.17508599, 0.18043345,
#         0.25658864, 0.46027464, 0.40611124, 0.20769982],
#        [0.5266928 , 0.7152399 , 0.3715768 , 0.21731818, 0.21398766,
#         0.30632347, 0.5284062 , 0.45515758, 0.25266433],
#        [0.5725517 , 0.759798  , 0.41619486, 0.26533607, 0.25633088,
#         0.35768113, 0.5805309 , 0.49926752, 0.3033898 ],
#        [0.6216533 , 0.8037847 , 0.46649116, 0.3169551 , 0.3035404 ,
#         0.41337952, 0.6365819 , 0.5465974 , 0.35688153],
#        [0.6797943 , 0.8492355 , 0.53399515, 0.3828589 , 0.3685968 ,
#         0.4824742 , 0.70390487, 0.606653  , 0.42719483],
#        [0.7453898 , 0.90920734, 0.596706  , 0.44832182, 0.43106627,
#         0.55295587, 0.7767117 , 0.66882247, 0.49570057],
#        [0.79786813, 0.94094   , 0.66448873, 0.51813495, 0.50125724,
#         0.6235192 , 0.83880144, 0.72772557, 0.56947005],
#        [0.8403851 , 0.96089405, 0.7235558 , 0.5812791 , 0.5649248 ,
#         0.68699515, 0.8893961 , 0.7788494 , 0.6346693 ],
#        [0.8700675 , 0.9559698 , 0.7866795 , 0.6444615 , 0.63374513,
#         0.7466161 , 0.92954826, 0.82478446, 0.70165515]], dtype=float32)

# %%
predictions_train.shape
# Out:
# (13, 9)

# %%
prediction_unscaled_train = scaler_prediction.inverse_transform(predictions_train)

predicted_train_df = pd.DataFrame(prediction_unscaled_train, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_train_df['year'] = [x for x in range(2003, 2016)]
predicted_train_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1483.441528  ...  2003
# 1                     1612.605347  ...  2004
# 2                     1790.066162  ...  2005
# 3                     1964.896240  ...  2006
# 4                     2130.969482  ...  2007
# 5                     2282.409668  ...  2008
# 6                     2391.565430  ...  2009
# 7                     2508.439453  ...  2010
# 8                     2646.829590  ...  2011
# 9                     2802.963623  ...  2012
# 10                    2927.875244  ...  2013
# 11                    3029.076172  ...  2014
# 12                    3099.727783  ...  2015
#
# [13 rows x 10 columns]

# %% [markdown]
# **Predict the test dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Testdatensatzes für die Verlustberechnung**

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[0.89034545, 0.9438347 , 0.8403861 , 0.69616276, 0.6934166 ,
#         0.79442453, 0.9595521 , 0.86176133, 0.7588254 ],
#        [0.9151615 , 0.93001604, 0.90488225, 0.7581687 , 0.7639936 ,
#         0.8520546 , 0.99659276, 0.9055243 , 0.82532084],
#        [0.94820964, 0.9205329 , 0.9770846 , 0.830814  , 0.84595287,
#         0.92100215, 1.0412185 , 0.95862263, 0.90065444],
#        [0.98621726, 0.902473  , 1.0610358 , 0.919256  , 0.9452682 ,
#         1.0045537 , 1.0894673 , 1.021915  , 0.98810947]], dtype=float32)

# %%
prediction_unscaled_test = scaler_prediction.inverse_transform(predictions)

predicted_test_df = pd.DataFrame(prediction_unscaled_test, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_test_df['year'] = [x for x in range(2016, 2020)]
predicted_test_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3147.994385            1905.714233  ...      77607.867188  2016
# 1                    3207.062988            1888.213379  ...      83529.843750  2017
# 2                    3285.725830            1876.203491  ...      90238.937500  2018
# 3                    3376.193604            1853.331421  ...      98027.554688  2019
#
# [4 rows x 10 columns]

# %% [markdown]
# **Calculate loss for testing data**
#
# **Deutsch:**
#
# **Verlustberechnung für Testdaten**

# %%
# create  the functions of mean absolute percentage error (MAPE) and root mean squared error (RMSE)
def mean_absolute_percentage_error(y_true, y_prediction): 
    y_true, y_prediction = np.array(y_true), np.array(y_prediction)
    return np.mean(np.abs((y_true - y_prediction) / y_true)) * 100

def root_mean_squared_error(y_true, y_prediction):
    mse = mean_squared_error(y_true, y_prediction)
    rmse = np.sqrt(mse)
    return rmse

# %%
# create a function of generating all the relevant errors
def calculate_performance(y_true, y_prediction):
    MSE = mean_squared_error(y_true, y_prediction)
    MAE = mean_absolute_error(y_true, y_prediction)
    MAPE = mean_absolute_percentage_error(y_true, y_prediction)
    RMSE = root_mean_squared_error(y_true, y_prediction)
    return round(MSE, 3), round(MAE, 3), round(MAPE, 3), round(RMSE, 3)

# %%
actual_arr=input_df.iloc[16:20,:].to_numpy()

# Get the predicted values for all 8 features
prediction_unscaled2 = scaler_prediction.inverse_transform(predictions)

MSE, MAE, MAPE, RMSE = calculate_performance(actual_arr, prediction_unscaled2)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 360947.029
# Mean Absolute Error (MAE): 198.781
# Mean Absolute Percentage Error (MAPE): 2.73 %
# Root Mean Squared Error (RMSE): 600.789

# %%
prediction_unscaled2
# Out:
# array([[ 3147.9944 ,  1905.7142 ,   615.7459 ,   193.01982,   366.4443 ,
#           635.4685 ,  3112.8323 ,  1381.7168 , 77607.87   ],
#        [ 3207.063  ,  1888.2134 ,   644.65656,   208.10493,   397.85135,
#           674.7268 ,  3189.379  ,  1387.5206 , 83529.84   ],
#        [ 3285.7258 ,  1876.2035 ,   677.02155,   225.77846,   434.32352,
#           721.6947 ,  3281.6003 ,  1394.5626 , 90238.94   ],
#        [ 3376.1936 ,  1853.3314 ,   714.6531 ,   247.29506,   478.5192 ,
#           778.611  ,  3381.3088 ,  1402.9563 , 98027.555  ]],
#       dtype=float32)

# %% [markdown]
# **Calculate loss of total energy consumption for prediction against actual values** (total energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Gesamtenergieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tec=predicted_test_df.iloc[:,0].to_numpy()
actual_tec=input_df.iloc[16:20,0].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tec, predicted_tec)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 1242.046
# Mean Absolute Error (MAE): 31.095
# Mean Absolute Percentage Error (MAPE): 0.97 %
# Root Mean Squared  Error (RMSE): 35.243

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tec)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tec)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtenergieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of coal consumption for prediction against actual values** (Coal consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Kohleverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_cc=predicted_test_df.iloc[:,1].to_numpy()
actual_cc=input_df.iloc[16:20,1].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_cc, predicted_cc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 3080.31
# Mean Absolute Error (MAE): 40.475
# Mean Absolute Percentage Error (MAPE): 2.09 %
# Root Mean Squared  Error (RMSE): 55.501

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_cc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_cc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Kohleverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of oil consumption for prediction against actual values** (Oil consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdölverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_oc=predicted_test_df.iloc[:,2].to_numpy()
actual_oc=input_df.iloc[16:20,2].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_oc, predicted_oc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 353.47
# Mean Absolute Error (MAE): 17.601
# Mean Absolute Percentage Error (MAPE): 2.69 %
# Root Mean Squared  Error (RMSE): 18.801

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_oc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_oc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdölverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of natural gas consumption for prediction against actual values** (Natural gas consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdgasverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gc=predicted_test_df.iloc[:,3].to_numpy()
actual_gc=input_df.iloc[16:20,3].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gc, predicted_gc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 224.633
# Mean Absolute Error (MAE): 12.838
# Mean Absolute Percentage Error (MAPE): 5.45 %
# Root Mean Squared  Error (RMSE): 14.988

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdgasverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of non fossil energy consumption for prediction against actual values** (non fossil energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des nichtfossilen Energieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_nfc=predicted_test_df.iloc[:,4].to_numpy()
actual_nfc=input_df.iloc[16:20,4].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_nfc, predicted_nfc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 383.757
# Mean Absolute Error (MAE): 18.817
# Mean Absolute Percentage Error (MAPE): 4.21 %
# Root Mean Squared  Error (RMSE): 19.59

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_nfc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_nfc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("nichtfossile Energieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of energy imports for prediction against actual values** (energy imports)
#
# **Deutsch:**
#
# **Verlustberechnung der Energieeinfuhr für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_imp=predicted_test_df.iloc[:,5].to_numpy()
actual_imp=input_df.iloc[16:20,5].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_imp, predicted_imp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 893.207
# Mean Absolute Error (MAE): 21.572
# Mean Absolute Percentage Error (MAPE): 2.9 %
# Root Mean Squared  Error (RMSE): 29.887

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_imp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_imp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Energieeinfuhr (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of tpes for prediction against actual values** (total primary energy supply)
#
# **Deutsch:**
#
# **Verlustberechnung der Gesamtprimärenergieversorgung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tpes=predicted_test_df.iloc[:,6].to_numpy()
actual_tpes=input_df.iloc[16:20,6].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tpes, predicted_tpes)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 19272.675
# Mean Absolute Error (MAE): 134.13
# Mean Absolute Percentage Error (MAPE): 4.32 %
# Root Mean Squared  Error (RMSE): 138.826

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tpes)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tpes)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtprimärenergieversorgung (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of population for prediction against actual values** (population)
#
# **Deutsch:**
#
# **Verlustberechnung der Bevölkerung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_pop=predicted_test_df.iloc[:,7].to_numpy()
actual_pop=input_df.iloc[16:20,7].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_pop, predicted_pop)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 4.163
# Mean Absolute Error (MAE): 1.819
# Mean Absolute Percentage Error (MAPE): 0.13 %
# Root Mean Squared  Error (RMSE): 2.04

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_pop)
ax1.plot(predicted_test_df.iloc[:,-1], actual_pop)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bevölkerung (Millionen)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of GDP for prediction against actual values** (GDP)
#
# **Deutsch:**
#
# **Verlustberechnung des Bruttoinlandsprodukts für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gdp=predicted_test_df.iloc[:,8].to_numpy()
actual_gdp=input_df.iloc[16:20,8].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gdp, predicted_gdp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 3223068.998
# Mean Absolute Error (MAE): 1510.685
# Mean Absolute Percentage Error (MAPE): 1.82 %
# Root Mean Squared  Error (RMSE): 1795.291

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gdp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gdp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bruttoinlandsprodukt (Milliarden Yuan)", fontsize=18)

plt.show()

# %% [markdown]
# **Make future predictions**
#
# Predict the value of the next six years
#
# **Deutsch:**
#
# **Zukunftsprognosen erstellen**
#
# Vorhersage des Wertes für die nächsten sechs Jahre

# %%
# extract last three rows from dataset
temp_input=final_df[-3:].tolist()

# %%
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999]]

# %%
last_3_years = np.array(temp_input)
last_3_years.shape
# Out:
# (3, 9)

# %%
predicted_consumption_output =[]
for i in range(6):
  # Get the last 3 year consumption values and scale the data to be values between 0 and 1
  last_3_years = np.array(temp_input[-3:])
  last_3_years_scaled = last_3_years.reshape(1, 3, -1)
  # Create an empty list and Append past 3 years
  X_test_new = []
  X_test_new.append(last_3_years_scaled)
  # Convert the X_test data set to a numpy array and reshape the data
  prediction_consumption_scaled = model.predict(X_test_new)
  temp_input.extend(prediction_consumption_scaled.tolist())
  predicted_consumption_output.extend(prediction_consumption_scaled.tolist())

# %%
# add new predicted values into temp_input list
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999],
#  [1.0127114057540894,
#   0.8744279146194458,
#   1.1327571868896484,
#   0.9950013756752014,
#   1.0333528518676758,
#   1.0733633041381836,
#   1.1249210834503174,
#   1.0740439891815186,
#   1.0649662017822266],
#  [1.0358717441558838,
#   0.8528821468353271,
#   1.1973659992218018,
#   1.0558072328567505,
#   1.109182596206665,
#   1.1289886236190796,
#   1.1568642854690552,
#   1.1181285381317139,
#   1.1300699710845947],
#  [1.0547263622283936,
#   0.8371785879135132,
#   1.2504560947418213,
#   1.1041672229766846,
#   1.1714568138122559,
#   1.1717050075531006,
#   1.1845734119415283,
#   1.1529834270477295,
#   1.1834442615509033],
#  [1.0715152025222778,
#   0.8242321014404297,
#   1.2963463068008423,
#   1.1453845500946045,
#   1.225432276725769,
#   1.2076120376586914,
#   1.2091717720031738,
#   1.1824610233306885,
#   1.2292280197143555],
#  [1.0836182832717896,
#   0.8059000372886658,
#   1.3356603384017944,
#   1.1836705207824707,
#   1.2731473445892334,
#   1.2409995794296265,
#   1.2269142866134644,
#   1.2083332538604736,
#   1.269071340560913],
#  [1.0930652618408203,
#   0.789833128452301,
#   1.3677988052368164,
#   1.2151774168014526,
#   1.3124165534973145,
#   1.268332600593567,
#   1.240909457206726,
#   1.2294656038284302,
#   1.3015801906585693]]

# %%
# rename temp_input with new inputs into prediction_arr
prediction_arr = np.array(temp_input)

# %%
prediction_arr
# Out:
# array([[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#         0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#        [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#         1.        , 1.        , 0.96478661, 0.91962137],
#        [1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.        ],
#        [1.01271141, 0.87442791, 1.13275719, 0.99500138, 1.03335285,
#         1.0733633 , 1.12492108, 1.07404399, 1.0649662 ],
#        [1.03587174, 0.85288215, 1.197366  , 1.05580723, 1.1091826 ,
#         1.12898862, 1.15686429, 1.11812854, 1.13006997],
#        [1.05472636, 0.83717859, 1.25045609, 1.10416722, 1.17145681,
#         1.17170501, 1.18457341, 1.15298343, 1.18344426],
#        [1.0715152 , 0.8242321 , 1.29634631, 1.14538455, 1.22543228,
#         1.20761204, 1.20917177, 1.18246102, 1.22922802],
#        [1.08361828, 0.80590004, 1.33566034, 1.18367052, 1.27314734,
#         1.24099958, 1.22691429, 1.20833325, 1.26907134],
#        [1.09306526, 0.78983313, 1.36779881, 1.21517742, 1.31241655,
#         1.2683326 , 1.24090946, 1.2294656 , 1.30158019]])

# %%
# transform the predicted value back to original form
prediction_unscaled = scaler_prediction.inverse_transform(prediction_arr)

# %%
predicted_consumption = prediction_unscaled.ravel()

# %%
predicted_consumption
# Out:
# array([  3190.789     ,   1899.7842638 ,    632.53951563,    209.41927228,
#           414.00076415,    700.273     ,   3064.9       ,   1390.08      ,
#         83203.59      ,   3303.475     ,   1912.9999275 ,    657.07314703,
#           245.92728745,    457.90272932,    775.509     ,   3196.42      ,
#          1395.38      ,  91928.11      ,   3409.        ,   1956.94088451,
#           687.29351129,    266.93887425,    502.87504711,    775.509     ,
#          3196.42      ,   1400.05      ,  99086.51      ,   3439.25634897,
#          1817.813719  ,    746.80248173,    265.72278392,    517.71718763,
#           825.48496314,   3454.575665  ,   1409.86971385, 104872.30248142,
#          3494.38379077,   1790.52702127,    775.76365509,    280.515937  ,
#           551.46169994,    863.37759827,   3520.58788914,   1415.71620673,
#        110670.34651984,   3539.26253315,   1770.63920525,    799.56151492,
#           292.28119729,    579.1739535 ,    892.47651161,   3577.85018445,
#          1420.3386621 , 115423.78076733,   3579.22420383,   1754.24309134,
#           820.13199654,    302.3087548 ,    603.19323101,    916.9368114 ,
#          3628.68392543,   1424.24798091, 119501.21359373,   3608.03258599,
#          1731.02639754,    837.75467746,    311.62315725,    624.42660994,
#           939.6808055 ,   3665.349719  ,   1427.67915613, 123049.59998334,
#          3630.51877563,   1710.67841601,    852.16088113,    319.28831251,
#           641.90155087,    958.30038752,   3694.27143879,   1430.48172838,
#        125944.78940977])

# %%
# reshape into proper format
predicted_consumption= predicted_consumption.reshape(-1,9)

# %%
predicted_consumption.shape
# Out:
# (9, 9)

# %% [markdown]
# **Table of actual values from 2017 to 2019 & prediction values from 2020 to 2025**
#
# **Deutsch:**
#
# **Tabelle mit realen Werten zwischen 2017 und 2019 sowie Vorhersagewerten zwischen 2020 und 2025**

# %%
# add column names and convert into dataframe for preparation of visualisation
prediction_df=pd.DataFrame(predicted_consumption ,columns=['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
prediction_df
# Out:
#    total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                    3190.789000  ...      83203.590000
# 1                    3303.475000  ...      91928.110000
# 2                    3409.000000  ...      99086.510000
# 3                    3439.256349  ...     104872.302481
# 4                    3494.383791  ...     110670.346520
# 5                    3539.262533  ...     115423.780767
# 6                    3579.224204  ...     119501.213594
# 7                    3608.032586  ...     123049.599983
# 8                    3630.518776  ...     125944.789410
#
# [9 rows x 9 columns]

# %% [markdown]
# **Preparation of predicted values for visualisation**
#
# **Deutsch:**
#
# **Aufbereitung der Vorhersagewerte für die Visualisierung**

# %%
# Generate list of sequence of years for predictions
year_range = range(2017,2026)

yearlist_predict = []

for y in year_range:
  yearlist_predict.append(y)

# %%
# Generate list of sequence of years for predictions
year_range = range(2000,2020)

yearlist_main = []

for y in year_range:
  yearlist_main.append(y)

# %%
# preparation for combination it to original dataset copies
prediction_df['year']=yearlist_predict
prediction_df.head()
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3190.789000            1899.784264  ...      83203.590000  2017
# 1                    3303.475000            1912.999927  ...      91928.110000  2018
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3439.256349            1817.813719  ...     104872.302481  2020
# 4                    3494.383791            1790.527021  ...     110670.346520  2021
#
# [5 rows x 10 columns]

# %%
# make a copy from input_df and add a year column
energy_consumption_df = input_df.loc[:, :]
energy_consumption_df['year']=yearlist_main
energy_consumption_df.tail()
# Out:
#     total_energy_consumption_mtoe  ...  year
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [5 rows x 10 columns]

# %%
target_df=prediction_df.iloc[5:,:]
target_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 5                    3539.262533            1770.639205  ...     115423.780767  2022
# 6                    3579.224204            1754.243091  ...     119501.213594  2023
# 7                    3608.032586            1731.026398  ...     123049.599983  2024
# 8                    3630.518776            1710.678416  ...     125944.789410  2025
#
# [4 rows x 10 columns]

# %%
# this is the prediction dataframe between 2019 and 2025
visual_df=prediction_df.iloc[2:,:]
visual_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3439.256349            1817.813719  ...     104872.302481  2020
# 4                    3494.383791            1790.527021  ...     110670.346520  2021
# 5                    3539.262533            1770.639205  ...     115423.780767  2022
# 6                    3579.224204            1754.243091  ...     119501.213594  2023
# 7                    3608.032586            1731.026398  ...     123049.599983  2024
# 8                    3630.518776            1710.678416  ...     125944.789410  2025
#
# [7 rows x 10 columns]

# %% [markdown]
# **Combination of original dataset and prediction table**
#
# **Deutsch:**
#
# **Zusammensetzung des originalen Datensatz und der Vorhersagetabelle**

# %%
# append the predicted dataframe to the original dataset copies
combined_energy_consumption_df= pd.concat([energy_consumption_df, prediction_df.iloc[3:,:]], axis=0)
combined_energy_consumption_df.reset_index(drop=True, inplace=True)
combined_energy_consumption_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1028.748000  ...  2000
# 1                     1088.829000  ...  2001
# 2                     1187.039000  ...  2002
# 3                     1379.581000  ...  2003
# 4                     1611.967000  ...  2004
# 5                     1829.583000  ...  2005
# 6                     2005.269000  ...  2006
# 7                     2180.094000  ...  2007
# 8                     2244.277000  ...  2008
# 9                     2352.882000  ...  2009
# 10                    2524.536000  ...  2010
# 11                    2709.301000  ...  2011
# 12                    2814.966000  ...  2012
# 13                    2918.391000  ...  2013
# 14                    2998.338000  ...  2014
# 15                    3038.791000  ...  2015
# 16                    3090.444000  ...  2016
# 17                    3190.789000  ...  2017
# 18                    3303.475000  ...  2018
# 19                    3409.000000  ...  2019
# 20                    3439.256349  ...  2020
# 21                    3494.383791  ...  2021
# 22                    3539.262533  ...  2022
# 23                    3579.224204  ...  2023
# 24                    3608.032586  ...  2024
# 25                    3630.518776  ...  2025
#
# [26 rows x 10 columns]

# %% [markdown]
# **Visualise the prediction**
#
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Gesamtenergieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['total_energy_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Gesamtenergieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,0], color='g', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,0], color='y', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Trainingdaten)')
#plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['Energy_consumption'], color='orange', label='Training predictions')
#plt.plot(input_df.iloc[:,-1], input_df.iloc[:, 0], color='b', label='Actual Energy Consumption')
plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,0], color='b', marker='x', label='Ist-Gesamtenergieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')
#plt.axvline(x = min(target_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Gesamtenergieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Kohleverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['coal_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Kohleverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,1], color='g', marker='x', label='Vorhersage - Kohleverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,1], color='y', marker='x', label='Vorhersage - Kohleverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,1], color='b', marker='x', label='Ist-Kohleverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Kohleverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Kohleverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdölverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['oil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdölverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,2], color='g', marker='x', label='Vorhersage - Erdölverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,2], color='y', marker='x', label='Vorhersage - Erdölverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,2], color='b', marker='x', label='Ist-Erdölverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdölverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdölverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdgasverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['gas_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdgasverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,3], color='g', marker='x', label='Vorhersage - Erdgasverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,3], color='y', marker='x', label='Vorhersage - Erdgasverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,3], color='b', marker='x', label='Ist-Erdgasverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdgasverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdgasverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Nichtfossiler Energieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['non_fossil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger nichtfossile Energieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,4], color='g', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,4], color='y', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,4], color='b', marker='x', label='Ist-Nichtfossiler Energieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Nichtfossile Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Nichtfossiler Energieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
