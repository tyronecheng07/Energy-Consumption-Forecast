# %% [markdown]
# <a href="https://colab.research.google.com/github/tyronecheng07/Energy-Consumption-Forecast/blob/main/MLP_model_two_layer_energy_consumption_forecast_china.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Total Energy Consumption Forecast- MLP-Model with 2 layers Multivariate**
#
# ##**Goal and Description**
# A good prediction of the energy data allows stateholders, researcher and politician make better decision and to be well informed with the future possible scenarios. The main focus of this study is to forecast the total energy consumption of China for the next 6 years. Using a set of different variables as inputs and the energy consumption as output with a period of 20 years from 2000 to 2019 to perform the timeseries forecasting.
#
# **Deutsch:**
# #**Vorhersage des Gesamtenergieverbrauchs Chinas- MLP-Modell (2 Schichten) Multivariate**
#
# ##**Zielsetzung und Beschreibung**
#
# Eine gute Vorhersage der Energiedaten ermöglicht es Entscheidungsträgern, Forschern und auch Politikern, bessere Entscheidungen zu treffen und über die möglichen zukünftigen Entwicklungen gut informiert zu sein. Das Schwerpunktthema dieser Studie ist die Vorhersage des Gesamtenergieverbrauchs von China für die nächsten 6 Jahre. Die Zeitreihenprognose wird mit einer Reihe von verschiedenen Variablen als Eingaben und dem Energieverbrauch als Ausgabe mit einem Zeitraum von 20 Jahren von 2000 bis 2019 durchgeführt.

# %% [markdown]
# Prepared by Kuan Yew Cheng, 2021
#
# Raw data collected from China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# and from the database: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics and https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
#
# **Deutsch:**
#
# Vorbereitet von Kuan Yew Cheng, 2021
#
# Rohdaten entnommen aus China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# auch von der Datenbank: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics und https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html

# %% [markdown]
# **Import the libraries**
#
# **Deutsch:**
#
# **Importieren der Pythonbibliotheken**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import TimeDistributed
from tensorflow.keras.layers import Dropout
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.layers.core import Activation
import tensorflow as tf
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras import backend
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import LeakyReLU
from keras.backend import set_epsilon
from scipy.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# **Convert data from Excel worksheet to CSV format**
#
# **Deutsch:**
#
# **Konvertieren von Daten aus einem Excel-Arbeitsblatt in das CSV-Format**

# %%
#energy_df = pd.read_excel('Energy_Dataset_China.xlsx', sheet_name=None)
#energy_df['for_processing3'].to_csv('final_energy_data_3.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
energy_df = pd.read_excel('/content/drive/MyDrive/Energy China/Dataset for Bachelorarbeit/Energy_Dataset_China.xlsx', sheet_name=None)
energy_df['for_processing4'].to_csv('final_energy_data_4.csv')

# %% [markdown]
# **Reading and preprocessing the csv file**
#
# **Deutsch:**
#
# **Lesen und Vorverarbeiten der CSV-Datei**

# %%
energy_df = pd.read_csv('final_energy_data_4.csv', index_col=[0])

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Dataset of total energy Consumption(Mtoe) and other variables of China**
#
# **Deutsch:**
#
# **Datensatz des Gesamtenergieverbrauchs (Mtoe) und anderer Variablen von China**

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           20 non-null     int64
#  1   total_energy_consumption_mtoe  20 non-null     float64
#  2   coal_consumption_mtoe          20 non-null     float64
#  3   oil_consumption_mtoe           20 non-null     float64
#  4   gas_consumption_mtoe           20 non-null     float64
#  5   non_fossil_consumption_mtoe    20 non-null     float64
#  6   imports_mtoe                   20 non-null     float64
#  7   tpes_mtoe                      20 non-null     float64
#  8   population_million             20 non-null     float64
#  9   gdp_billion_yuan               20 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 1.7 KB

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualise data of years against each column**
#
# **Deutsch:**
#
# **Visualisierung der Jahresdaten gegenüber jeder Spalte**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")
plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.show()

# %% [markdown]
# Comment: Some of the plots showed abnormal drops since there were missing values in the dataset which displayed as 0.
#
# **Deutsch:**
#
# Kommentar: Einige der Grafiken zeigten abnormale Absenkungen, da es fehlende Werte im Datensatz gab, die als 0 angezeigt wurden.

# %% [markdown]
# **Arrange the columns**
#
# Shifting the ***year*** column to the last column and adding a new column ***prediction*** into the energy_df
#
# **Deutsch:**
#
# **Anordnen der Spalten**
#
# Verschieben der **Jahres**-Spalte in die letzte Spalte und Hinzufügung einer neuen **Vorhersage**-spalte in der energy_df

# %%
features = ['total_energy_consumption_mtoe', 'coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe', 'imports_mtoe','tpes_mtoe', 'population_million', 'gdp_billion_yuan', 'year']
energy_df = energy_df[features]
energy_df_ext = energy_df.copy()
energy_df_ext['prediction'] = energy_df_ext['total_energy_consumption_mtoe']
energy_df_ext.tail()
# Out:
#     total_energy_consumption_mtoe  coal_consumption_mtoe  ...  year  prediction
# 15                       3038.791            1920.657806  ...  2015    3038.791
# 16                       3090.444            1895.791743  ...  2016    3090.444
# 17                       3190.789            1899.784264  ...  2017    3190.789
# 18                       3303.475            1912.999927  ...  2018    3303.475
# 19                       3409.000            1956.940885  ...  2019    3409.000
#
# [5 rows x 11 columns]

# %% [markdown]
# **Check zero values**
#
# **Deutsch:**
#
# **0-werte überprüfen**

# %%
energy_df.isin([0]).sum()
# Out:
# total_energy_consumption_mtoe    0
# coal_consumption_mtoe            0
# oil_consumption_mtoe             0
# gas_consumption_mtoe             0
# non_fossil_consumption_mtoe      0
# imports_mtoe                     1
# tpes_mtoe                        1
# population_million               0
# gdp_billion_yuan                 0
# year                             0
# dtype: int64

# %% [markdown]
# **Replace the zero values with null**
#
# **Deutsch:**
#
# **Ersetzen Sie die 0-Werte durch Nullwerte**

# %%
cols = ["imports_mtoe","tpes_mtoe"]
energy_df[cols] = energy_df[cols].replace(['0', 0], np.nan)

# %% [markdown]
# **Interpolate the missing values by using linear interpolation**
#
# **Deutsch:**
#
# **Interpolierung der fehlenden Werte mit Hilfe der linearen Interpolation**

# %%
energy_df.interpolate(method='linear', limit_direction ='both', inplace=True)

energy_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                        1028.748  ...  2000
# 1                        1088.829  ...  2001
# 2                        1187.039  ...  2002
# 3                        1379.581  ...  2003
# 4                        1611.967  ...  2004
# 5                        1829.583  ...  2005
# 6                        2005.269  ...  2006
# 7                        2180.094  ...  2007
# 8                        2244.277  ...  2008
# 9                        2352.882  ...  2009
# 10                       2524.536  ...  2010
# 11                       2709.301  ...  2011
# 12                       2814.966  ...  2012
# 13                       2918.391  ...  2013
# 14                       2998.338  ...  2014
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualize data of years against each column after interpolation**
#
# **Deutsch:**
#
# **Visualisierung der Daten von Jahren gegenüber jeder Spalte nach der Interpolation**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']

plt.figure()
plt.title("total_energy_consumption_mtoe 2000 to 2019")
plt.plot(x, y1, 'g-')
plt.xlabel("Years")
plt.ylabel("Energy comsumption mtoe")

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.show()

# %% [markdown]
# **Check Correlations**
#
# **Deutsch:**
#
# **Korrelationen prüfen**

# %%
pearsoncorr = energy_df.corr(method='pearson')
pearsoncorr
# Out:
#                                total_energy_consumption_mtoe  ...      year
# total_energy_consumption_mtoe                       1.000000  ...  0.987076
# coal_consumption_mtoe                               0.967508  ...  0.915922
# oil_consumption_mtoe                                0.982699  ...  0.997376
# gas_consumption_mtoe                                0.930097  ...  0.971747
# non_fossil_consumption_mtoe                         0.919665  ...  0.968318
# imports_mtoe                                        0.957505  ...  0.986707
# tpes_mtoe                                           0.997467  ...  0.981646
# population_million                                  0.989195  ...  0.999361
# gdp_billion_yuan                                    0.945927  ...  0.982514
# year                                                0.987076  ...  1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# **Correlation Matrix**
#
# **Deutsch:**
#
# **Korrelations-Matrix**

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# **Calculation of P-value**
#
# **Deutsch:**
#
# **Berechnung vom P-Wert**

# %%
def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 12)
    return pvalues

# %%
calculate_pvalues(energy_df)
# Out:
#                               total_energy_consumption_mtoe  ...        year
# total_energy_consumption_mtoe                             0  ...           0
# coal_consumption_mtoe                                 3e-12  ...  1.4652e-08
# oil_consumption_mtoe                                      0  ...           0
# gas_consumption_mtoe                              2.932e-09  ...       1e-12
# non_fossil_consumption_mtoe                       9.861e-09  ...       3e-12
# imports_mtoe                                        3.7e-11  ...           0
# tpes_mtoe                                                 0  ...           0
# population_million                                        0  ...           0
# gdp_billion_yuan                                   3.08e-10  ...           0
# year                                                      0  ...           0
#
# [10 rows x 10 columns]

# %% [markdown]
# All the values are with a  p-value < 0.01, the variables are statistically significant and the null hypothese can be rejected
#
# **Deutsch:**
#
# Alle Werte wurden mit dem P-Wert < 0,01 berechnet. Dieses Variablen waren statistisch signifikant und die Nullhypothese lässt sich ablehnen.

# %% [markdown]
# **Create a new DataFrame without exports_mtoe and year**
#
# **Deutsch:**
#
# **Erstellung eines neuen DataFrames ohne exports_mtoe und Jahr**

# %%
input_df = energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']]

# %%
input_df
# Out:
#     total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                        1028.748  ...          10028.01
# 1                        1088.829  ...          11086.31
# 2                        1187.039  ...          12171.74
# 3                        1379.581  ...          13742.20
# 4                        1611.967  ...          16184.02
# 5                        1829.583  ...          18731.89
# 6                        2005.269  ...          21943.85
# 7                        2180.094  ...          27009.23
# 8                        2244.277  ...          31924.46
# 9                        2352.882  ...          34851.77
# 10                       2524.536  ...          41211.93
# 11                       2709.301  ...          48794.02
# 12                       2814.966  ...          53858.00
# 13                       2918.391  ...          59296.32
# 14                       2998.338  ...          64356.31
# 15                       3038.791  ...          68885.82
# 16                       3090.444  ...          74639.51
# 17                       3190.789  ...          83203.59
# 18                       3303.475  ...          91928.11
# 19                       3409.000  ...          99086.51
#
# [20 rows x 9 columns]

# %% [markdown]
# **Display our feature column: total_energy_consumption_mtoe**
#
# **Deutsch:**
#
# **Feature-Spalte anzeigen: total_energy_consumption_mtoe**

# %%
input_df.iloc[:,0]
# Out:
# 0     1028.748
# 1     1088.829
# 2     1187.039
# 3     1379.581
# 4     1611.967
# 5     1829.583
# 6     2005.269
# 7     2180.094
# 8     2244.277
# 9     2352.882
# 10    2524.536
# 11    2709.301
# 12    2814.966
# 13    2918.391
# 14    2998.338
# 15    3038.791
# 16    3090.444
# 17    3190.789
# 18    3303.475
# 19    3409.000
# Name: total_energy_consumption_mtoe, dtype: float64

# %% [markdown]
# **Basic Statistics**
#
# **Deutsch:**
#
# **Basis-Statistik**

# %%
input_df.describe()
# Out:
#        total_energy_consumption_mtoe  ...  gdp_billion_yuan
# count                      20.000000  ...         20.000000
# mean                     2345.315000  ...      44146.680000
# std                       777.438682  ...      28823.738016
# min                      1028.748000  ...      10028.010000
# 25%                      1775.179000  ...      18094.922500
# 50%                      2438.709000  ...      38031.850000
# 75%                      3008.451250  ...      65488.687500
# max                      3409.000000  ...      99086.510000
#
# [8 rows x 9 columns]

# %% [markdown]
# **Feature Scaling: Min Max Scaling**
#
# **Deutsch:**
#
# **Feature-Skalierung: Min Max Scaling**

# %%
# Calculate the number of rows in the data
nrows = input_df.shape[0]
input_df_unscaled = np.array(input_df)
input_df_unscaled = np.reshape(input_df_unscaled, (nrows, -1))
print(input_df_unscaled.shape)

#Feature Scaling
# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
final_df = scaler.fit_transform(input_df_unscaled)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_prediction = MinMaxScaler()
#consumption_df = pd.DataFrame(energy_df_ext['total_energy_consumption_mtoe'])
consumption_df = pd.DataFrame(energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']])
consumption_df_scaled = scaler_prediction.fit_transform(consumption_df)
# Out:
# (20, 9)

# %%
final_df[:,0]
# Out:
# array([0.        , 0.02524145, 0.06650178, 0.14739322, 0.24502406,
#        0.33644967, 0.4102595 , 0.48370761, 0.5106724 , 0.55629992,
#        0.62841581, 0.70603995, 0.75043231, 0.79388359, 0.82747121,
#        0.84446647, 0.86616711, 0.90832441, 0.95566646, 1.        ])

# %% [markdown]
# **Convert into a supervised learning problem**
#
# **Deutsch:**
#
# **In ein Format* des überwachten Lernens umwandeln**

# %%
###
*    Dieser Teil des Codes geändert aus dem ipynb-Dokument von JonJae:
*    Titel: FeedInMngmt_LSTM_NN
*    Autor: JonJae
*    Datum: 2020
*    Verfügbarkeit: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb
*   (Quelle: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb abgerufen am Februar 2021)
###

#Global Settings
sequence_length = 3   # Number of past years that we want to predict the future values
n_out = 1            # Number of years that we wamt to forecast into the future

# Split the training data into x_train and y_train data sets
# Get the number of rows to train the model on 80% of the data 
train_data_len = math.ceil(final_df.shape[0] * 0.8) #16 train data point

# Create the training data
train_data = final_df[0:train_data_len, :]
X_train, y_train = [], []
in_start = 0
# step over the entire history five time step at a time
for _ in range(train_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(train_data):
		X_train.append(train_data[in_start:in_end, :])
		y_train.append(train_data[in_end:out_end, :])
	# move along one batch
	in_start += 1
    
# Convert the X_train and y_train into numpy arrays
X_train, y_train = np.array(X_train), np.array(y_train)

# Create the test data
test_data = final_df[train_data_len - sequence_length:, :]

# Seperate the test data into X_test and y_test
X_test, y_test = [], []
test_data_len = test_data.shape[0]
in_start = 0
# step over the entire history five time step at a time
for _ in range(test_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(test_data):
		X_test.append(test_data[in_start:in_end, :])
		y_test.append(test_data[in_end:out_end, :])
	# move along one batch
	in_start += 1

X_test, y_test = np.array(X_test), np.array(y_test)

# Convert the X_train and y_train to numpy arrays
X_test = np.array(X_test); y_test = np.array(y_test)
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13, 3, 9) (13, 1, 9)
# (4, 3, 9) (4, 1, 9)

# %% [markdown]
# **Take a look on test and train data after transformation**
#
# **Deutsch:**
#
# **Schauen wir nun, wie die Training- und Testdaten nach der Transformation aussiehen.**

# %%
X_train
# Out:
# array([[[0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.00879609, 0.        , 0.        , 0.        ],
#         [0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103]],
#
#        [[0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]]])

# %%
y_train
# Out:
# array([[[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]]])

# %%
X_test
# Out:
# array([[[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#         [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]]])

# %%
X_test
# Out:
# array([[[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#         [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]]])

# %% [markdown]
# **Let's see how y_test looks like**
#
# **Deutsch:**
#
# **Schauen wir uns an, wie y_test aussieht**

# %%
y_test
# Out:
# array([[[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]],
#
#        [[1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#          1.        , 1.        , 1.        , 1.        ]]])

# %% [markdown]
# **Change the shape of the training dataset to suit the MLP Model's input dimension**
#
# **Deutsch:**
#
# **Änderung der Form des Trainingsdatensatzes zur Anpassung an die Eingangsdimension des MLP-Modells**

# %%
# flatten input
n_input = X_train.shape[1] * X_train.shape[2]
X_train1 = X_train.reshape((X_train.shape[0], n_input))
# flatten output
n_output = y_train.shape[1] * y_train.shape[2]
y_train1 = y_train.reshape((y_train.shape[0], n_output))

# %%
# flatten input
n_input1 = X_test.shape[1] * X_test.shape[2]
X_test1 = X_test.reshape((X_test.shape[0], n_input1))
# flatten output
n_output1 = y_test.shape[1] * y_test.shape[2]
y_test1 = y_test.reshape((y_test.shape[0], n_output1))

# %% [markdown]
# **Build the MLP-Model**
#
# **Deutsch:**
#
# **Aufbau des MLP-Modells**

# %%
# set the denominator of mape function permanently as 1 to ensure mathematical operation error free  
set_epsilon(1)

# define model
model_2=Sequential()

# Custom fuction of root mean square error
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# Initializing the Neural Network based on multilayered-perceptron 
# Adding 1st dense layer
model_2.add(Dense(units=70, input_dim=n_input, activation='tanh')) #input_shape=(X_train1.shape[1], X_train1.shape[2])
model_2.add(Dropout(0.2))

# Adding a hidden dense layer
model_2.add(Dense(units=50, activation='relu'))

# Adding Dropout
model_2.add(Dropout(0.2))

#model_2.add(Dense(30))

# Output layer
model_2.add(Dense(n_output))

# Compiling the Neural Network
model_2.compile(optimizer=Adam(learning_rate=0.0002), loss=rmse, metrics='mean_absolute_percentage_error')

# %%
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 70)                1960
# _________________________________________________________________
# dropout (Dropout)            (None, 70)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                3550
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 459
# =================================================================
# Total params: 5,969
# Trainable params: 5,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Start training with max 2000 epochs**
#
# **Deutsch:**
#
# **Training mit max. 2000 Epochen**

# %%
epochs = 2000
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=60, restore_best_weights=True)
history_2 = model_2.fit(X_train1, y_train1, validation_data=(X_test1, y_test1), batch_size=2, 
                    epochs=epochs, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/2000
# 7/7 [==============================] - 1s 72ms/step - loss: 0.4309 - mean_absolute_percentage_error: 35.5498 - val_loss: 0.9791 - val_mean_absolute_percentage_error: 91.1063
# Epoch 2/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3945 - mean_absolute_percentage_error: 32.7938 - val_loss: 0.9221 - val_mean_absolute_percentage_error: 85.7990
# Epoch 3/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3673 - mean_absolute_percentage_error: 29.5668 - val_loss: 0.8697 - val_mean_absolute_percentage_error: 80.7733
# Epoch 4/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3303 - mean_absolute_percentage_error: 26.6655 - val_loss: 0.8201 - val_mean_absolute_percentage_error: 75.8480
# Epoch 5/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3390 - mean_absolute_percentage_error: 27.0631 - val_loss: 0.7711 - val_mean_absolute_percentage_error: 70.8282
# Epoch 6/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3194 - mean_absolute_percentage_error: 24.7774 - val_loss: 0.7264 - val_mean_absolute_percentage_error: 66.2448
# Epoch 7/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2993 - mean_absolute_percentage_error: 23.9271 - val_loss: 0.6841 - val_mean_absolute_percentage_error: 61.7098
# Epoch 8/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2705 - mean_absolute_percentage_error: 21.0448 - val_loss: 0.6457 - val_mean_absolute_percentage_error: 57.6027
# Epoch 9/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2633 - mean_absolute_percentage_error: 20.6551 - val_loss: 0.6099 - val_mean_absolute_percentage_error: 53.7395
# Epoch 10/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2424 - mean_absolute_percentage_error: 19.7242 - val_loss: 0.5764 - val_mean_absolute_percentage_error: 50.3074
# Epoch 11/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2478 - mean_absolute_percentage_error: 19.9067 - val_loss: 0.5475 - val_mean_absolute_percentage_error: 47.5696
# Epoch 12/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2446 - mean_absolute_percentage_error: 19.5663 - val_loss: 0.5234 - val_mean_absolute_percentage_error: 45.4174
# Epoch 13/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2288 - mean_absolute_percentage_error: 18.9096 - val_loss: 0.5008 - val_mean_absolute_percentage_error: 43.4885
# Epoch 14/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2150 - mean_absolute_percentage_error: 17.8785 - val_loss: 0.4773 - val_mean_absolute_percentage_error: 41.4039
# Epoch 15/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2206 - mean_absolute_percentage_error: 17.8600 - val_loss: 0.4600 - val_mean_absolute_percentage_error: 40.3337
# Epoch 16/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1960 - mean_absolute_percentage_error: 15.7386 - val_loss: 0.4572 - val_mean_absolute_percentage_error: 40.4895
# Epoch 17/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2072 - mean_absolute_percentage_error: 16.6370 - val_loss: 0.4520 - val_mean_absolute_percentage_error: 40.2076
# Epoch 18/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1712 - mean_absolute_percentage_error: 13.4466 - val_loss: 0.4380 - val_mean_absolute_percentage_error: 38.6803
# Epoch 19/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1700 - mean_absolute_percentage_error: 14.0398 - val_loss: 0.4230 - val_mean_absolute_percentage_error: 36.9397
# Epoch 20/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1616 - mean_absolute_percentage_error: 13.1196 - val_loss: 0.4151 - val_mean_absolute_percentage_error: 35.6542
# Epoch 21/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1624 - mean_absolute_percentage_error: 12.9676 - val_loss: 0.4049 - val_mean_absolute_percentage_error: 34.7515
# Epoch 22/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1880 - mean_absolute_percentage_error: 15.7412 - val_loss: 0.3910 - val_mean_absolute_percentage_error: 33.5877
# Epoch 23/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1731 - mean_absolute_percentage_error: 14.2917 - val_loss: 0.3775 - val_mean_absolute_percentage_error: 32.3329
# Epoch 24/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1543 - mean_absolute_percentage_error: 12.6327 - val_loss: 0.3650 - val_mean_absolute_percentage_error: 31.1824
# Epoch 25/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1606 - mean_absolute_percentage_error: 12.7931 - val_loss: 0.3477 - val_mean_absolute_percentage_error: 29.6005
# Epoch 26/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1518 - mean_absolute_percentage_error: 12.1029 - val_loss: 0.3360 - val_mean_absolute_percentage_error: 28.5714
# Epoch 27/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1832 - mean_absolute_percentage_error: 15.0606 - val_loss: 0.3419 - val_mean_absolute_percentage_error: 29.2997
# Epoch 28/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1402 - mean_absolute_percentage_error: 10.8185 - val_loss: 0.3552 - val_mean_absolute_percentage_error: 30.7821
# Epoch 29/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1417 - mean_absolute_percentage_error: 11.6720 - val_loss: 0.3639 - val_mean_absolute_percentage_error: 31.6796
# Epoch 30/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1376 - mean_absolute_percentage_error: 11.1554 - val_loss: 0.3634 - val_mean_absolute_percentage_error: 31.3070
# Epoch 31/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_percentage_error: 13.6310 - val_loss: 0.3481 - val_mean_absolute_percentage_error: 29.2783
# Epoch 32/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1469 - mean_absolute_percentage_error: 12.2011 - val_loss: 0.3330 - val_mean_absolute_percentage_error: 28.1624
# Epoch 33/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1507 - mean_absolute_percentage_error: 12.1936 - val_loss: 0.3268 - val_mean_absolute_percentage_error: 27.8566
# Epoch 34/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1468 - mean_absolute_percentage_error: 11.6032 - val_loss: 0.3198 - val_mean_absolute_percentage_error: 27.5858
# Epoch 35/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1601 - mean_absolute_percentage_error: 12.9801 - val_loss: 0.3056 - val_mean_absolute_percentage_error: 26.3916
# Epoch 36/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1409 - mean_absolute_percentage_error: 11.8247 - val_loss: 0.3184 - val_mean_absolute_percentage_error: 27.3594
# Epoch 37/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1513 - mean_absolute_percentage_error: 12.0308 - val_loss: 0.3263 - val_mean_absolute_percentage_error: 28.2267
# Epoch 38/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1405 - mean_absolute_percentage_error: 11.3295 - val_loss: 0.3257 - val_mean_absolute_percentage_error: 28.4864
# Epoch 39/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1359 - mean_absolute_percentage_error: 11.3944 - val_loss: 0.3314 - val_mean_absolute_percentage_error: 29.4592
# Epoch 40/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1533 - mean_absolute_percentage_error: 12.5984 - val_loss: 0.3382 - val_mean_absolute_percentage_error: 30.1420
# Epoch 41/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1666 - mean_absolute_percentage_error: 13.6184 - val_loss: 0.3356 - val_mean_absolute_percentage_error: 29.8116
# Epoch 42/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1215 - mean_absolute_percentage_error: 9.9162 - val_loss: 0.3334 - val_mean_absolute_percentage_error: 29.6142
# Epoch 43/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1136 - mean_absolute_percentage_error: 9.3627 - val_loss: 0.3320 - val_mean_absolute_percentage_error: 29.0767
# Epoch 44/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1263 - mean_absolute_percentage_error: 10.5824 - val_loss: 0.3343 - val_mean_absolute_percentage_error: 28.7118
# Epoch 45/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1400 - mean_absolute_percentage_error: 11.3111 - val_loss: 0.3275 - val_mean_absolute_percentage_error: 28.0443
# Epoch 46/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1171 - mean_absolute_percentage_error: 10.0210 - val_loss: 0.3210 - val_mean_absolute_percentage_error: 27.9161
# Epoch 47/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1287 - mean_absolute_percentage_error: 11.2188 - val_loss: 0.3090 - val_mean_absolute_percentage_error: 26.8826
# Epoch 48/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1416 - mean_absolute_percentage_error: 11.8424 - val_loss: 0.2949 - val_mean_absolute_percentage_error: 25.4444
# Epoch 49/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1202 - mean_absolute_percentage_error: 10.0240 - val_loss: 0.2855 - val_mean_absolute_percentage_error: 25.0563
# Epoch 50/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1266 - mean_absolute_percentage_error: 10.9135 - val_loss: 0.2893 - val_mean_absolute_percentage_error: 25.8321
# Epoch 51/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1251 - mean_absolute_percentage_error: 10.8723 - val_loss: 0.2890 - val_mean_absolute_percentage_error: 25.9163
# Epoch 52/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1352 - mean_absolute_percentage_error: 11.1070 - val_loss: 0.2918 - val_mean_absolute_percentage_error: 26.1129
# Epoch 53/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1392 - mean_absolute_percentage_error: 11.7173 - val_loss: 0.2922 - val_mean_absolute_percentage_error: 26.2089
# Epoch 54/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1092 - mean_absolute_percentage_error: 8.6523 - val_loss: 0.2940 - val_mean_absolute_percentage_error: 26.4858
# Epoch 55/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1190 - mean_absolute_percentage_error: 9.5076 - val_loss: 0.3045 - val_mean_absolute_percentage_error: 27.2592
# Epoch 56/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1212 - mean_absolute_percentage_error: 10.3335 - val_loss: 0.2977 - val_mean_absolute_percentage_error: 26.3860
# Epoch 57/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1096 - mean_absolute_percentage_error: 8.7404 - val_loss: 0.2909 - val_mean_absolute_percentage_error: 25.6715
# Epoch 58/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0863 - mean_absolute_percentage_error: 7.1530 - val_loss: 0.2960 - val_mean_absolute_percentage_error: 25.9776
# Epoch 59/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1247 - mean_absolute_percentage_error: 10.2149 - val_loss: 0.2979 - val_mean_absolute_percentage_error: 26.0769
# Epoch 60/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1093 - mean_absolute_percentage_error: 9.3439 - val_loss: 0.2874 - val_mean_absolute_percentage_error: 25.3421
# Epoch 61/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1318 - mean_absolute_percentage_error: 10.8224 - val_loss: 0.2735 - val_mean_absolute_percentage_error: 24.0677
# Epoch 62/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1079 - mean_absolute_percentage_error: 9.2120 - val_loss: 0.2651 - val_mean_absolute_percentage_error: 23.1456
# Epoch 63/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1206 - mean_absolute_percentage_error: 10.3137 - val_loss: 0.2680 - val_mean_absolute_percentage_error: 23.3331
# Epoch 64/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0943 - mean_absolute_percentage_error: 7.8895 - val_loss: 0.2705 - val_mean_absolute_percentage_error: 23.5148
# Epoch 65/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1210 - mean_absolute_percentage_error: 10.2068 - val_loss: 0.2822 - val_mean_absolute_percentage_error: 24.3986
# Epoch 66/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1216 - mean_absolute_percentage_error: 9.8605 - val_loss: 0.2874 - val_mean_absolute_percentage_error: 24.9760
# Epoch 67/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1052 - mean_absolute_percentage_error: 8.7126 - val_loss: 0.2902 - val_mean_absolute_percentage_error: 25.1337
# Epoch 68/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1015 - mean_absolute_percentage_error: 8.0472 - val_loss: 0.2920 - val_mean_absolute_percentage_error: 25.1886
# Epoch 69/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1401 - mean_absolute_percentage_error: 11.6016 - val_loss: 0.2861 - val_mean_absolute_percentage_error: 24.5723
# Epoch 70/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0989 - mean_absolute_percentage_error: 8.4351 - val_loss: 0.2790 - val_mean_absolute_percentage_error: 23.5382
# Epoch 71/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1174 - mean_absolute_percentage_error: 9.5200 - val_loss: 0.2734 - val_mean_absolute_percentage_error: 22.9410
# Epoch 72/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0986 - mean_absolute_percentage_error: 8.1255 - val_loss: 0.2705 - val_mean_absolute_percentage_error: 22.7282
# Epoch 73/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1075 - mean_absolute_percentage_error: 8.7843 - val_loss: 0.2588 - val_mean_absolute_percentage_error: 21.5096
# Epoch 74/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1024 - mean_absolute_percentage_error: 8.4605 - val_loss: 0.2583 - val_mean_absolute_percentage_error: 21.4377
# Epoch 75/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0955 - mean_absolute_percentage_error: 8.0063 - val_loss: 0.2677 - val_mean_absolute_percentage_error: 22.4351
# Epoch 76/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1037 - mean_absolute_percentage_error: 8.6620 - val_loss: 0.2798 - val_mean_absolute_percentage_error: 24.1336
# Epoch 77/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1159 - mean_absolute_percentage_error: 9.5017 - val_loss: 0.2902 - val_mean_absolute_percentage_error: 25.5781
# Epoch 78/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1419 - mean_absolute_percentage_error: 11.7134 - val_loss: 0.2795 - val_mean_absolute_percentage_error: 24.3694
# Epoch 79/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1227 - mean_absolute_percentage_error: 10.5147 - val_loss: 0.2720 - val_mean_absolute_percentage_error: 23.4707
# Epoch 80/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1210 - mean_absolute_percentage_error: 10.2635 - val_loss: 0.2632 - val_mean_absolute_percentage_error: 22.6525
# Epoch 81/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1183 - mean_absolute_percentage_error: 9.8138 - val_loss: 0.2516 - val_mean_absolute_percentage_error: 21.4625
# Epoch 82/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1039 - mean_absolute_percentage_error: 8.6527 - val_loss: 0.2469 - val_mean_absolute_percentage_error: 20.9201
# Epoch 83/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0897 - mean_absolute_percentage_error: 7.1718 - val_loss: 0.2518 - val_mean_absolute_percentage_error: 21.3866
# Epoch 84/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0985 - mean_absolute_percentage_error: 7.9760 - val_loss: 0.2604 - val_mean_absolute_percentage_error: 22.7272
# Epoch 85/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1147 - mean_absolute_percentage_error: 9.5215 - val_loss: 0.2673 - val_mean_absolute_percentage_error: 23.5963
# Epoch 86/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1200 - mean_absolute_percentage_error: 10.3942 - val_loss: 0.2790 - val_mean_absolute_percentage_error: 24.9941
# Epoch 87/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1045 - mean_absolute_percentage_error: 8.7187 - val_loss: 0.2713 - val_mean_absolute_percentage_error: 23.7708
# Epoch 88/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0952 - mean_absolute_percentage_error: 7.9085 - val_loss: 0.2631 - val_mean_absolute_percentage_error: 22.8603
# Epoch 89/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1098 - mean_absolute_percentage_error: 8.8832 - val_loss: 0.2583 - val_mean_absolute_percentage_error: 22.3294
# Epoch 90/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1213 - mean_absolute_percentage_error: 10.2854 - val_loss: 0.2639 - val_mean_absolute_percentage_error: 23.0192
# Epoch 91/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1037 - mean_absolute_percentage_error: 8.3629 - val_loss: 0.2740 - val_mean_absolute_percentage_error: 23.9653
# Epoch 92/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1325 - mean_absolute_percentage_error: 10.9415 - val_loss: 0.2823 - val_mean_absolute_percentage_error: 25.2335
# Epoch 93/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0884 - mean_absolute_percentage_error: 7.2368 - val_loss: 0.2770 - val_mean_absolute_percentage_error: 24.6609
# Epoch 94/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0919 - mean_absolute_percentage_error: 7.6345 - val_loss: 0.2741 - val_mean_absolute_percentage_error: 24.3551
# Epoch 95/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1029 - mean_absolute_percentage_error: 8.5916 - val_loss: 0.2651 - val_mean_absolute_percentage_error: 23.2526
# Epoch 96/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1083 - mean_absolute_percentage_error: 8.8057 - val_loss: 0.2505 - val_mean_absolute_percentage_error: 21.0555
# Epoch 97/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1015 - mean_absolute_percentage_error: 8.4727 - val_loss: 0.2347 - val_mean_absolute_percentage_error: 19.4828
# Epoch 98/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0975 - mean_absolute_percentage_error: 8.4973 - val_loss: 0.2344 - val_mean_absolute_percentage_error: 19.5564
# Epoch 99/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0953 - mean_absolute_percentage_error: 7.4957 - val_loss: 0.2395 - val_mean_absolute_percentage_error: 20.0312
# Epoch 100/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1091 - mean_absolute_percentage_error: 9.1350 - val_loss: 0.2363 - val_mean_absolute_percentage_error: 19.7443
# Epoch 101/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0881 - mean_absolute_percentage_error: 7.3302 - val_loss: 0.2412 - val_mean_absolute_percentage_error: 20.2114
# Epoch 102/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0925 - mean_absolute_percentage_error: 7.5894 - val_loss: 0.2547 - val_mean_absolute_percentage_error: 21.6812
# Epoch 103/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0889 - mean_absolute_percentage_error: 7.1532 - val_loss: 0.2720 - val_mean_absolute_percentage_error: 23.6391
# Epoch 104/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1107 - mean_absolute_percentage_error: 9.1295 - val_loss: 0.2657 - val_mean_absolute_percentage_error: 23.0392
# Epoch 105/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1027 - mean_absolute_percentage_error: 8.3454 - val_loss: 0.2544 - val_mean_absolute_percentage_error: 21.9774
# Epoch 106/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0997 - mean_absolute_percentage_error: 8.0716 - val_loss: 0.2373 - val_mean_absolute_percentage_error: 20.2209
# Epoch 107/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1083 - mean_absolute_percentage_error: 9.1019 - val_loss: 0.2214 - val_mean_absolute_percentage_error: 18.5105
# Epoch 108/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1010 - mean_absolute_percentage_error: 8.6964 - val_loss: 0.2181 - val_mean_absolute_percentage_error: 18.0272
# Epoch 109/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0860 - mean_absolute_percentage_error: 7.0514 - val_loss: 0.2281 - val_mean_absolute_percentage_error: 19.1622
# Epoch 110/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1052 - mean_absolute_percentage_error: 8.9110 - val_loss: 0.2302 - val_mean_absolute_percentage_error: 19.3160
# Epoch 111/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0972 - mean_absolute_percentage_error: 7.9294 - val_loss: 0.2299 - val_mean_absolute_percentage_error: 18.9828
# Epoch 112/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1017 - mean_absolute_percentage_error: 8.4514 - val_loss: 0.2364 - val_mean_absolute_percentage_error: 19.6930
# Epoch 113/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1075 - mean_absolute_percentage_error: 8.9062 - val_loss: 0.2374 - val_mean_absolute_percentage_error: 19.9651
# Epoch 114/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0780 - mean_absolute_percentage_error: 6.6305 - val_loss: 0.2383 - val_mean_absolute_percentage_error: 20.0857
# Epoch 115/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1103 - mean_absolute_percentage_error: 8.8415 - val_loss: 0.2433 - val_mean_absolute_percentage_error: 20.6924
# Epoch 116/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0981 - mean_absolute_percentage_error: 8.4703 - val_loss: 0.2291 - val_mean_absolute_percentage_error: 18.7294
# Epoch 117/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0885 - mean_absolute_percentage_error: 7.0259 - val_loss: 0.2114 - val_mean_absolute_percentage_error: 17.1970
# Epoch 118/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0893 - mean_absolute_percentage_error: 7.2884 - val_loss: 0.2037 - val_mean_absolute_percentage_error: 16.7047
# Epoch 119/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0779 - mean_absolute_percentage_error: 6.6046 - val_loss: 0.2086 - val_mean_absolute_percentage_error: 17.1033
# Epoch 120/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1019 - mean_absolute_percentage_error: 8.4565 - val_loss: 0.2170 - val_mean_absolute_percentage_error: 17.7861
# Epoch 121/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0799 - mean_absolute_percentage_error: 6.4669 - val_loss: 0.2323 - val_mean_absolute_percentage_error: 19.4858
# Epoch 122/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1098 - mean_absolute_percentage_error: 9.3800 - val_loss: 0.2486 - val_mean_absolute_percentage_error: 21.1781
# Epoch 123/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0890 - mean_absolute_percentage_error: 7.1894 - val_loss: 0.2572 - val_mean_absolute_percentage_error: 22.0634
# Epoch 124/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0854 - mean_absolute_percentage_error: 6.8371 - val_loss: 0.2618 - val_mean_absolute_percentage_error: 22.6884
# Epoch 125/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1033 - mean_absolute_percentage_error: 8.9226 - val_loss: 0.2632 - val_mean_absolute_percentage_error: 23.0679
# Epoch 126/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0998 - mean_absolute_percentage_error: 8.2928 - val_loss: 0.2414 - val_mean_absolute_percentage_error: 20.1110
# Epoch 127/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0848 - mean_absolute_percentage_error: 7.1859 - val_loss: 0.2275 - val_mean_absolute_percentage_error: 18.5455
# Epoch 128/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1159 - mean_absolute_percentage_error: 9.5412 - val_loss: 0.2182 - val_mean_absolute_percentage_error: 17.7939
# Epoch 129/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0854 - mean_absolute_percentage_error: 7.1529 - val_loss: 0.2130 - val_mean_absolute_percentage_error: 17.4927
# Epoch 130/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0952 - mean_absolute_percentage_error: 8.0218 - val_loss: 0.2111 - val_mean_absolute_percentage_error: 17.3664
# Epoch 131/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0814 - mean_absolute_percentage_error: 6.7380 - val_loss: 0.2105 - val_mean_absolute_percentage_error: 17.2961
# Epoch 132/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0994 - mean_absolute_percentage_error: 8.2738 - val_loss: 0.2096 - val_mean_absolute_percentage_error: 17.1189
# Epoch 133/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0797 - mean_absolute_percentage_error: 6.6451 - val_loss: 0.2082 - val_mean_absolute_percentage_error: 16.9851
# Epoch 134/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0888 - mean_absolute_percentage_error: 6.9939 - val_loss: 0.2085 - val_mean_absolute_percentage_error: 17.1288
# Epoch 135/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0787 - mean_absolute_percentage_error: 6.4521 - val_loss: 0.2225 - val_mean_absolute_percentage_error: 18.1513
# Epoch 136/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0925 - mean_absolute_percentage_error: 7.8688 - val_loss: 0.2396 - val_mean_absolute_percentage_error: 20.0794
# Epoch 137/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0871 - mean_absolute_percentage_error: 7.3150 - val_loss: 0.2389 - val_mean_absolute_percentage_error: 20.2033
# Epoch 138/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0754 - mean_absolute_percentage_error: 6.5766 - val_loss: 0.2267 - val_mean_absolute_percentage_error: 18.8259
# Epoch 139/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0917 - mean_absolute_percentage_error: 7.5750 - val_loss: 0.2209 - val_mean_absolute_percentage_error: 18.3387
# Epoch 140/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0903 - mean_absolute_percentage_error: 7.3550 - val_loss: 0.2163 - val_mean_absolute_percentage_error: 17.9071
# Epoch 141/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0843 - mean_absolute_percentage_error: 7.0039 - val_loss: 0.2238 - val_mean_absolute_percentage_error: 18.9671
# Epoch 142/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0805 - mean_absolute_percentage_error: 7.0028 - val_loss: 0.2302 - val_mean_absolute_percentage_error: 20.4206
# Epoch 143/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0893 - mean_absolute_percentage_error: 7.3889 - val_loss: 0.2264 - val_mean_absolute_percentage_error: 20.0182
# Epoch 144/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0910 - mean_absolute_percentage_error: 7.7643 - val_loss: 0.2157 - val_mean_absolute_percentage_error: 18.5517
# Epoch 145/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0738 - mean_absolute_percentage_error: 6.0083 - val_loss: 0.2050 - val_mean_absolute_percentage_error: 17.2362
# Epoch 146/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0944 - mean_absolute_percentage_error: 7.6706 - val_loss: 0.1972 - val_mean_absolute_percentage_error: 16.5649
# Epoch 147/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0770 - mean_absolute_percentage_error: 6.1503 - val_loss: 0.2077 - val_mean_absolute_percentage_error: 17.7728
# Epoch 148/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0901 - mean_absolute_percentage_error: 7.5091 - val_loss: 0.2197 - val_mean_absolute_percentage_error: 19.0621
# Epoch 149/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0855 - mean_absolute_percentage_error: 7.2633 - val_loss: 0.2220 - val_mean_absolute_percentage_error: 19.3132
# Epoch 150/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0816 - mean_absolute_percentage_error: 6.6123 - val_loss: 0.2249 - val_mean_absolute_percentage_error: 19.6339
# Epoch 151/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0952 - mean_absolute_percentage_error: 7.8335 - val_loss: 0.2322 - val_mean_absolute_percentage_error: 20.5761
# Epoch 152/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0742 - mean_absolute_percentage_error: 6.4284 - val_loss: 0.2208 - val_mean_absolute_percentage_error: 19.1553
# Epoch 153/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0917 - mean_absolute_percentage_error: 7.7861 - val_loss: 0.2044 - val_mean_absolute_percentage_error: 17.1036
# Epoch 154/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0848 - mean_absolute_percentage_error: 6.9874 - val_loss: 0.1963 - val_mean_absolute_percentage_error: 16.3134
# Epoch 155/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0826 - mean_absolute_percentage_error: 6.6679 - val_loss: 0.1901 - val_mean_absolute_percentage_error: 15.8442
# Epoch 156/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0811 - mean_absolute_percentage_error: 6.8771 - val_loss: 0.1961 - val_mean_absolute_percentage_error: 16.5775
# Epoch 157/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1049 - mean_absolute_percentage_error: 8.5709 - val_loss: 0.1961 - val_mean_absolute_percentage_error: 16.4974
# Epoch 158/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0909 - mean_absolute_percentage_error: 7.6117 - val_loss: 0.1923 - val_mean_absolute_percentage_error: 15.9520
# Epoch 159/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0789 - mean_absolute_percentage_error: 6.5598 - val_loss: 0.1887 - val_mean_absolute_percentage_error: 15.3937
# Epoch 160/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0868 - mean_absolute_percentage_error: 7.3982 - val_loss: 0.1953 - val_mean_absolute_percentage_error: 16.0533
# Epoch 161/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0740 - mean_absolute_percentage_error: 6.3538 - val_loss: 0.1961 - val_mean_absolute_percentage_error: 16.3136
# Epoch 162/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0758 - mean_absolute_percentage_error: 6.2647 - val_loss: 0.1925 - val_mean_absolute_percentage_error: 15.9632
# Epoch 163/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0823 - mean_absolute_percentage_error: 6.8500 - val_loss: 0.1820 - val_mean_absolute_percentage_error: 14.6113
# Epoch 164/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0755 - mean_absolute_percentage_error: 6.2626 - val_loss: 0.1755 - val_mean_absolute_percentage_error: 13.8478
# Epoch 165/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0812 - mean_absolute_percentage_error: 7.0386 - val_loss: 0.1931 - val_mean_absolute_percentage_error: 16.1768
# Epoch 166/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0800 - mean_absolute_percentage_error: 6.6522 - val_loss: 0.2074 - val_mean_absolute_percentage_error: 18.3448
# Epoch 167/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0740 - mean_absolute_percentage_error: 6.0419 - val_loss: 0.2100 - val_mean_absolute_percentage_error: 18.7861
# Epoch 168/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0869 - mean_absolute_percentage_error: 7.2203 - val_loss: 0.1942 - val_mean_absolute_percentage_error: 16.8037
# Epoch 169/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0911 - mean_absolute_percentage_error: 7.4364 - val_loss: 0.1708 - val_mean_absolute_percentage_error: 14.1643
# Epoch 170/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0837 - mean_absolute_percentage_error: 6.7486 - val_loss: 0.1555 - val_mean_absolute_percentage_error: 12.9817
# Epoch 171/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0810 - mean_absolute_percentage_error: 6.9185 - val_loss: 0.1556 - val_mean_absolute_percentage_error: 13.0750
# Epoch 172/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0880 - mean_absolute_percentage_error: 7.3201 - val_loss: 0.1449 - val_mean_absolute_percentage_error: 12.3863
# Epoch 173/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0628 - mean_absolute_percentage_error: 5.3277 - val_loss: 0.1377 - val_mean_absolute_percentage_error: 11.7759
# Epoch 174/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0744 - mean_absolute_percentage_error: 6.1560 - val_loss: 0.1410 - val_mean_absolute_percentage_error: 11.9805
# Epoch 175/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0723 - mean_absolute_percentage_error: 6.0967 - val_loss: 0.1582 - val_mean_absolute_percentage_error: 13.3137
# Epoch 176/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0709 - mean_absolute_percentage_error: 5.8566 - val_loss: 0.1908 - val_mean_absolute_percentage_error: 17.1852
# Epoch 177/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0948 - mean_absolute_percentage_error: 7.8204 - val_loss: 0.2088 - val_mean_absolute_percentage_error: 19.5764
# Epoch 178/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0861 - mean_absolute_percentage_error: 7.0819 - val_loss: 0.2031 - val_mean_absolute_percentage_error: 18.8771
# Epoch 179/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0805 - mean_absolute_percentage_error: 6.8677 - val_loss: 0.1809 - val_mean_absolute_percentage_error: 16.0869
# Epoch 180/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0707 - mean_absolute_percentage_error: 5.8883 - val_loss: 0.1629 - val_mean_absolute_percentage_error: 13.6465
# Epoch 181/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0843 - mean_absolute_percentage_error: 7.0688 - val_loss: 0.1553 - val_mean_absolute_percentage_error: 12.8093
# Epoch 182/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0797 - mean_absolute_percentage_error: 6.5175 - val_loss: 0.1655 - val_mean_absolute_percentage_error: 14.0408
# Epoch 183/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0907 - mean_absolute_percentage_error: 7.9229 - val_loss: 0.1657 - val_mean_absolute_percentage_error: 14.2005
# Epoch 184/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0823 - mean_absolute_percentage_error: 7.0022 - val_loss: 0.1545 - val_mean_absolute_percentage_error: 13.0193
# Epoch 185/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0845 - mean_absolute_percentage_error: 7.0205 - val_loss: 0.1397 - val_mean_absolute_percentage_error: 11.5216
# Epoch 186/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0643 - mean_absolute_percentage_error: 5.2521 - val_loss: 0.1388 - val_mean_absolute_percentage_error: 11.5179
# Epoch 187/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0736 - mean_absolute_percentage_error: 6.1785 - val_loss: 0.1623 - val_mean_absolute_percentage_error: 14.2166
# Epoch 188/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0766 - mean_absolute_percentage_error: 6.3907 - val_loss: 0.2078 - val_mean_absolute_percentage_error: 19.4629
# Epoch 189/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0700 - mean_absolute_percentage_error: 5.8412 - val_loss: 0.2130 - val_mean_absolute_percentage_error: 20.0187
# Epoch 190/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0723 - mean_absolute_percentage_error: 6.1069 - val_loss: 0.2053 - val_mean_absolute_percentage_error: 19.1866
# Epoch 191/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0877 - mean_absolute_percentage_error: 7.5840 - val_loss: 0.1881 - val_mean_absolute_percentage_error: 17.2709
# Epoch 192/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0799 - mean_absolute_percentage_error: 6.6388 - val_loss: 0.1607 - val_mean_absolute_percentage_error: 13.8199
# Epoch 193/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0820 - mean_absolute_percentage_error: 6.7474 - val_loss: 0.1405 - val_mean_absolute_percentage_error: 11.7368
# Epoch 194/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0683 - mean_absolute_percentage_error: 5.6135 - val_loss: 0.1310 - val_mean_absolute_percentage_error: 10.9796
# Epoch 195/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0751 - mean_absolute_percentage_error: 6.2740 - val_loss: 0.1372 - val_mean_absolute_percentage_error: 11.3533
# Epoch 196/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0773 - mean_absolute_percentage_error: 6.1920 - val_loss: 0.1428 - val_mean_absolute_percentage_error: 11.8634
# Epoch 197/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0821 - mean_absolute_percentage_error: 6.9943 - val_loss: 0.1573 - val_mean_absolute_percentage_error: 13.7260
# Epoch 198/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0869 - mean_absolute_percentage_error: 7.6101 - val_loss: 0.1596 - val_mean_absolute_percentage_error: 13.8663
# Epoch 199/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0733 - mean_absolute_percentage_error: 6.2890 - val_loss: 0.1513 - val_mean_absolute_percentage_error: 12.8050
# Epoch 200/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0827 - mean_absolute_percentage_error: 6.9603 - val_loss: 0.1382 - val_mean_absolute_percentage_error: 11.1371
# Epoch 201/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0772 - mean_absolute_percentage_error: 6.4092 - val_loss: 0.1242 - val_mean_absolute_percentage_error: 10.0578
# Epoch 202/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0738 - mean_absolute_percentage_error: 6.0163 - val_loss: 0.1269 - val_mean_absolute_percentage_error: 10.0834
# Epoch 203/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0620 - mean_absolute_percentage_error: 5.2448 - val_loss: 0.1327 - val_mean_absolute_percentage_error: 10.3410
# Epoch 204/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0674 - mean_absolute_percentage_error: 5.4128 - val_loss: 0.1546 - val_mean_absolute_percentage_error: 12.8745
# Epoch 205/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0714 - mean_absolute_percentage_error: 5.8902 - val_loss: 0.1672 - val_mean_absolute_percentage_error: 14.4525
# Epoch 206/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0786 - mean_absolute_percentage_error: 6.7996 - val_loss: 0.1721 - val_mean_absolute_percentage_error: 15.2510
# Epoch 207/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0745 - mean_absolute_percentage_error: 6.1083 - val_loss: 0.1525 - val_mean_absolute_percentage_error: 12.8755
# Epoch 208/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0632 - mean_absolute_percentage_error: 5.3467 - val_loss: 0.1505 - val_mean_absolute_percentage_error: 12.4973
# Epoch 209/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0818 - mean_absolute_percentage_error: 6.7542 - val_loss: 0.1455 - val_mean_absolute_percentage_error: 11.9840
# Epoch 210/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0798 - mean_absolute_percentage_error: 6.6814 - val_loss: 0.1407 - val_mean_absolute_percentage_error: 11.4638
# Epoch 211/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0719 - mean_absolute_percentage_error: 5.8683 - val_loss: 0.1446 - val_mean_absolute_percentage_error: 11.8268
# Epoch 212/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0661 - mean_absolute_percentage_error: 5.5083 - val_loss: 0.1415 - val_mean_absolute_percentage_error: 11.4729
# Epoch 213/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0795 - mean_absolute_percentage_error: 6.6558 - val_loss: 0.1333 - val_mean_absolute_percentage_error: 10.6249
# Epoch 214/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0656 - mean_absolute_percentage_error: 5.5108 - val_loss: 0.1349 - val_mean_absolute_percentage_error: 10.7001
# Epoch 215/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0654 - mean_absolute_percentage_error: 5.4662 - val_loss: 0.1452 - val_mean_absolute_percentage_error: 12.0159
# Epoch 216/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0817 - mean_absolute_percentage_error: 6.6988 - val_loss: 0.1355 - val_mean_absolute_percentage_error: 11.0019
# Epoch 217/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0737 - mean_absolute_percentage_error: 6.0922 - val_loss: 0.1299 - val_mean_absolute_percentage_error: 10.4970
# Epoch 218/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0643 - mean_absolute_percentage_error: 5.4618 - val_loss: 0.1189 - val_mean_absolute_percentage_error: 9.5949
# Epoch 219/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0669 - mean_absolute_percentage_error: 5.3559 - val_loss: 0.1135 - val_mean_absolute_percentage_error: 9.5461
# Epoch 220/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0560 - mean_absolute_percentage_error: 4.7490 - val_loss: 0.1219 - val_mean_absolute_percentage_error: 10.0865
# Epoch 221/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0685 - mean_absolute_percentage_error: 5.8583 - val_loss: 0.1387 - val_mean_absolute_percentage_error: 11.5923
# Epoch 222/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0690 - mean_absolute_percentage_error: 5.8444 - val_loss: 0.1440 - val_mean_absolute_percentage_error: 12.2555
# Epoch 223/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0590 - mean_absolute_percentage_error: 4.9241 - val_loss: 0.1329 - val_mean_absolute_percentage_error: 10.8627
# Epoch 224/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0753 - mean_absolute_percentage_error: 6.0997 - val_loss: 0.1290 - val_mean_absolute_percentage_error: 10.4332
# Epoch 225/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0671 - mean_absolute_percentage_error: 5.4524 - val_loss: 0.1233 - val_mean_absolute_percentage_error: 10.2354
# Epoch 226/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0721 - mean_absolute_percentage_error: 5.8062 - val_loss: 0.1334 - val_mean_absolute_percentage_error: 11.2692
# Epoch 227/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0723 - mean_absolute_percentage_error: 5.9085 - val_loss: 0.1419 - val_mean_absolute_percentage_error: 12.0866
# Epoch 228/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0683 - mean_absolute_percentage_error: 5.3333 - val_loss: 0.1356 - val_mean_absolute_percentage_error: 11.6897
# Epoch 229/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0758 - mean_absolute_percentage_error: 6.6729 - val_loss: 0.1464 - val_mean_absolute_percentage_error: 12.6658
# Epoch 230/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0748 - mean_absolute_percentage_error: 6.3066 - val_loss: 0.1732 - val_mean_absolute_percentage_error: 15.7269
# Epoch 231/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0649 - mean_absolute_percentage_error: 5.5573 - val_loss: 0.1943 - val_mean_absolute_percentage_error: 18.0877
# Epoch 232/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0659 - mean_absolute_percentage_error: 5.6629 - val_loss: 0.1840 - val_mean_absolute_percentage_error: 16.7036
# Epoch 233/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0681 - mean_absolute_percentage_error: 5.6518 - val_loss: 0.1651 - val_mean_absolute_percentage_error: 14.5987
# Epoch 234/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0665 - mean_absolute_percentage_error: 5.4576 - val_loss: 0.1574 - val_mean_absolute_percentage_error: 13.8927
# Epoch 235/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0645 - mean_absolute_percentage_error: 5.4337 - val_loss: 0.1539 - val_mean_absolute_percentage_error: 13.5625
# Epoch 236/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0800 - mean_absolute_percentage_error: 6.7432 - val_loss: 0.1400 - val_mean_absolute_percentage_error: 12.0182
# Epoch 237/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0666 - mean_absolute_percentage_error: 5.3812 - val_loss: 0.1354 - val_mean_absolute_percentage_error: 11.4546
# Epoch 238/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0629 - mean_absolute_percentage_error: 5.2504 - val_loss: 0.1290 - val_mean_absolute_percentage_error: 10.8395
# Epoch 239/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0650 - mean_absolute_percentage_error: 5.4377 - val_loss: 0.1237 - val_mean_absolute_percentage_error: 10.2830
# Epoch 240/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0763 - mean_absolute_percentage_error: 6.4284 - val_loss: 0.1131 - val_mean_absolute_percentage_error: 9.4366
# Epoch 241/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0657 - mean_absolute_percentage_error: 5.4613 - val_loss: 0.1243 - val_mean_absolute_percentage_error: 10.4055
# Epoch 242/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0757 - mean_absolute_percentage_error: 6.2606 - val_loss: 0.1456 - val_mean_absolute_percentage_error: 13.0916
# Epoch 243/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0641 - mean_absolute_percentage_error: 5.3209 - val_loss: 0.1370 - val_mean_absolute_percentage_error: 12.0608
# Epoch 244/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0792 - mean_absolute_percentage_error: 6.7030 - val_loss: 0.1217 - val_mean_absolute_percentage_error: 10.3449
# Epoch 245/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0693 - mean_absolute_percentage_error: 5.9794 - val_loss: 0.1153 - val_mean_absolute_percentage_error: 9.6504
# Epoch 246/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0740 - mean_absolute_percentage_error: 6.2142 - val_loss: 0.1222 - val_mean_absolute_percentage_error: 10.3147
# Epoch 247/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0785 - mean_absolute_percentage_error: 6.7929 - val_loss: 0.1356 - val_mean_absolute_percentage_error: 11.5869
# Epoch 248/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0632 - mean_absolute_percentage_error: 5.2382 - val_loss: 0.1304 - val_mean_absolute_percentage_error: 10.4227
# Epoch 249/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0675 - mean_absolute_percentage_error: 5.8331 - val_loss: 0.1214 - val_mean_absolute_percentage_error: 9.6449
# Epoch 250/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0683 - mean_absolute_percentage_error: 5.8928 - val_loss: 0.1356 - val_mean_absolute_percentage_error: 10.7661
# Epoch 251/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0582 - mean_absolute_percentage_error: 4.6598 - val_loss: 0.1607 - val_mean_absolute_percentage_error: 13.9738
# Epoch 252/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0693 - mean_absolute_percentage_error: 5.7963 - val_loss: 0.1525 - val_mean_absolute_percentage_error: 12.8724
# Epoch 253/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0652 - mean_absolute_percentage_error: 5.5160 - val_loss: 0.1431 - val_mean_absolute_percentage_error: 11.8196
# Epoch 254/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0584 - mean_absolute_percentage_error: 4.9470 - val_loss: 0.1287 - val_mean_absolute_percentage_error: 10.0570
# Epoch 255/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0754 - mean_absolute_percentage_error: 6.1211 - val_loss: 0.1169 - val_mean_absolute_percentage_error: 9.4022
# Epoch 256/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0599 - mean_absolute_percentage_error: 5.0152 - val_loss: 0.1324 - val_mean_absolute_percentage_error: 10.6223
# Epoch 257/2000
# ...
# Epoch 426/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0383 - mean_absolute_percentage_error: 3.3267 - val_loss: 0.0918 - val_mean_absolute_percentage_error: 7.9209
# Epoch 427/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0496 - mean_absolute_percentage_error: 4.1686 - val_loss: 0.0684 - val_mean_absolute_percentage_error: 5.6625
# Epoch 428/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0418 - mean_absolute_percentage_error: 3.5442 - val_loss: 0.0671 - val_mean_absolute_percentage_error: 5.6830
# Epoch 429/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0506 - mean_absolute_percentage_error: 4.2624 - val_loss: 0.0762 - val_mean_absolute_percentage_error: 6.4500
# Epoch 430/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.7386 - val_loss: 0.0909 - val_mean_absolute_percentage_error: 7.8755
# Epoch 431/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0462 - mean_absolute_percentage_error: 3.6524 - val_loss: 0.0895 - val_mean_absolute_percentage_error: 7.7969
# Epoch 432/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0549 - mean_absolute_percentage_error: 4.6607 - val_loss: 0.0936 - val_mean_absolute_percentage_error: 8.0812
# Epoch 433/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0434 - mean_absolute_percentage_error: 3.6982 - val_loss: 0.0789 - val_mean_absolute_percentage_error: 6.6296
# Epoch 434/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0631 - mean_absolute_percentage_error: 5.4971 - val_loss: 0.0688 - val_mean_absolute_percentage_error: 5.6255
# Epoch 435/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0423 - mean_absolute_percentage_error: 3.4845 - val_loss: 0.0659 - val_mean_absolute_percentage_error: 5.2656
# Epoch 436/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0482 - mean_absolute_percentage_error: 4.0187 - val_loss: 0.0923 - val_mean_absolute_percentage_error: 7.7569
# Epoch 437/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0532 - mean_absolute_percentage_error: 4.4884 - val_loss: 0.1239 - val_mean_absolute_percentage_error: 11.4658
# Epoch 438/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0486 - mean_absolute_percentage_error: 4.2587 - val_loss: 0.1339 - val_mean_absolute_percentage_error: 12.4204
# Epoch 439/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0464 - mean_absolute_percentage_error: 3.8873 - val_loss: 0.1231 - val_mean_absolute_percentage_error: 10.8497
# Epoch 440/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0406 - mean_absolute_percentage_error: 3.3718 - val_loss: 0.1304 - val_mean_absolute_percentage_error: 11.4873
# Epoch 441/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0448 - mean_absolute_percentage_error: 3.9116 - val_loss: 0.1143 - val_mean_absolute_percentage_error: 9.6597
# Epoch 442/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0506 - mean_absolute_percentage_error: 4.2971 - val_loss: 0.0977 - val_mean_absolute_percentage_error: 8.0979
# Epoch 443/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0413 - mean_absolute_percentage_error: 3.5224 - val_loss: 0.1018 - val_mean_absolute_percentage_error: 8.5612
# Epoch 444/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0583 - mean_absolute_percentage_error: 5.0491 - val_loss: 0.1165 - val_mean_absolute_percentage_error: 10.4238
# Epoch 445/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0444 - mean_absolute_percentage_error: 3.6933 - val_loss: 0.0931 - val_mean_absolute_percentage_error: 7.6712
# Epoch 446/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0470 - mean_absolute_percentage_error: 3.9391 - val_loss: 0.0794 - val_mean_absolute_percentage_error: 6.5537
# Epoch 447/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0480 - mean_absolute_percentage_error: 4.0919 - val_loss: 0.0813 - val_mean_absolute_percentage_error: 6.8071
# Epoch 448/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0571 - mean_absolute_percentage_error: 4.9685 - val_loss: 0.0804 - val_mean_absolute_percentage_error: 6.7404
# Epoch 449/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0469 - mean_absolute_percentage_error: 3.7895 - val_loss: 0.0648 - val_mean_absolute_percentage_error: 5.5300
# Epoch 450/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0531 - mean_absolute_percentage_error: 4.4996 - val_loss: 0.0611 - val_mean_absolute_percentage_error: 5.2539
# Epoch 451/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0460 - mean_absolute_percentage_error: 3.8228 - val_loss: 0.0661 - val_mean_absolute_percentage_error: 5.6839
# Epoch 452/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0426 - mean_absolute_percentage_error: 3.4518 - val_loss: 0.0682 - val_mean_absolute_percentage_error: 5.8470
# Epoch 453/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0487 - mean_absolute_percentage_error: 4.0621 - val_loss: 0.0673 - val_mean_absolute_percentage_error: 5.7710
# Epoch 454/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0470 - mean_absolute_percentage_error: 4.0168 - val_loss: 0.0795 - val_mean_absolute_percentage_error: 6.4032
# Epoch 455/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0663 - mean_absolute_percentage_error: 5.6150 - val_loss: 0.1051 - val_mean_absolute_percentage_error: 8.8665
# Epoch 456/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0364 - mean_absolute_percentage_error: 2.9702 - val_loss: 0.1168 - val_mean_absolute_percentage_error: 10.0940
# Epoch 457/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0623 - mean_absolute_percentage_error: 5.5258 - val_loss: 0.1017 - val_mean_absolute_percentage_error: 8.1646
# Epoch 458/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0491 - mean_absolute_percentage_error: 4.0567 - val_loss: 0.0802 - val_mean_absolute_percentage_error: 6.6059
# Epoch 459/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0455 - mean_absolute_percentage_error: 3.7595 - val_loss: 0.0902 - val_mean_absolute_percentage_error: 7.4657
# Epoch 460/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0683 - mean_absolute_percentage_error: 5.8512 - val_loss: 0.0960 - val_mean_absolute_percentage_error: 8.0788
# Epoch 461/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.6869 - val_loss: 0.0821 - val_mean_absolute_percentage_error: 6.7637
# Epoch 462/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0512 - mean_absolute_percentage_error: 4.1697 - val_loss: 0.0721 - val_mean_absolute_percentage_error: 6.1190
# Epoch 463/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0463 - mean_absolute_percentage_error: 3.9836 - val_loss: 0.1005 - val_mean_absolute_percentage_error: 8.6567
# Epoch 464/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0596 - mean_absolute_percentage_error: 5.1439 - val_loss: 0.1242 - val_mean_absolute_percentage_error: 11.4500
# Epoch 465/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0686 - mean_absolute_percentage_error: 6.0253 - val_loss: 0.0830 - val_mean_absolute_percentage_error: 6.7049
# Epoch 466/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0598 - mean_absolute_percentage_error: 5.1193 - val_loss: 0.0630 - val_mean_absolute_percentage_error: 5.1501
# Epoch 467/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0434 - mean_absolute_percentage_error: 3.6653 - val_loss: 0.0613 - val_mean_absolute_percentage_error: 5.0296
# Epoch 468/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0465 - mean_absolute_percentage_error: 3.8007 - val_loss: 0.0697 - val_mean_absolute_percentage_error: 5.7234
# Epoch 469/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0478 - mean_absolute_percentage_error: 4.0507 - val_loss: 0.0976 - val_mean_absolute_percentage_error: 8.3377
# Epoch 470/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0526 - mean_absolute_percentage_error: 4.3630 - val_loss: 0.1168 - val_mean_absolute_percentage_error: 10.1475
# Epoch 471/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0530 - mean_absolute_percentage_error: 4.5084 - val_loss: 0.1413 - val_mean_absolute_percentage_error: 12.9453
# Epoch 472/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0460 - mean_absolute_percentage_error: 3.9258 - val_loss: 0.1538 - val_mean_absolute_percentage_error: 14.4449
# Epoch 473/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0610 - mean_absolute_percentage_error: 5.3193 - val_loss: 0.1641 - val_mean_absolute_percentage_error: 15.6716
# Epoch 474/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0518 - mean_absolute_percentage_error: 4.4859 - val_loss: 0.1283 - val_mean_absolute_percentage_error: 11.7115
# Epoch 475/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0468 - mean_absolute_percentage_error: 3.9494 - val_loss: 0.0897 - val_mean_absolute_percentage_error: 7.3631
# Epoch 476/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0557 - mean_absolute_percentage_error: 4.7951 - val_loss: 0.0755 - val_mean_absolute_percentage_error: 6.1024
# Epoch 477/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0427 - mean_absolute_percentage_error: 3.6788 - val_loss: 0.0713 - val_mean_absolute_percentage_error: 5.7210
# Epoch 478/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0650 - mean_absolute_percentage_error: 5.4759 - val_loss: 0.0657 - val_mean_absolute_percentage_error: 5.4614
# Epoch 479/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0526 - mean_absolute_percentage_error: 4.5464 - val_loss: 0.0893 - val_mean_absolute_percentage_error: 7.3405
# Epoch 480/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0498 - mean_absolute_percentage_error: 4.1215 - val_loss: 0.1258 - val_mean_absolute_percentage_error: 11.4965
# Epoch 481/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0486 - mean_absolute_percentage_error: 4.0277 - val_loss: 0.1232 - val_mean_absolute_percentage_error: 11.1555
# Epoch 482/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.7634 - val_loss: 0.1202 - val_mean_absolute_percentage_error: 10.8319
# Epoch 483/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0453 - mean_absolute_percentage_error: 3.8948 - val_loss: 0.1092 - val_mean_absolute_percentage_error: 9.6792
# Epoch 484/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0466 - mean_absolute_percentage_error: 3.9115 - val_loss: 0.1003 - val_mean_absolute_percentage_error: 8.8233
# Epoch 485/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0415 - mean_absolute_percentage_error: 3.4096 - val_loss: 0.1169 - val_mean_absolute_percentage_error: 10.7767
# Epoch 486/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0425 - mean_absolute_percentage_error: 3.6491 - val_loss: 0.1276 - val_mean_absolute_percentage_error: 12.1256
# Epoch 487/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0529 - mean_absolute_percentage_error: 4.4202 - val_loss: 0.1049 - val_mean_absolute_percentage_error: 9.5963
# Epoch 488/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0425 - mean_absolute_percentage_error: 3.5390 - val_loss: 0.0833 - val_mean_absolute_percentage_error: 7.1117
# Epoch 489/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0423 - mean_absolute_percentage_error: 3.5214 - val_loss: 0.0720 - val_mean_absolute_percentage_error: 6.1618
# Epoch 490/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0515 - mean_absolute_percentage_error: 4.2405 - val_loss: 0.0670 - val_mean_absolute_percentage_error: 5.6997
# Epoch 491/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0538 - mean_absolute_percentage_error: 4.3933 - val_loss: 0.0652 - val_mean_absolute_percentage_error: 5.4511
# Epoch 492/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0523 - mean_absolute_percentage_error: 4.3459 - val_loss: 0.0773 - val_mean_absolute_percentage_error: 6.2970
# Epoch 493/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0398 - mean_absolute_percentage_error: 3.3106 - val_loss: 0.0819 - val_mean_absolute_percentage_error: 6.6982
# Epoch 494/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0469 - mean_absolute_percentage_error: 3.9426 - val_loss: 0.0893 - val_mean_absolute_percentage_error: 7.4311
# Epoch 495/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0434 - mean_absolute_percentage_error: 3.6211 - val_loss: 0.0955 - val_mean_absolute_percentage_error: 8.0770
# Epoch 496/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0426 - mean_absolute_percentage_error: 3.5815 - val_loss: 0.0873 - val_mean_absolute_percentage_error: 7.3807
# Epoch 497/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0486 - mean_absolute_percentage_error: 4.1617 - val_loss: 0.0828 - val_mean_absolute_percentage_error: 6.8103
# Epoch 498/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0487 - mean_absolute_percentage_error: 4.2482 - val_loss: 0.1100 - val_mean_absolute_percentage_error: 9.6143
# Epoch 499/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0424 - mean_absolute_percentage_error: 3.6353 - val_loss: 0.1330 - val_mean_absolute_percentage_error: 12.2465
# Epoch 500/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0442 - mean_absolute_percentage_error: 3.7204 - val_loss: 0.1283 - val_mean_absolute_percentage_error: 11.6901
# Epoch 501/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0513 - mean_absolute_percentage_error: 4.4607 - val_loss: 0.1038 - val_mean_absolute_percentage_error: 8.9577
# Epoch 502/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0520 - mean_absolute_percentage_error: 4.5624 - val_loss: 0.0798 - val_mean_absolute_percentage_error: 6.8622
# Epoch 503/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0469 - mean_absolute_percentage_error: 3.8192 - val_loss: 0.0782 - val_mean_absolute_percentage_error: 6.6313
# Epoch 504/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0597 - mean_absolute_percentage_error: 4.9492 - val_loss: 0.0855 - val_mean_absolute_percentage_error: 7.1846
# Epoch 505/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0468 - mean_absolute_percentage_error: 3.9895 - val_loss: 0.0718 - val_mean_absolute_percentage_error: 5.9450
# Epoch 506/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0437 - mean_absolute_percentage_error: 3.7980 - val_loss: 0.0672 - val_mean_absolute_percentage_error: 5.5428
# Epoch 507/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0480 - mean_absolute_percentage_error: 4.0984 - val_loss: 0.0660 - val_mean_absolute_percentage_error: 5.5131
# Epoch 508/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0468 - mean_absolute_percentage_error: 3.7994 - val_loss: 0.0743 - val_mean_absolute_percentage_error: 6.2738
# Epoch 509/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0545 - mean_absolute_percentage_error: 4.8378 - val_loss: 0.0744 - val_mean_absolute_percentage_error: 6.2925
# Epoch 510/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0496 - mean_absolute_percentage_error: 4.1760 - val_loss: 0.0692 - val_mean_absolute_percentage_error: 5.8283
# Restoring model weights from the end of the best epoch.
# Epoch 00510: early stopping

# %% [markdown]
# **Performance plot of the model: RMSE and MAPE**
#
# **Deutsch:**
#
# **Erstellung des Diagramms der Modellleistung: RMSE und MAPE**

# %%
 # Plot training & validation loss values (RMSE)
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history_2.history["loss"])
plt.plot(history_2.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %%
# Plot tht training and validation's MAPE
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history_2.history["mean_absolute_percentage_error"])
plt.plot(history_2.history["val_mean_absolute_percentage_error"])
plt.title("Model Accuracy with MAPE")
plt.ylabel("Loss (%)")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# **Predict the train dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Trainingdatensatzes für die Verlustberechnung**

# %%
predictions_train = model_2.predict(X_train1)
predictions_train
# Out:
# array([[0.15720166, 0.21011545, 0.1428127 , 0.03516841, 0.05338756,
#         0.07125772, 0.1336456 , 0.18777221, 0.04010369],
#        [0.2357703 , 0.3258315 , 0.21984334, 0.05899353, 0.08855635,
#         0.11736758, 0.22701849, 0.24007969, 0.08727522],
#        [0.32528967, 0.452354  , 0.26759776, 0.09384446, 0.11468859,
#         0.15857968, 0.304339  , 0.2903267 , 0.11206608],
#        [0.39082867, 0.5551616 , 0.29245907, 0.13460043, 0.1442965 ,
#         0.20567116, 0.38200027, 0.33222866, 0.14644876],
#        [0.46451613, 0.6619545 , 0.34731573, 0.1706256 , 0.18317702,
#         0.26232058, 0.47603077, 0.39367706, 0.19222131],
#        [0.52271736, 0.7452615 , 0.39442354, 0.22262526, 0.22467183,
#         0.31440604, 0.5519922 , 0.4521854 , 0.23686096],
#        [0.54799354, 0.75602955, 0.42615065, 0.26044747, 0.26748443,
#         0.35689935, 0.58840775, 0.4940086 , 0.29174384],
#        [0.6108233 , 0.8028519 , 0.49438274, 0.30995664, 0.31496716,
#         0.41599074, 0.65087825, 0.5492535 , 0.34900412],
#        [0.6679852 , 0.87561965, 0.57751465, 0.3833582 , 0.38703394,
#         0.4876661 , 0.7269859 , 0.6169708 , 0.4062345 ],
#        [0.730582  , 0.94184995, 0.62281585, 0.43356597, 0.4219854 ,
#         0.5499019 , 0.7913161 , 0.66584486, 0.4321933 ],
#        [0.7747114 , 0.9466326 , 0.68600845, 0.48395908, 0.48662955,
#         0.6222368 , 0.8500897 , 0.7208594 , 0.5027559 ],
#        [0.82975006, 0.9786571 , 0.74544007, 0.5550033 , 0.54028136,
#         0.67984945, 0.8987881 , 0.77871525, 0.5749916 ],
#        [0.8736967 , 0.9986379 , 0.7919685 , 0.6078508 , 0.6105256 ,
#         0.73104125, 0.94114923, 0.81559455, 0.6469263 ]], dtype=float32)

# %%
prediction_unscaled_train = scaler_prediction.inverse_transform(predictions_train)

predicted_train_df = pd.DataFrame(prediction_unscaled_train, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_train_df['year'] = [x for x in range(2003, 2016)]
predicted_train_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1402.927612  ...  2003
# 1                     1589.940796  ...  2004
# 2                     1803.019409  ...  2005
# 3                     1959.018799  ...  2006
# 4                     2134.413574  ...  2007
# 5                     2272.947021  ...  2008
# 6                     2333.110840  ...  2009
# 7                     2482.661133  ...  2010
# 8                     2618.720947  ...  2011
# 9                     2767.717285  ...  2012
# 10                    2872.756104  ...  2013
# 11                    3003.762207  ...  2014
# 12                    3108.366211  ...  2015
#
# [13 rows x 10 columns]

# %% [markdown]
# **Predict the test dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Testdatensatzes für die Verlustberechnung**

# %%
# predict the test data which is from 2016 to 2019
x_input = X_test.reshape((-1, n_input))
predictions = model_2.predict(x_input)
predictions
# Out:
# array([[0.91130126, 1.011496  , 0.8341849 , 0.6575167 , 0.6575278 ,
#         0.7799767 , 0.9665311 , 0.8514225 , 0.7137654 ],
#        [0.9416069 , 1.0072162 , 0.87636244, 0.71541566, 0.7230076 ,
#         0.82683134, 0.9829376 , 0.8819241 , 0.7977273 ],
#        [0.98831475, 1.0358753 , 0.9257636 , 0.8052569 , 0.797456  ,
#         0.90505004, 1.0336077 , 0.92347026, 0.86944455],
#        [1.0389563 , 1.057453  , 0.9813356 , 0.8739498 , 0.86771095,
#         0.9802561 , 1.0836877 , 0.95893323, 0.9197572 ]], dtype=float32)

# %%
# convert back the predicted value to original format
prediction_unscaled_test = scaler_prediction.inverse_transform(predictions)

# arrange the valus in a dataframe
predicted_test_df = pd.DataFrame(prediction_unscaled_test, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_test_df['year'] = [x for x in range(2016, 2020)]
predicted_test_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3197.874512            1991.403809  ...      73594.882812  2016
# 1                    3270.009521            1985.983765  ...      81072.406250  2017
# 2                    3381.186035            2022.279175  ...      87459.437500  2018
# 3                    3501.725586            2049.606445  ...      91940.203125  2019
#
# [4 rows x 10 columns]

# %% [markdown]
# **Calculate loss for testing data**
#
# **Deutsch:**
#
# **Verlustberechnung für Testdaten**

# %%
# create  the functions of mean absolute percentage error (MAPE) and root mean squared error (RMSE)
def mean_absolute_percentage_error(y_true, y_prediction): 
    y_true, y_prediction = np.array(y_true), np.array(y_prediction)
    return np.mean(np.abs((y_true - y_prediction) / y_true)) * 100

def root_mean_squared_error(y_true, y_prediction):
    mse = mean_squared_error(y_true, y_prediction)
    rmse = np.sqrt(mse)
    return rmse

# %%
# create a function of generating all the relevant errors
def calculate_performance(y_true, y_prediction):
    MSE = mean_squared_error(y_true, y_prediction)
    MAE = mean_absolute_error(y_true, y_prediction)
    MAPE = mean_absolute_percentage_error(y_true, y_prediction)
    RMSE = root_mean_squared_error(y_true, y_prediction)
    return round(MSE, 3), round(MAE, 3), round(MAPE, 3), round(RMSE, 3)

# %%
# rearrange the shape of test data's input for  inputing in the model
x_input2 = X_test.reshape((-1, n_input))
actual_arr=input_df.iloc[16:20,:].to_numpy()

# Get the predicted values
predictions = model_2.predict(x_input2)
prediction_unscaled2 = scaler_prediction.inverse_transform(predictions)

MSE, MAE, MAPE, RMSE = calculate_performance(actual_arr, prediction_unscaled2)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 2134044.708
# Mean Absolute Error (MAE): 456.333
# Mean Absolute Percentage Error (MAPE): 4.17 %
# Root Mean Squared Error (RMSE): 1460.837

# %% [markdown]
# **Calculate loss of total energy consumption for prediction against actual values** (total energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Gesamtenergieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tec=predicted_test_df.iloc[:,0].to_numpy()
actual_tec=input_df.iloc[16:20,0].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tec, predicted_tec)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 8113.561
# Mean Absolute Error (MAE): 89.272
# Mean Absolute Percentage Error (MAPE): 2.76 %
# Root Mean Squared  Error (RMSE): 90.075

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tec)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tec)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtenergieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of coal consumption for prediction against actual values** (Coal consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Kohleverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_cc=predicted_test_df.iloc[:,1].to_numpy()
actual_cc=input_df.iloc[16:20,1].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_cc, predicted_cc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 9275.22
# Mean Absolute Error (MAE): 95.939
# Mean Absolute Percentage Error (MAPE): 5.01 %
# Root Mean Squared  Error (RMSE): 96.308

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_cc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_cc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Kohleverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of oil consumption for prediction against actual values** (Oil consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdölverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_oc=predicted_test_df.iloc[:,2].to_numpy()
actual_oc=input_df.iloc[16:20,2].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_oc, predicted_oc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 36.759
# Mean Absolute Error (MAE): 5.073
# Mean Absolute Percentage Error (MAPE): 0.79 %
# Root Mean Squared  Error (RMSE): 6.063

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_oc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_oc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdölverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of natural gas consumption for prediction against actual values** (Natural gas consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdgasverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gc=predicted_test_df.iloc[:,3].to_numpy()
actual_gc=input_df.iloc[16:20,3].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gc, predicted_gc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 443.392
# Mean Absolute Error (MAE): 17.398
# Mean Absolute Percentage Error (MAPE): 7.07 %
# Root Mean Squared  Error (RMSE): 21.057

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdgasverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of non fossil energy consumption for prediction against actual values** (non fossil energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des nichtfossilen Energieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_nfc=predicted_test_df.iloc[:,4].to_numpy()
actual_nfc=input_df.iloc[16:20,4].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_nfc, predicted_nfc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 1856.216
# Mean Absolute Error (MAE): 41.393
# Mean Absolute Percentage Error (MAPE): 9.27 %
# Root Mean Squared  Error (RMSE): 43.084

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_nfc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_nfc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("nichtfossile Energieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of energy imports for prediction against actual values** (energy imports)
#
# **Deutsch:**
#
# **Verlustberechnung der Energieeinfuhr für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_imp=predicted_test_df.iloc[:,5].to_numpy()
actual_imp=input_df.iloc[16:20,5].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_imp, predicted_imp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 1556.622
# Mean Absolute Error (MAE): 31.719
# Mean Absolute Percentage Error (MAPE): 4.28 %
# Root Mean Squared  Error (RMSE): 39.454

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_imp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_imp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Energieeinfuhr (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of tpes for prediction against actual values** (total primary energy supply)
#
# **Deutsch:**
#
# **Verlustberechnung der Gesamtprimärenergieversorgung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tpes=predicted_test_df.iloc[:,6].to_numpy()
actual_tpes=input_df.iloc[16:20,6].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tpes, predicted_tpes)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 17114.69
# Mean Absolute Error (MAE): 123.763
# Mean Absolute Percentage Error (MAPE): 4.0 %
# Root Mean Squared  Error (RMSE): 130.823

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tpes)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tpes)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtprimärenergieversorgung (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of population for prediction against actual values** (population)
#
# **Deutsch:**
#
# **Verlustberechnung der Bevölkerung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_pop=predicted_test_df.iloc[:,7].to_numpy()
actual_pop=input_df.iloc[16:20,7].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_pop, predicted_pop)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 24.411
# Mean Absolute Error (MAE): 4.745
# Mean Absolute Percentage Error (MAPE): 0.34 %
# Root Mean Squared  Error (RMSE): 4.941

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_pop)
ax1.plot(predicted_test_df.iloc[:,-1], actual_pop)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bevölkerung (Millionen)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of GDP for prediction against actual values** (GDP)
#
# **Deutsch:**
#
# **Verlustberechnung des Bruttoinlandsprodukts für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gdp=predicted_test_df.iloc[:,8].to_numpy()
actual_gdp=input_df.iloc[16:20,8].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gdp, predicted_gdp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 19167981.5
# Mean Absolute Error (MAE): 3697.698
# Mean Absolute Percentage Error (MAPE): 4.01 %
# Root Mean Squared  Error (RMSE): 4378.125

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gdp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gdp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bruttoinlandsprodukt (Milliarden Yuan)", fontsize=18)

plt.show()

# %% [markdown]
# **Make future predictions**
#
# Predict the value of the next six years
#
# **Deutsch:**
#
# **Zukunftsprognosen erstellen**
#
# Vorhersage des Wertes für die nächsten sechs Jahre

# %%
# extract last three rows from dataset
temp_input=final_df[-3:].tolist()

# %%
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999]]

# %%
predicted_consumption_output =[]
for i in range(6):
  # Get the last 3 year consumption values and scale the data to be values between 0 and 1
  last_5_years = np.array(temp_input[-3:])
  last_5_years_scaled = last_5_years.reshape(-1, n_input)
  # Create an empty list and Append past 5 years
  X_test_new = []
  X_test_new.append(last_5_years_scaled)
  # Convert the X_test data set to a numpy array and reshape the data
  prediction_consumption_scaled = model_2.predict(X_test_new)
  temp_input.extend(prediction_consumption_scaled.tolist())
  predicted_consumption_output.extend(prediction_consumption_scaled.tolist())

# %%
# add new predicted values into temp_input list
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999],
#  [1.078506588935852,
#   1.1015774011611938,
#   1.0205378532409668,
#   0.9203643798828125,
#   0.9234514832496643,
#   1.0344972610473633,
#   1.146363377571106,
#   0.9998195767402649,
#   0.9665470719337463],
#  [1.1785989999771118,
#   1.2018059492111206,
#   1.092320442199707,
#   0.9590848684310913,
#   0.9572893977165222,
#   1.1494553089141846,
#   1.2372668981552124,
#   1.0539928674697876,
#   1.0241411924362183],
#  [1.2346689701080322,
#   1.2788045406341553,
#   1.1500025987625122,
#   1.0262832641601562,
#   1.0339741706848145,
#   1.210007667541504,
#   1.3026326894760132,
#   1.1192915439605713,
#   1.1087744235992432],
#  [1.2443180084228516,
#   1.2703635692596436,
#   1.1717473268508911,
#   1.0465443134307861,
#   1.0419254302978516,
#   1.202770709991455,
#   1.3226499557495117,
#   1.1217998266220093,
#   1.1031486988067627],
#  [1.2935960292816162,
#   1.2918998003005981,
#   1.2050591707229614,
#   1.043498158454895,
#   1.0481902360916138,
#   1.2301430702209473,
#   1.372067928314209,
#   1.1591178178787231,
#   1.1431066989898682],
#  [1.377084493637085,
#   1.3767759799957275,
#   1.2556649446487427,
#   1.1176416873931885,
#   1.1179395914077759,
#   1.3131475448608398,
#   1.428301215171814,
#   1.2183200120925903,
#   1.223793864250183]]

# %%
# rename temp_input into prediction_arr
prediction_arr = np.array(temp_input)

# %%
prediction_arr
# Out:
# array([[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#         0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#        [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#         1.        , 1.        , 0.96478661, 0.91962137],
#        [1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.        ],
#        [1.07850659, 1.1015774 , 1.02053785, 0.92036438, 0.92345148,
#         1.03449726, 1.14636338, 0.99981958, 0.96654707],
#        [1.178599  , 1.20180595, 1.09232044, 0.95908487, 0.9572894 ,
#         1.14945531, 1.2372669 , 1.05399287, 1.02414119],
#        [1.23466897, 1.27880454, 1.1500026 , 1.02628326, 1.03397417,
#         1.21000767, 1.30263269, 1.11929154, 1.10877442],
#        [1.24431801, 1.27036357, 1.17174733, 1.04654431, 1.04192543,
#         1.20277071, 1.32264996, 1.12179983, 1.1031487 ],
#        [1.29359603, 1.2918998 , 1.20505917, 1.04349816, 1.04819024,
#         1.23014307, 1.37206793, 1.15911782, 1.1431067 ],
#        [1.37708449, 1.37677598, 1.25566494, 1.11764169, 1.11793959,
#         1.31314754, 1.42830122, 1.21832001, 1.22379386]])

# %%
# transform the predicted value back to original form
prediction_unscaled = scaler_prediction.inverse_transform(prediction_arr)

# %%
predicted_consumption = prediction_unscaled.ravel()

# %%
predicted_consumption
# Out:
# array([  3190.789     ,   1899.7842638 ,    632.53951563,    209.41927228,
#           414.00076415,    700.273     ,   3064.9       ,   1390.08      ,
#         83203.59      ,   3303.475     ,   1912.9999275 ,    657.07314703,
#           245.92728745,    457.90272932,    775.509     ,   3196.42      ,
#          1395.38      ,  91928.11      ,   3409.        ,   1956.94088451,
#           687.29351129,    266.93887425,    502.87504711,    775.509     ,
#          3196.42      ,   1400.05      ,  99086.51      ,   3595.86546533,
#          2105.48782004,    696.49969086,    247.56472226,    468.81067846,
#           799.00894819,   3498.88723792,   1400.02607227,  96107.24240581,
#          3834.11062689,   2232.42254438,    728.67653992,    256.98483639,
#           483.8686736 ,    877.3197499 ,   3686.74390838,   1407.21053408,
#        101236.48838658,   3967.57128544,   2329.93762534,    754.53281054,
#           273.33319822,    517.99367676,    918.56874322,   3821.82558444,
#          1415.87044456, 108773.79700411,   3990.53842818,   2319.24753359,
#           764.27997686,    278.26240763,    521.53201624,    913.63884089,
#          3863.19226605,   1416.20309301, 108272.77839268,   4107.83253589,
#          2346.52215348,    779.21215175,    277.52132381,    524.31987763,
#           932.28522115,   3965.31697726,   1421.15220501, 111831.37795199,
#          4306.55612015,   2454.01382808,    801.89640392,    295.55933239,
#           555.35859469,    988.82886533,   4081.52587621,   1429.0036    ,
#        119017.25585932])

# %%
# reshape into proper format
predicted_consumption= predicted_consumption.reshape(-1,9)

# %%
predicted_consumption.shape
# Out:
# (9, 9)

# %% [markdown]
# **Table of actual values from 2017 to 2019 & prediction values from 2020 to 2025**
#
# **Deutsch:**
#
# **Tabelle mit realen Werten zwischen 2017 und 2019 sowie Vorhersagewerten zwischen 2020 und 2025**

# %%
# add column names and convert into dataframe for preparation of visualisation
prediction_df=pd.DataFrame(predicted_consumption ,columns=['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
prediction_df
# Out:
#    total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                    3190.789000  ...      83203.590000
# 1                    3303.475000  ...      91928.110000
# 2                    3409.000000  ...      99086.510000
# 3                    3595.865465  ...      96107.242406
# 4                    3834.110627  ...     101236.488387
# 5                    3967.571285  ...     108773.797004
# 6                    3990.538428  ...     108272.778393
# 7                    4107.832536  ...     111831.377952
# 8                    4306.556120  ...     119017.255859
#
# [9 rows x 9 columns]

# %% [markdown]
# **Preparation of predicted values for visualisation**
#
# **Deutsch:**
#
# **Aufbereitung der Vorhersagewerte für die Visualisierung**

# %%
# Generate list of sequence of days for predictions
year_range = range(2017,2026)

yearlist_predict = []

for y in year_range:
  yearlist_predict.append(y)

# %%
# Generate list of sequence of days for predictions
year_range = range(2000,2020)

yearlist_main = []

for y in year_range:
  yearlist_main.append(y)

# %%
# preparation for combination it to original dataset copies
prediction_df['year']=yearlist_predict
prediction_df.head()
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3190.789000            1899.784264  ...      83203.590000  2017
# 1                    3303.475000            1912.999927  ...      91928.110000  2018
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3595.865465            2105.487820  ...      96107.242406  2020
# 4                    3834.110627            2232.422544  ...     101236.488387  2021
#
# [5 rows x 10 columns]

# %%
# make a copy from input_df and add a year column
energy_consumption_df = input_df.loc[:, :]
energy_consumption_df['year']=yearlist_main
energy_consumption_df.tail()
# Out:
#     total_energy_consumption_mtoe  ...  year
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [5 rows x 10 columns]

# %%
target_df=prediction_df.iloc[5:,:]
target_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 5                    3967.571285            2329.937625  ...     108773.797004  2022
# 6                    3990.538428            2319.247534  ...     108272.778393  2023
# 7                    4107.832536            2346.522153  ...     111831.377952  2024
# 8                    4306.556120            2454.013828  ...     119017.255859  2025
#
# [4 rows x 10 columns]

# %%
# this is the prediction dataframe between 2019 and 2025
visual_df=prediction_df.iloc[2:,:]
visual_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3595.865465            2105.487820  ...      96107.242406  2020
# 4                    3834.110627            2232.422544  ...     101236.488387  2021
# 5                    3967.571285            2329.937625  ...     108773.797004  2022
# 6                    3990.538428            2319.247534  ...     108272.778393  2023
# 7                    4107.832536            2346.522153  ...     111831.377952  2024
# 8                    4306.556120            2454.013828  ...     119017.255859  2025
#
# [7 rows x 10 columns]

# %% [markdown]
# **Combination of original dataset and prediction table**
#
# **Deutsch:**
#
# **Zusammensetzung des originalen Datensatz und der Vorhersagetabelle**

# %%
# append the predicted dataframe to the original dataset copies
combined_energy_consumption_df= pd.concat([energy_consumption_df, prediction_df.iloc[3:,:]], axis=0)
combined_energy_consumption_df.reset_index(drop=True, inplace=True)
combined_energy_consumption_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1028.748000  ...  2000
# 1                     1088.829000  ...  2001
# 2                     1187.039000  ...  2002
# 3                     1379.581000  ...  2003
# 4                     1611.967000  ...  2004
# 5                     1829.583000  ...  2005
# 6                     2005.269000  ...  2006
# 7                     2180.094000  ...  2007
# 8                     2244.277000  ...  2008
# 9                     2352.882000  ...  2009
# 10                    2524.536000  ...  2010
# 11                    2709.301000  ...  2011
# 12                    2814.966000  ...  2012
# 13                    2918.391000  ...  2013
# 14                    2998.338000  ...  2014
# 15                    3038.791000  ...  2015
# 16                    3090.444000  ...  2016
# 17                    3190.789000  ...  2017
# 18                    3303.475000  ...  2018
# 19                    3409.000000  ...  2019
# 20                    3595.865465  ...  2020
# 21                    3834.110627  ...  2021
# 22                    3967.571285  ...  2022
# 23                    3990.538428  ...  2023
# 24                    4107.832536  ...  2024
# 25                    4306.556120  ...  2025
#
# [26 rows x 10 columns]

# %% [markdown]
# **Visualise the prediction**
#
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Gesamtenergieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['total_energy_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Gesamtenergieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,0], color='g', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,0], color='y', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Trainingdaten)')
#plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['Energy_consumption'], color='orange', label='Training predictions')
#plt.plot(input_df.iloc[:,-1], input_df.iloc[:, 0], color='b', label='Actual Energy Consumption')
plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,0], color='b', marker='x', label='Ist-Gesamtenergieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')
#plt.axvline(x = min(target_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Gesamtenergieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Kohleverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['coal_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Kohleverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,1], color='g', marker='x', label='Vorhersage - Kohleverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,1], color='y', marker='x', label='Vorhersage - Kohleverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,1], color='b', marker='x', label='Ist-Kohleverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Kohleverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Kohleverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdölverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['oil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdölverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,2], color='g', marker='x', label='Vorhersage - Erdölverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,2], color='y', marker='x', label='Vorhersage - Erdölverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,2], color='b', marker='x', label='Ist-Erdölverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdölverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdölverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdgasverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['gas_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdgasverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,3], color='g', marker='x', label='Vorhersage - Erdgasverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,3], color='y', marker='x', label='Vorhersage - Erdgasverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,3], color='b', marker='x', label='Ist-Erdgasverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdgasverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdgasverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Nichtfossiler Energieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['non_fossil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger nichtfossile Energieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,4], color='g', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,4], color='y', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,4], color='b', marker='x', label='Ist-Nichtfossiler Energieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Nichtfossile Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Nichtfossiler Energieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
