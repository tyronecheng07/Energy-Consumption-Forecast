# %% [markdown]
# <a href="https://colab.research.google.com/github/tyronecheng07/Energy-Consumption-Forecast/blob/main/LSTM_model_single_layer_energy_consumption_forecast_china.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Total Energy Consumption Forecast of China - LSTM-Model Single Layer  Multivariate**
#
# ##**Goal and Description**
# A good prediction of the energy data allows stateholders, researcher and politician make better decision and to be well informed with the future possible scenarios. The main focus of this study is to forecast the total energy consumption of China for the next 6 years. Using a set of different variables as inputs and the energy consumption as output with a period of 20 years from 2000 to 2019 to perform the timeseries forecasting.
#
# **Deutsch:**
# #**Vorhersage des Gesamtenergieverbrauchs Chinas- LSTM-Modell (1 Schicht) Multivariate**
#
# ##**Zielsetzung und Beschreibung**
#
# Eine gute Vorhersage der Energiedaten ermöglicht es Entscheidungsträgern, Forschern und auch Politikern, bessere Entscheidungen zu treffen und über die möglichen zukünftigen Entwicklungen gut informiert zu sein. Das Schwerpunktthema dieser Studie ist die Vorhersage des Gesamtenergieverbrauchs von China für die nächsten 6 Jahre. Die Zeitreihenprognose wird mit einer Reihe von verschiedenen Variablen als Eingaben und dem Energieverbrauch als Ausgabe mit einem Zeitraum von 20 Jahren von 2000 bis 2019 durchgeführt.

# %% [markdown]
# Prepared by Kuan Yew Cheng, 2021
#
# Raw data collected from China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# and from the database: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics and https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
#
# **Deutsch:**
#
# Vorbereitet von Kuan Yew Cheng, 2021
#
# Rohdaten entnommen aus China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# auch von der Datenbank: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics und https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html

# %% [markdown]
# **Import the libraries**
#
# **Deutsch:**
#
# **Importieren der Pythonbibliotheken**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import TimeDistributed
from tensorflow.keras.layers import Dropout
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.layers.core import Activation
import tensorflow as tf
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras import backend
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import LeakyReLU
from keras.backend import set_epsilon
from scipy.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# **Convert data from Excel worksheet to CSV format**
#
# **Deutsch:**
#
# **Konvertieren von Daten aus einem Excel-Arbeitsblatt in das CSV-Format**

# %%
#energy_df = pd.read_excel('Energy_Dataset_China.xlsx', sheet_name=None)
#energy_df['for_processing4'].to_csv('final_energy_data_4.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
energy_df = pd.read_excel('/content/drive/MyDrive/Energy China/Dataset for Bachelorarbeit/Energy_Dataset_China.xlsx', sheet_name=None)
energy_df['for_processing4'].to_csv('final_energy_data_4.csv')

# %% [markdown]
# **Reading and preprocessing the CSV file**
#
# **Deutsch:**
#
# **Lesen und Vorverarbeiten der CSV-Datei**

# %%
energy_df = pd.read_csv('final_energy_data_4.csv', index_col=[0])

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Dataset of total energy Consumption(Mtoe) and other variables of China**
#
# **Deutsch:**
#
# **Datensatz des Gesamtenergieverbrauchs (Mtoe) und anderer Variablen von China**

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           20 non-null     int64
#  1   total_energy_consumption_mtoe  20 non-null     float64
#  2   coal_consumption_mtoe          20 non-null     float64
#  3   oil_consumption_mtoe           20 non-null     float64
#  4   gas_consumption_mtoe           20 non-null     float64
#  5   non_fossil_consumption_mtoe    20 non-null     float64
#  6   imports_mtoe                   20 non-null     float64
#  7   tpes_mtoe                      20 non-null     float64
#  8   population_million             20 non-null     float64
#  9   gdp_billion_yuan               20 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 1.7 KB

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualise data of years against each column**
#
# **Deutsch:**
#
# **Visualisierung der Jahresdaten gegenüber jeder Spalte**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']


plt.figure()
plt.title("total_energy_consumption_mtoe 2000 to 2019")
plt.plot(x, y1, 'g-')
plt.xlabel("Years")
plt.ylabel("Energy comsumption mtoe")

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")

plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.show()

# %% [markdown]
# Comment: Some of the plots showed abnormal drops since there were missing values in the dataset which displayed as 0.
#
# **Deutsch:**
#
# Kommentar: Einige der Grafiken zeigten abnormale Absenkungen, da es fehlende Werte im Datensatz gab, die als 0 angezeigt wurden.

# %% [markdown]
# **Arrange the columns**
#
# Shifting the ***year*** column to the last column and adding a new column ***prediction*** into the energy_df
#
# **Deutsch:**
#
# **Anordnen der Spalten**
#
# Verschieben der **Jahres**-Spalte in die letzte Spalte und Hinzufügung einer neuen **Vorhersage**-spalte in der energy_df

# %%
features = ['total_energy_consumption_mtoe', 'coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe', 'imports_mtoe','tpes_mtoe', 'population_million', 'gdp_billion_yuan', 'year']
energy_df = energy_df[features]
energy_df_ext = energy_df.copy()
energy_df_ext['prediction'] = energy_df_ext['total_energy_consumption_mtoe']
energy_df_ext.tail()
# Out:
#     total_energy_consumption_mtoe  coal_consumption_mtoe  ...  year  prediction
# 15                       3038.791            1920.657806  ...  2015    3038.791
# 16                       3090.444            1895.791743  ...  2016    3090.444
# 17                       3190.789            1899.784264  ...  2017    3190.789
# 18                       3303.475            1912.999927  ...  2018    3303.475
# 19                       3409.000            1956.940885  ...  2019    3409.000
#
# [5 rows x 11 columns]

# %% [markdown]
# **Check zero values**
#
# **Deutsch:**
#
# **0-werte überprüfen**

# %%
energy_df.isin([0]).sum()
# Out:
# total_energy_consumption_mtoe    0
# coal_consumption_mtoe            0
# oil_consumption_mtoe             0
# gas_consumption_mtoe             0
# non_fossil_consumption_mtoe      0
# imports_mtoe                     1
# tpes_mtoe                        1
# population_million               0
# gdp_billion_yuan                 0
# year                             0
# dtype: int64

# %% [markdown]
# **Replace the zero values with null**
#
# **Deutsch:**
#
# **Ersetzen Sie die 0-Werte durch Nullwerte**

# %%
cols = ["imports_mtoe","tpes_mtoe"]
energy_df[cols] = energy_df[cols].replace(['0', 0], np.nan)

# %% [markdown]
# **Interpolate the missing values by using linear interpolation**
#
# **Deutsch:**
#
# **Interpolierung der fehlenden Werte mit Hilfe der linearen Interpolation**

# %%
energy_df.interpolate(method='linear', limit_direction ='both', inplace=True)

energy_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                        1028.748  ...  2000
# 1                        1088.829  ...  2001
# 2                        1187.039  ...  2002
# 3                        1379.581  ...  2003
# 4                        1611.967  ...  2004
# 5                        1829.583  ...  2005
# 6                        2005.269  ...  2006
# 7                        2180.094  ...  2007
# 8                        2244.277  ...  2008
# 9                        2352.882  ...  2009
# 10                       2524.536  ...  2010
# 11                       2709.301  ...  2011
# 12                       2814.966  ...  2012
# 13                       2918.391  ...  2013
# 14                       2998.338  ...  2014
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualize data of years against each column after interpolation**
#
# **Deutsch:**
#
# **Visualisierung der Daten von Jahren gegenüber jeder Spalte nach der Interpolation**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']

plt.figure()
plt.title("total_energy_consumption_mtoe 2000 to 2019")
plt.plot(x, y1, 'g-')
plt.xlabel("Years")
plt.ylabel("Energy comsumption mtoe")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")

plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.show()

# %% [markdown]
# **Check Correlations**
#
# **Deutsch:**
#
# **Korrelationen prüfen**

# %%
pearsoncorr = energy_df.corr(method='pearson')
pearsoncorr
# Out:
#                                total_energy_consumption_mtoe  ...      year
# total_energy_consumption_mtoe                       1.000000  ...  0.987076
# coal_consumption_mtoe                               0.967508  ...  0.915922
# oil_consumption_mtoe                                0.982699  ...  0.997376
# gas_consumption_mtoe                                0.930097  ...  0.971747
# non_fossil_consumption_mtoe                         0.919665  ...  0.968318
# imports_mtoe                                        0.957505  ...  0.986707
# tpes_mtoe                                           0.997467  ...  0.981646
# population_million                                  0.989195  ...  0.999361
# gdp_billion_yuan                                    0.945927  ...  0.982514
# year                                                0.987076  ...  1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# **Correlation Matrix with Pearson coefficient**
#
# **Deutsch:**
#
# **Korrelations-Matrix mit Pearson-Korrelationskoeffizient**

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# **Calculation of P-value**
#
# **Deutsch:**
#
# **Berechnung vom P-Wert**

# %%
def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 12)
    return pvalues

# %%
calculate_pvalues(energy_df)
# Out:
#                               total_energy_consumption_mtoe  ...        year
# total_energy_consumption_mtoe                             0  ...           0
# coal_consumption_mtoe                                 3e-12  ...  1.4652e-08
# oil_consumption_mtoe                                      0  ...           0
# gas_consumption_mtoe                              2.932e-09  ...       1e-12
# non_fossil_consumption_mtoe                       9.861e-09  ...       3e-12
# imports_mtoe                                        3.7e-11  ...           0
# tpes_mtoe                                                 0  ...           0
# population_million                                        0  ...           0
# gdp_billion_yuan                                   3.08e-10  ...           0
# year                                                      0  ...           0
#
# [10 rows x 10 columns]

# %% [markdown]
# All the values are with a  p-value < 0.01, the variables are statistically significant and the null hypothese can be rejected
#
# **Deutsch:**
#
# Alle Werte wurden mit dem P-Wert < 0,01 berechnet. Dieses Variablen waren statistisch signifikant und die Nullhypothese lässt sich ablehnen.

# %% [markdown]
# **Create a new DataFrame without exports_mtoe and year**
#
# **Deutsch:**
#
# **Erstellung eines neuen DataFrames ohne exports_mtoe und Jahr**

# %%
input_df = energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']]

# %%
input_df
# Out:
#     total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                        1028.748  ...          10028.01
# 1                        1088.829  ...          11086.31
# 2                        1187.039  ...          12171.74
# 3                        1379.581  ...          13742.20
# 4                        1611.967  ...          16184.02
# 5                        1829.583  ...          18731.89
# 6                        2005.269  ...          21943.85
# 7                        2180.094  ...          27009.23
# 8                        2244.277  ...          31924.46
# 9                        2352.882  ...          34851.77
# 10                       2524.536  ...          41211.93
# 11                       2709.301  ...          48794.02
# 12                       2814.966  ...          53858.00
# 13                       2918.391  ...          59296.32
# 14                       2998.338  ...          64356.31
# 15                       3038.791  ...          68885.82
# 16                       3090.444  ...          74639.51
# 17                       3190.789  ...          83203.59
# 18                       3303.475  ...          91928.11
# 19                       3409.000  ...          99086.51
#
# [20 rows x 9 columns]

# %% [markdown]
# **Display our feature column: total_energy_consumption_mtoe**
#
# **Deutsch:**
#
# **Feature-Spalte anzeigen: total_energy_consumption_mtoe**

# %%
input_df.iloc[:,0]
# Out:
# 0     1028.748
# 1     1088.829
# 2     1187.039
# 3     1379.581
# 4     1611.967
# 5     1829.583
# 6     2005.269
# 7     2180.094
# 8     2244.277
# 9     2352.882
# 10    2524.536
# 11    2709.301
# 12    2814.966
# 13    2918.391
# 14    2998.338
# 15    3038.791
# 16    3090.444
# 17    3190.789
# 18    3303.475
# 19    3409.000
# Name: total_energy_consumption_mtoe, dtype: float64

# %%
input_df.iloc[:,-1]
# Out:
# 0     10028.01
# 1     11086.31
# 2     12171.74
# 3     13742.20
# 4     16184.02
# 5     18731.89
# 6     21943.85
# 7     27009.23
# 8     31924.46
# 9     34851.77
# 10    41211.93
# 11    48794.02
# 12    53858.00
# 13    59296.32
# 14    64356.31
# 15    68885.82
# 16    74639.51
# 17    83203.59
# 18    91928.11
# 19    99086.51
# Name: gdp_billion_yuan, dtype: float64

# %% [markdown]
# **Basic Statistics**
#
# **Deutsch:**
#
# **Basis-Statistik**

# %%
input_df.describe()
# Out:
#        total_energy_consumption_mtoe  ...  gdp_billion_yuan
# count                      20.000000  ...         20.000000
# mean                     2345.315000  ...      44146.680000
# std                       777.438682  ...      28823.738016
# min                      1028.748000  ...      10028.010000
# 25%                      1775.179000  ...      18094.922500
# 50%                      2438.709000  ...      38031.850000
# 75%                      3008.451250  ...      65488.687500
# max                      3409.000000  ...      99086.510000
#
# [8 rows x 9 columns]

# %% [markdown]
# **Feature Scaling: Min Max Scaling**
#
# **Deutsch:**
#
# **Feature-Skalierung: Min Max Scaling**

# %%
# Calculate the number of rows in the data
nrows = input_df.shape[0]
input_df_unscaled = np.array(input_df)
input_df_unscaled = np.reshape(input_df_unscaled, (nrows, -1))
print(input_df_unscaled.shape)

#Feature Scaling
# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
final_df = scaler.fit_transform(input_df_unscaled)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_prediction = MinMaxScaler()
#consumption_df = pd.DataFrame(energy_df_ext['total_energy_consumption_mtoe'])
consumption_df = pd.DataFrame(energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']])
consumption_df_scaled = scaler_prediction.fit_transform(consumption_df)
# Out:
# (20, 9)

# %%
final_df[:,0]
# Out:
# array([0.        , 0.02524145, 0.06650178, 0.14739322, 0.24502406,
#        0.33644967, 0.4102595 , 0.48370761, 0.5106724 , 0.55629992,
#        0.62841581, 0.70603995, 0.75043231, 0.79388359, 0.82747121,
#        0.84446647, 0.86616711, 0.90832441, 0.95566646, 1.        ])

# %% [markdown]
# **Convert into a supervised learning problem**
#
# **Deutsch:**
#
# **In ein Format des überwachten Lernens umwandeln**

# %%
###
*    Dieser Teil des Codes geändert aus dem ipynb-Dokument von JonJae:
*    Titel: FeedInMngmt_LSTM_NN
*    Autor: JonJae
*    Datum: 2020
*    Verfügbarkeit: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb
*   (Quelle: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb abgerufen am Februar 2021)
###

#Global Settings
sequence_length = 3   # Number of past years that we want to predict the future values
n_out = 1            # Number of years that we wamt to forecast into the future

# Split the training data into x_train and y_train data sets
# Get the number of rows to train the model on 80% of the data 
train_data_len = math.ceil(final_df.shape[0] * 0.8) #16 train data point

# Create the training data
train_data = final_df[0:train_data_len, :]
X_train, y_train = [], []
in_start = 0
# step over the entire history five time step at a time
for _ in range(train_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(train_data):
		X_train.append(train_data[in_start:in_end, :])
		y_train.append(train_data[in_end:out_end, :])
	# move along one batch
	in_start += 1
    
# Convert the X_train and y_train into numpy arrays
X_train, y_train = np.array(X_train), np.array(y_train)

# Create the test data
test_data = final_df[train_data_len - sequence_length:, :]

# Seperate the test data into X_test and y_test
X_test, y_test = [], []
test_data_len = test_data.shape[0]
in_start = 0
# step over the entire history three time step at a time
for _ in range(test_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(test_data):
		X_test.append(test_data[in_start:in_end, :])
		y_test.append(test_data[in_end:out_end, :])
	# move along one batch
	in_start += 1

X_test, y_test = np.array(X_test), np.array(y_test)

# Convert the X_train and y_train to numpy arrays
X_test = np.array(X_test); y_test = np.array(y_test)
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13, 3, 9) (13, 1, 9)
# (4, 3, 9) (4, 1, 9)

# %% [markdown]
# **Take a look on test and train data after transformation**
#
# **Deutsch:**
#
# **Schauen wir nun, wie die Training- und Testdaten nach der Transformation aussiehen.**

# %%
X_train
# Out:
# array([[[0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.00879609, 0.        , 0.        , 0.        ],
#         [0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103]],
#
#        [[0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]]])

# %%
y_train
# Out:
# array([[[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]]])

# %%
X_test
# Out:
# array([[[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#         [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]]])

# %% [markdown]
# **Let's see how y_test looks like**
#
# **Deutsch:**
#
# **Schauen wir uns an, wie y_test aussieht**

# %%
y_test
# Out:
# array([[[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]],
#
#        [[1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#          1.        , 1.        , 1.        , 1.        ]]])

# %% [markdown]
# **Build the LSTM Model**
#
# **Deutsch:**
#
# **Aufbau des LSTM-Modells**

# %%
# set the denominator of mape function permanently as 1 to ensure mathematical operation error free 
set_epsilon(1)

# define model
model = Sequential()

# Custom fuction of root mean square error
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# Initializing the Neural Network based on LSTM
# Adding 1st LSTM layer
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh',
               return_sequences=False))
# Adding Dropout
model.add(Dropout(0.2))

# Adding 2nd LSTM layer
#model.add(LSTM(70, return_sequences=False, activation='tanh')) 
# Adding Dropout
#model.add(Dropout(0.26))

# Adding 3rd LSTM layer
#model.add(LSTM(9, activation='tanh', return_sequences=False)) 
# Adding Dropout
#model.add(Dropout(0.24))

#model.add(TimeDistributed(Dense(30)))
#model.add(Dropout(0.23))
#model.add(Activation('relu'))
#model.add(LeakyReLU(alpha=0.3))
#model.add(Dense(15, activation='relu'))

# Output layer
model.add(Dense(9))

#model.add(Dense(n_steps_out, activation='relu'))

# Compiling the Neural Network
model.compile(optimizer=Adam(learning_rate=0.001), loss=rmse, metrics='mean_absolute_percentage_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50)                12000
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 9)                 459
# =================================================================
# Total params: 12,459
# Trainable params: 12,459
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Start training with max 2000 epochs**
#
# **Deutsch:**
#
# **Training mit max. 2000 Epochen**

# %%
epochs = 2000
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=120, restore_best_weights=True)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),  batch_size=2,
                    epochs=epochs, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/2000
# 7/7 [==============================] - 3s 172ms/step - loss: 0.3615 - mean_absolute_percentage_error: 32.7132 - val_loss: 0.8817 - val_mean_absolute_percentage_error: 84.7794
# Epoch 2/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3168 - mean_absolute_percentage_error: 28.2647 - val_loss: 0.7807 - val_mean_absolute_percentage_error: 73.8337
# Epoch 3/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2722 - mean_absolute_percentage_error: 23.7892 - val_loss: 0.6713 - val_mean_absolute_percentage_error: 61.3593
# Epoch 4/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2259 - mean_absolute_percentage_error: 18.8740 - val_loss: 0.5489 - val_mean_absolute_percentage_error: 49.3568
# Epoch 5/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1738 - mean_absolute_percentage_error: 14.2063 - val_loss: 0.4180 - val_mean_absolute_percentage_error: 37.6313
# Epoch 6/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1297 - mean_absolute_percentage_error: 10.6479 - val_loss: 0.3049 - val_mean_absolute_percentage_error: 26.7335
# Epoch 7/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1099 - mean_absolute_percentage_error: 8.9485 - val_loss: 0.2300 - val_mean_absolute_percentage_error: 19.0758
# Epoch 8/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0982 - mean_absolute_percentage_error: 8.3130 - val_loss: 0.2068 - val_mean_absolute_percentage_error: 18.2632
# Epoch 9/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0992 - mean_absolute_percentage_error: 8.0674 - val_loss: 0.2086 - val_mean_absolute_percentage_error: 16.7926
# Epoch 10/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1019 - mean_absolute_percentage_error: 8.1818 - val_loss: 0.2165 - val_mean_absolute_percentage_error: 17.2070
# Epoch 11/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0889 - mean_absolute_percentage_error: 7.2562 - val_loss: 0.2169 - val_mean_absolute_percentage_error: 18.1961
# Epoch 12/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0927 - mean_absolute_percentage_error: 7.5833 - val_loss: 0.2157 - val_mean_absolute_percentage_error: 18.4610
# Epoch 13/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0866 - mean_absolute_percentage_error: 7.0103 - val_loss: 0.2021 - val_mean_absolute_percentage_error: 17.7367
# Epoch 14/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0850 - mean_absolute_percentage_error: 6.7745 - val_loss: 0.1940 - val_mean_absolute_percentage_error: 17.0884
# Epoch 15/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0853 - mean_absolute_percentage_error: 6.9512 - val_loss: 0.1979 - val_mean_absolute_percentage_error: 17.0708
# Epoch 16/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0801 - mean_absolute_percentage_error: 6.8031 - val_loss: 0.2023 - val_mean_absolute_percentage_error: 17.6206
# Epoch 17/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0749 - mean_absolute_percentage_error: 6.0514 - val_loss: 0.2012 - val_mean_absolute_percentage_error: 17.1339
# Epoch 18/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0764 - mean_absolute_percentage_error: 6.2765 - val_loss: 0.1918 - val_mean_absolute_percentage_error: 16.1982
# Epoch 19/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0826 - mean_absolute_percentage_error: 6.7884 - val_loss: 0.1877 - val_mean_absolute_percentage_error: 15.7410
# Epoch 20/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0762 - mean_absolute_percentage_error: 6.3684 - val_loss: 0.1805 - val_mean_absolute_percentage_error: 15.0812
# Epoch 21/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0890 - mean_absolute_percentage_error: 7.5952 - val_loss: 0.1512 - val_mean_absolute_percentage_error: 13.0221
# Epoch 22/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0745 - mean_absolute_percentage_error: 6.1052 - val_loss: 0.1247 - val_mean_absolute_percentage_error: 10.9373
# Epoch 23/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0775 - mean_absolute_percentage_error: 6.5101 - val_loss: 0.1369 - val_mean_absolute_percentage_error: 12.0879
# Epoch 24/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0761 - mean_absolute_percentage_error: 6.1450 - val_loss: 0.1783 - val_mean_absolute_percentage_error: 15.2244
# Epoch 25/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0834 - mean_absolute_percentage_error: 7.0109 - val_loss: 0.1826 - val_mean_absolute_percentage_error: 15.3987
# Epoch 26/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0719 - mean_absolute_percentage_error: 5.9941 - val_loss: 0.1521 - val_mean_absolute_percentage_error: 13.2985
# Epoch 27/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0700 - mean_absolute_percentage_error: 5.9700 - val_loss: 0.1423 - val_mean_absolute_percentage_error: 12.1851
# Epoch 28/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0794 - mean_absolute_percentage_error: 6.3811 - val_loss: 0.1284 - val_mean_absolute_percentage_error: 11.3525
# Epoch 29/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0753 - mean_absolute_percentage_error: 6.0300 - val_loss: 0.1625 - val_mean_absolute_percentage_error: 13.9982
# Epoch 30/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0842 - mean_absolute_percentage_error: 6.9687 - val_loss: 0.1661 - val_mean_absolute_percentage_error: 13.8618
# Epoch 31/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0661 - mean_absolute_percentage_error: 5.3840 - val_loss: 0.1365 - val_mean_absolute_percentage_error: 12.0907
# Epoch 32/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0737 - mean_absolute_percentage_error: 6.0155 - val_loss: 0.1244 - val_mean_absolute_percentage_error: 11.0797
# Epoch 33/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0701 - mean_absolute_percentage_error: 6.0180 - val_loss: 0.1356 - val_mean_absolute_percentage_error: 11.5270
# Epoch 34/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0645 - mean_absolute_percentage_error: 5.3164 - val_loss: 0.1746 - val_mean_absolute_percentage_error: 14.6818
# Epoch 35/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0681 - mean_absolute_percentage_error: 5.6344 - val_loss: 0.1563 - val_mean_absolute_percentage_error: 13.0526
# Epoch 36/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0695 - mean_absolute_percentage_error: 5.7281 - val_loss: 0.1325 - val_mean_absolute_percentage_error: 12.0550
# Epoch 37/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0707 - mean_absolute_percentage_error: 5.8180 - val_loss: 0.1251 - val_mean_absolute_percentage_error: 11.4220
# Epoch 38/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0733 - mean_absolute_percentage_error: 6.1418 - val_loss: 0.1215 - val_mean_absolute_percentage_error: 11.2464
# Epoch 39/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0645 - mean_absolute_percentage_error: 5.2496 - val_loss: 0.1424 - val_mean_absolute_percentage_error: 12.6712
# Epoch 40/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0728 - mean_absolute_percentage_error: 6.1275 - val_loss: 0.1589 - val_mean_absolute_percentage_error: 13.5203
# Epoch 41/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0643 - mean_absolute_percentage_error: 5.3450 - val_loss: 0.1371 - val_mean_absolute_percentage_error: 11.5395
# Epoch 42/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0627 - mean_absolute_percentage_error: 5.1891 - val_loss: 0.1298 - val_mean_absolute_percentage_error: 11.0519
# Epoch 43/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0764 - mean_absolute_percentage_error: 6.4914 - val_loss: 0.1248 - val_mean_absolute_percentage_error: 10.9594
# Epoch 44/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0697 - mean_absolute_percentage_error: 5.8467 - val_loss: 0.1245 - val_mean_absolute_percentage_error: 10.8439
# Epoch 45/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0641 - mean_absolute_percentage_error: 5.3881 - val_loss: 0.1283 - val_mean_absolute_percentage_error: 11.7078
# Epoch 46/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0625 - mean_absolute_percentage_error: 5.2467 - val_loss: 0.1503 - val_mean_absolute_percentage_error: 13.0482
# Epoch 47/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0671 - mean_absolute_percentage_error: 5.6715 - val_loss: 0.1687 - val_mean_absolute_percentage_error: 14.8226
# Epoch 48/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0708 - mean_absolute_percentage_error: 6.0284 - val_loss: 0.1391 - val_mean_absolute_percentage_error: 12.0635
# Epoch 49/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0652 - mean_absolute_percentage_error: 5.4654 - val_loss: 0.1138 - val_mean_absolute_percentage_error: 9.7712
# Epoch 50/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0672 - mean_absolute_percentage_error: 5.7031 - val_loss: 0.1152 - val_mean_absolute_percentage_error: 9.7912
# Epoch 51/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0625 - mean_absolute_percentage_error: 5.3046 - val_loss: 0.1193 - val_mean_absolute_percentage_error: 10.5430
# Epoch 52/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0686 - mean_absolute_percentage_error: 5.6473 - val_loss: 0.1153 - val_mean_absolute_percentage_error: 9.7731
# Epoch 53/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0731 - mean_absolute_percentage_error: 6.2636 - val_loss: 0.1270 - val_mean_absolute_percentage_error: 10.8746
# Epoch 54/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0668 - mean_absolute_percentage_error: 5.5954 - val_loss: 0.1322 - val_mean_absolute_percentage_error: 11.2789
# Epoch 55/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0666 - mean_absolute_percentage_error: 5.4626 - val_loss: 0.1194 - val_mean_absolute_percentage_error: 10.1979
# Epoch 56/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0732 - mean_absolute_percentage_error: 6.1982 - val_loss: 0.1222 - val_mean_absolute_percentage_error: 10.9094
# Epoch 57/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0641 - mean_absolute_percentage_error: 5.4409 - val_loss: 0.1234 - val_mean_absolute_percentage_error: 10.6448
# Epoch 58/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0660 - mean_absolute_percentage_error: 5.6080 - val_loss: 0.1318 - val_mean_absolute_percentage_error: 11.3400
# Epoch 59/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0654 - mean_absolute_percentage_error: 5.6053 - val_loss: 0.1041 - val_mean_absolute_percentage_error: 8.9833
# Epoch 60/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0650 - mean_absolute_percentage_error: 5.4246 - val_loss: 0.1052 - val_mean_absolute_percentage_error: 9.3349
# Epoch 61/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0639 - mean_absolute_percentage_error: 5.4320 - val_loss: 0.1370 - val_mean_absolute_percentage_error: 12.2488
# Epoch 62/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.0635 - val_loss: 0.1457 - val_mean_absolute_percentage_error: 13.0444
# Epoch 63/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0609 - mean_absolute_percentage_error: 5.2214 - val_loss: 0.1341 - val_mean_absolute_percentage_error: 11.8194
# Epoch 64/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0616 - mean_absolute_percentage_error: 4.9971 - val_loss: 0.1172 - val_mean_absolute_percentage_error: 10.0102
# Epoch 65/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0641 - mean_absolute_percentage_error: 5.4513 - val_loss: 0.1199 - val_mean_absolute_percentage_error: 10.4662
# Epoch 66/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0605 - mean_absolute_percentage_error: 5.1273 - val_loss: 0.1565 - val_mean_absolute_percentage_error: 13.7056
# Epoch 67/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0647 - mean_absolute_percentage_error: 5.5495 - val_loss: 0.1593 - val_mean_absolute_percentage_error: 13.9882
# Epoch 68/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0592 - mean_absolute_percentage_error: 4.9877 - val_loss: 0.1103 - val_mean_absolute_percentage_error: 9.7143
# Epoch 69/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0615 - mean_absolute_percentage_error: 5.1181 - val_loss: 0.1045 - val_mean_absolute_percentage_error: 8.9861
# Epoch 70/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0685 - mean_absolute_percentage_error: 5.7871 - val_loss: 0.1134 - val_mean_absolute_percentage_error: 9.9609
# Epoch 71/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0631 - mean_absolute_percentage_error: 5.2734 - val_loss: 0.1573 - val_mean_absolute_percentage_error: 13.6605
# Epoch 72/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0677 - mean_absolute_percentage_error: 5.8941 - val_loss: 0.1784 - val_mean_absolute_percentage_error: 15.7183
# Epoch 73/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0569 - mean_absolute_percentage_error: 4.8309 - val_loss: 0.1260 - val_mean_absolute_percentage_error: 10.7914
# Epoch 74/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0605 - mean_absolute_percentage_error: 4.9895 - val_loss: 0.1239 - val_mean_absolute_percentage_error: 10.5951
# Epoch 75/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0584 - mean_absolute_percentage_error: 4.8422 - val_loss: 0.1287 - val_mean_absolute_percentage_error: 10.9060
# Epoch 76/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0594 - mean_absolute_percentage_error: 4.9030 - val_loss: 0.1325 - val_mean_absolute_percentage_error: 11.4247
# Epoch 77/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0657 - mean_absolute_percentage_error: 5.4615 - val_loss: 0.1200 - val_mean_absolute_percentage_error: 10.4835
# Epoch 78/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0650 - mean_absolute_percentage_error: 5.4814 - val_loss: 0.1014 - val_mean_absolute_percentage_error: 8.7125
# Epoch 79/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0609 - mean_absolute_percentage_error: 5.0581 - val_loss: 0.1210 - val_mean_absolute_percentage_error: 10.7321
# Epoch 80/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0595 - mean_absolute_percentage_error: 5.0718 - val_loss: 0.1135 - val_mean_absolute_percentage_error: 9.8025
# Epoch 81/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0556 - mean_absolute_percentage_error: 4.6923 - val_loss: 0.1184 - val_mean_absolute_percentage_error: 10.1158
# Epoch 82/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0659 - mean_absolute_percentage_error: 5.6328 - val_loss: 0.1397 - val_mean_absolute_percentage_error: 11.5925
# Epoch 83/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0609 - mean_absolute_percentage_error: 5.2084 - val_loss: 0.1314 - val_mean_absolute_percentage_error: 11.2200
# Epoch 84/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0574 - mean_absolute_percentage_error: 4.9944 - val_loss: 0.1275 - val_mean_absolute_percentage_error: 11.1577
# Epoch 85/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0570 - mean_absolute_percentage_error: 4.7203 - val_loss: 0.1171 - val_mean_absolute_percentage_error: 10.4220
# Epoch 86/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0636 - mean_absolute_percentage_error: 5.4113 - val_loss: 0.1090 - val_mean_absolute_percentage_error: 9.6100
# Epoch 87/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0550 - mean_absolute_percentage_error: 4.7625 - val_loss: 0.1123 - val_mean_absolute_percentage_error: 9.9069
# Epoch 88/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0566 - mean_absolute_percentage_error: 4.7992 - val_loss: 0.0934 - val_mean_absolute_percentage_error: 7.9791
# Epoch 89/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0605 - mean_absolute_percentage_error: 5.3029 - val_loss: 0.0986 - val_mean_absolute_percentage_error: 8.5299
# Epoch 90/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0607 - mean_absolute_percentage_error: 5.1956 - val_loss: 0.1261 - val_mean_absolute_percentage_error: 10.9326
# Epoch 91/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0581 - mean_absolute_percentage_error: 4.9060 - val_loss: 0.1026 - val_mean_absolute_percentage_error: 8.8914
# Epoch 92/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0620 - mean_absolute_percentage_error: 5.3374 - val_loss: 0.1000 - val_mean_absolute_percentage_error: 8.6107
# Epoch 93/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0633 - mean_absolute_percentage_error: 5.3933 - val_loss: 0.0994 - val_mean_absolute_percentage_error: 8.4916
# Epoch 94/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0612 - mean_absolute_percentage_error: 5.1892 - val_loss: 0.0876 - val_mean_absolute_percentage_error: 7.3988
# Epoch 95/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0585 - mean_absolute_percentage_error: 5.0062 - val_loss: 0.0807 - val_mean_absolute_percentage_error: 6.9276
# Epoch 96/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0609 - mean_absolute_percentage_error: 5.2943 - val_loss: 0.0845 - val_mean_absolute_percentage_error: 7.1974
# Epoch 97/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0565 - mean_absolute_percentage_error: 4.8327 - val_loss: 0.0911 - val_mean_absolute_percentage_error: 7.8947
# Epoch 98/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0568 - mean_absolute_percentage_error: 4.9026 - val_loss: 0.1109 - val_mean_absolute_percentage_error: 9.7789
# Epoch 99/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0603 - mean_absolute_percentage_error: 5.2769 - val_loss: 0.1204 - val_mean_absolute_percentage_error: 10.1502
# Epoch 100/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0549 - mean_absolute_percentage_error: 4.7372 - val_loss: 0.1039 - val_mean_absolute_percentage_error: 8.6264
# Epoch 101/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0566 - mean_absolute_percentage_error: 4.8022 - val_loss: 0.0911 - val_mean_absolute_percentage_error: 7.7427
# Epoch 102/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0545 - mean_absolute_percentage_error: 4.5696 - val_loss: 0.0884 - val_mean_absolute_percentage_error: 7.5761
# Epoch 103/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0588 - mean_absolute_percentage_error: 5.0005 - val_loss: 0.0952 - val_mean_absolute_percentage_error: 8.2612
# Epoch 104/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0640 - mean_absolute_percentage_error: 5.5876 - val_loss: 0.0981 - val_mean_absolute_percentage_error: 8.4261
# Epoch 105/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0616 - mean_absolute_percentage_error: 5.2448 - val_loss: 0.1197 - val_mean_absolute_percentage_error: 10.0887
# Epoch 106/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0630 - mean_absolute_percentage_error: 5.5856 - val_loss: 0.1419 - val_mean_absolute_percentage_error: 12.3847
# Epoch 107/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0560 - mean_absolute_percentage_error: 4.7976 - val_loss: 0.1007 - val_mean_absolute_percentage_error: 8.6732
# Epoch 108/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0521 - mean_absolute_percentage_error: 4.3951 - val_loss: 0.0928 - val_mean_absolute_percentage_error: 7.9644
# Epoch 109/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0522 - mean_absolute_percentage_error: 4.4227 - val_loss: 0.1191 - val_mean_absolute_percentage_error: 10.5558
# Epoch 110/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0547 - mean_absolute_percentage_error: 4.5618 - val_loss: 0.1099 - val_mean_absolute_percentage_error: 9.7237
# Epoch 111/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0596 - mean_absolute_percentage_error: 5.2248 - val_loss: 0.1277 - val_mean_absolute_percentage_error: 11.4770
# Epoch 112/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0582 - mean_absolute_percentage_error: 5.0070 - val_loss: 0.1122 - val_mean_absolute_percentage_error: 9.7834
# Epoch 113/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0531 - mean_absolute_percentage_error: 4.5531 - val_loss: 0.1005 - val_mean_absolute_percentage_error: 8.6613
# Epoch 114/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0535 - mean_absolute_percentage_error: 4.6192 - val_loss: 0.1175 - val_mean_absolute_percentage_error: 10.0729
# Epoch 115/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0546 - mean_absolute_percentage_error: 4.7203 - val_loss: 0.1169 - val_mean_absolute_percentage_error: 9.8601
# Epoch 116/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0537 - mean_absolute_percentage_error: 4.6918 - val_loss: 0.1021 - val_mean_absolute_percentage_error: 8.7497
# Epoch 117/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.7137 - val_loss: 0.1109 - val_mean_absolute_percentage_error: 9.8802
# Epoch 118/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.5124 - val_loss: 0.0941 - val_mean_absolute_percentage_error: 8.2445
# Epoch 119/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0506 - mean_absolute_percentage_error: 4.3048 - val_loss: 0.0880 - val_mean_absolute_percentage_error: 7.4126
# Epoch 120/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0546 - mean_absolute_percentage_error: 4.6578 - val_loss: 0.0919 - val_mean_absolute_percentage_error: 7.6461
# Epoch 121/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0601 - mean_absolute_percentage_error: 5.1462 - val_loss: 0.0908 - val_mean_absolute_percentage_error: 7.5665
# Epoch 122/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0576 - mean_absolute_percentage_error: 5.0458 - val_loss: 0.1187 - val_mean_absolute_percentage_error: 9.9531
# Epoch 123/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0501 - mean_absolute_percentage_error: 4.2534 - val_loss: 0.0995 - val_mean_absolute_percentage_error: 8.5274
# Epoch 124/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0569 - mean_absolute_percentage_error: 4.9126 - val_loss: 0.0952 - val_mean_absolute_percentage_error: 8.2598
# Epoch 125/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0525 - mean_absolute_percentage_error: 4.5949 - val_loss: 0.0971 - val_mean_absolute_percentage_error: 8.3612
# Epoch 126/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0502 - mean_absolute_percentage_error: 4.3056 - val_loss: 0.0993 - val_mean_absolute_percentage_error: 8.8549
# Epoch 127/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0571 - mean_absolute_percentage_error: 5.0431 - val_loss: 0.0928 - val_mean_absolute_percentage_error: 8.2185
# Epoch 128/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0541 - mean_absolute_percentage_error: 4.6937 - val_loss: 0.0727 - val_mean_absolute_percentage_error: 6.1686
# Epoch 129/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0525 - mean_absolute_percentage_error: 4.4649 - val_loss: 0.0820 - val_mean_absolute_percentage_error: 7.0662
# Epoch 130/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0589 - mean_absolute_percentage_error: 5.0997 - val_loss: 0.1093 - val_mean_absolute_percentage_error: 9.3110
# Epoch 131/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0534 - mean_absolute_percentage_error: 4.5367 - val_loss: 0.0919 - val_mean_absolute_percentage_error: 7.9621
# Epoch 132/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0523 - mean_absolute_percentage_error: 4.4704 - val_loss: 0.0788 - val_mean_absolute_percentage_error: 6.8084
# Epoch 133/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0549 - mean_absolute_percentage_error: 4.7232 - val_loss: 0.0688 - val_mean_absolute_percentage_error: 5.9710
# Epoch 134/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0558 - mean_absolute_percentage_error: 4.8464 - val_loss: 0.1012 - val_mean_absolute_percentage_error: 9.2186
# Epoch 135/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0505 - mean_absolute_percentage_error: 4.2901 - val_loss: 0.0899 - val_mean_absolute_percentage_error: 8.0308
# Epoch 136/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0590 - mean_absolute_percentage_error: 5.1419 - val_loss: 0.0922 - val_mean_absolute_percentage_error: 8.1848
# Epoch 137/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0546 - mean_absolute_percentage_error: 4.6490 - val_loss: 0.0957 - val_mean_absolute_percentage_error: 8.3642
# Epoch 138/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0557 - mean_absolute_percentage_error: 4.7622 - val_loss: 0.0777 - val_mean_absolute_percentage_error: 6.5968
# Epoch 139/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0560 - mean_absolute_percentage_error: 4.8137 - val_loss: 0.0791 - val_mean_absolute_percentage_error: 6.6973
# Epoch 140/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.5262 - val_loss: 0.0819 - val_mean_absolute_percentage_error: 7.0102
# Epoch 141/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0547 - mean_absolute_percentage_error: 4.6137 - val_loss: 0.0803 - val_mean_absolute_percentage_error: 6.7803
# Epoch 142/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0563 - mean_absolute_percentage_error: 4.8393 - val_loss: 0.0997 - val_mean_absolute_percentage_error: 8.4624
# Epoch 143/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0551 - mean_absolute_percentage_error: 4.6941 - val_loss: 0.0981 - val_mean_absolute_percentage_error: 8.3801
# Epoch 144/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0532 - mean_absolute_percentage_error: 4.4735 - val_loss: 0.0708 - val_mean_absolute_percentage_error: 5.9319
# Epoch 145/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0539 - mean_absolute_percentage_error: 4.6366 - val_loss: 0.0763 - val_mean_absolute_percentage_error: 6.3908
# Epoch 146/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0572 - mean_absolute_percentage_error: 4.8826 - val_loss: 0.0994 - val_mean_absolute_percentage_error: 8.5052
# Epoch 147/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0530 - mean_absolute_percentage_error: 4.5011 - val_loss: 0.1324 - val_mean_absolute_percentage_error: 11.4455
# Epoch 148/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0593 - mean_absolute_percentage_error: 5.1302 - val_loss: 0.0891 - val_mean_absolute_percentage_error: 7.5535
# Epoch 149/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0551 - mean_absolute_percentage_error: 4.7067 - val_loss: 0.0850 - val_mean_absolute_percentage_error: 7.1872
# Epoch 150/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0579 - mean_absolute_percentage_error: 4.9648 - val_loss: 0.0824 - val_mean_absolute_percentage_error: 6.8689
# Epoch 151/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0525 - mean_absolute_percentage_error: 4.5910 - val_loss: 0.1083 - val_mean_absolute_percentage_error: 9.0634
# Epoch 152/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0568 - mean_absolute_percentage_error: 4.8600 - val_loss: 0.1198 - val_mean_absolute_percentage_error: 10.0956
# Epoch 153/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0560 - mean_absolute_percentage_error: 4.7907 - val_loss: 0.0848 - val_mean_absolute_percentage_error: 6.9618
# Epoch 154/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0587 - mean_absolute_percentage_error: 5.0479 - val_loss: 0.0757 - val_mean_absolute_percentage_error: 6.3470
# Epoch 155/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0502 - mean_absolute_percentage_error: 4.1821 - val_loss: 0.0986 - val_mean_absolute_percentage_error: 8.6459
# Epoch 156/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0572 - mean_absolute_percentage_error: 4.9616 - val_loss: 0.1246 - val_mean_absolute_percentage_error: 11.3067
# Epoch 157/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7708 - val_loss: 0.0887 - val_mean_absolute_percentage_error: 7.6019
# Epoch 158/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0536 - mean_absolute_percentage_error: 4.7730 - val_loss: 0.0692 - val_mean_absolute_percentage_error: 5.9354
# Epoch 159/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0601 - mean_absolute_percentage_error: 5.2382 - val_loss: 0.0775 - val_mean_absolute_percentage_error: 6.6479
# Epoch 160/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0533 - mean_absolute_percentage_error: 4.5007 - val_loss: 0.1178 - val_mean_absolute_percentage_error: 10.1330
# Epoch 161/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0646 - mean_absolute_percentage_error: 5.8518 - val_loss: 0.1444 - val_mean_absolute_percentage_error: 13.1458
# Epoch 162/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0591 - mean_absolute_percentage_error: 5.1545 - val_loss: 0.0951 - val_mean_absolute_percentage_error: 8.1868
# Epoch 163/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0523 - mean_absolute_percentage_error: 4.4455 - val_loss: 0.0915 - val_mean_absolute_percentage_error: 7.6783
# Epoch 164/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0556 - mean_absolute_percentage_error: 4.8372 - val_loss: 0.0842 - val_mean_absolute_percentage_error: 7.0857
# Epoch 165/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0543 - mean_absolute_percentage_error: 4.6519 - val_loss: 0.0885 - val_mean_absolute_percentage_error: 7.3521
# Epoch 166/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0520 - mean_absolute_percentage_error: 4.4587 - val_loss: 0.0992 - val_mean_absolute_percentage_error: 8.4901
# Epoch 167/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0467 - mean_absolute_percentage_error: 4.0078 - val_loss: 0.1255 - val_mean_absolute_percentage_error: 10.7684
# Epoch 168/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.6165 - val_loss: 0.1208 - val_mean_absolute_percentage_error: 10.3109
# Epoch 169/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0519 - mean_absolute_percentage_error: 4.3717 - val_loss: 0.0908 - val_mean_absolute_percentage_error: 7.7089
# Epoch 170/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0562 - mean_absolute_percentage_error: 4.8271 - val_loss: 0.0834 - val_mean_absolute_percentage_error: 7.1488
# Epoch 171/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.7185 - val_loss: 0.0759 - val_mean_absolute_percentage_error: 6.4572
# Epoch 172/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0528 - mean_absolute_percentage_error: 4.6197 - val_loss: 0.0847 - val_mean_absolute_percentage_error: 7.1057
# Epoch 173/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0542 - mean_absolute_percentage_error: 4.7771 - val_loss: 0.1061 - val_mean_absolute_percentage_error: 9.3295
# Epoch 174/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0487 - mean_absolute_percentage_error: 4.1790 - val_loss: 0.1071 - val_mean_absolute_percentage_error: 9.0849
# Epoch 175/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0568 - mean_absolute_percentage_error: 4.9672 - val_loss: 0.0970 - val_mean_absolute_percentage_error: 8.0614
# Epoch 176/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0526 - mean_absolute_percentage_error: 4.5738 - val_loss: 0.0947 - val_mean_absolute_percentage_error: 7.6488
# Epoch 177/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0482 - mean_absolute_percentage_error: 4.1749 - val_loss: 0.0859 - val_mean_absolute_percentage_error: 7.0541
# Epoch 178/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0508 - mean_absolute_percentage_error: 4.4180 - val_loss: 0.1011 - val_mean_absolute_percentage_error: 8.5581
# Epoch 179/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0550 - mean_absolute_percentage_error: 4.6540 - val_loss: 0.1066 - val_mean_absolute_percentage_error: 9.1852
# Epoch 180/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0516 - mean_absolute_percentage_error: 4.4970 - val_loss: 0.0829 - val_mean_absolute_percentage_error: 7.0374
# Epoch 181/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0502 - mean_absolute_percentage_error: 4.3544 - val_loss: 0.0687 - val_mean_absolute_percentage_error: 5.8324
# Epoch 182/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.6289 - val_loss: 0.0725 - val_mean_absolute_percentage_error: 6.0063
# Epoch 183/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0503 - mean_absolute_percentage_error: 4.3494 - val_loss: 0.0833 - val_mean_absolute_percentage_error: 6.9857
# Epoch 184/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0520 - mean_absolute_percentage_error: 4.5448 - val_loss: 0.1083 - val_mean_absolute_percentage_error: 9.2155
# Epoch 185/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0524 - mean_absolute_percentage_error: 4.5604 - val_loss: 0.0899 - val_mean_absolute_percentage_error: 7.6276
# Epoch 186/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0533 - mean_absolute_percentage_error: 4.6333 - val_loss: 0.0847 - val_mean_absolute_percentage_error: 6.8842
# Epoch 187/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0543 - mean_absolute_percentage_error: 4.6767 - val_loss: 0.1038 - val_mean_absolute_percentage_error: 8.7052
# Epoch 188/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7334 - val_loss: 0.1097 - val_mean_absolute_percentage_error: 9.2033
# Epoch 189/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0557 - mean_absolute_percentage_error: 4.9132 - val_loss: 0.0769 - val_mean_absolute_percentage_error: 6.3605
# Epoch 190/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0554 - mean_absolute_percentage_error: 4.9128 - val_loss: 0.0746 - val_mean_absolute_percentage_error: 6.2476
# Epoch 191/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0483 - mean_absolute_percentage_error: 4.1037 - val_loss: 0.0891 - val_mean_absolute_percentage_error: 7.1792
# Epoch 192/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0501 - mean_absolute_percentage_error: 4.3076 - val_loss: 0.0857 - val_mean_absolute_percentage_error: 6.9674
# Epoch 193/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0519 - mean_absolute_percentage_error: 4.5008 - val_loss: 0.0868 - val_mean_absolute_percentage_error: 7.2353
# Epoch 194/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0581 - mean_absolute_percentage_error: 5.0434 - val_loss: 0.0712 - val_mean_absolute_percentage_error: 5.9695
# Epoch 195/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0496 - mean_absolute_percentage_error: 4.3505 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 6.1434
# Epoch 196/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0513 - mean_absolute_percentage_error: 4.4215 - val_loss: 0.0765 - val_mean_absolute_percentage_error: 6.3594
# Epoch 197/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0490 - mean_absolute_percentage_error: 4.2165 - val_loss: 0.1040 - val_mean_absolute_percentage_error: 8.9680
# Epoch 198/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0494 - mean_absolute_percentage_error: 4.3676 - val_loss: 0.0976 - val_mean_absolute_percentage_error: 8.3599
# Epoch 199/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0494 - mean_absolute_percentage_error: 4.3163 - val_loss: 0.1043 - val_mean_absolute_percentage_error: 9.1936
# Epoch 200/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0528 - mean_absolute_percentage_error: 4.6472 - val_loss: 0.1248 - val_mean_absolute_percentage_error: 11.5455
# Epoch 201/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0487 - mean_absolute_percentage_error: 4.2167 - val_loss: 0.1257 - val_mean_absolute_percentage_error: 11.6690
# Epoch 202/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0461 - mean_absolute_percentage_error: 3.9735 - val_loss: 0.0851 - val_mean_absolute_percentage_error: 7.4175
# Epoch 203/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0577 - mean_absolute_percentage_error: 5.1247 - val_loss: 0.0760 - val_mean_absolute_percentage_error: 6.5269
# Epoch 204/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0500 - mean_absolute_percentage_error: 4.3154 - val_loss: 0.1049 - val_mean_absolute_percentage_error: 9.0885
# Epoch 205/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0473 - mean_absolute_percentage_error: 4.0945 - val_loss: 0.0947 - val_mean_absolute_percentage_error: 8.1235
# Epoch 206/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0548 - mean_absolute_percentage_error: 4.7140 - val_loss: 0.0788 - val_mean_absolute_percentage_error: 6.6027
# Epoch 207/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0500 - mean_absolute_percentage_error: 4.3022 - val_loss: 0.0791 - val_mean_absolute_percentage_error: 6.6227
# Epoch 208/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0464 - mean_absolute_percentage_error: 4.0623 - val_loss: 0.1202 - val_mean_absolute_percentage_error: 10.8066
# Epoch 209/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0622 - mean_absolute_percentage_error: 5.4732 - val_loss: 0.1482 - val_mean_absolute_percentage_error: 13.5739
# Epoch 210/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0480 - mean_absolute_percentage_error: 4.1712 - val_loss: 0.0991 - val_mean_absolute_percentage_error: 8.2633
# Epoch 211/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0498 - mean_absolute_percentage_error: 4.3699 - val_loss: 0.0785 - val_mean_absolute_percentage_error: 6.5175
# Epoch 212/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0536 - mean_absolute_percentage_error: 4.6841 - val_loss: 0.0889 - val_mean_absolute_percentage_error: 7.3646
# Epoch 213/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0537 - mean_absolute_percentage_error: 4.7215 - val_loss: 0.0812 - val_mean_absolute_percentage_error: 6.8153
# Epoch 214/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0492 - mean_absolute_percentage_error: 4.3591 - val_loss: 0.0793 - val_mean_absolute_percentage_error: 6.8005
# Epoch 215/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0508 - mean_absolute_percentage_error: 4.5233 - val_loss: 0.0770 - val_mean_absolute_percentage_error: 6.6248
# Epoch 216/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.7200 - val_loss: 0.0955 - val_mean_absolute_percentage_error: 8.1523
# Epoch 217/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0552 - mean_absolute_percentage_error: 4.9524 - val_loss: 0.0812 - val_mean_absolute_percentage_error: 6.6983
# Epoch 218/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0470 - mean_absolute_percentage_error: 4.0800 - val_loss: 0.0767 - val_mean_absolute_percentage_error: 6.4072
# Epoch 219/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0513 - mean_absolute_percentage_error: 4.4761 - val_loss: 0.0845 - val_mean_absolute_percentage_error: 7.1718
# Epoch 220/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0456 - mean_absolute_percentage_error: 3.9244 - val_loss: 0.0896 - val_mean_absolute_percentage_error: 7.5569
# Epoch 221/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0528 - mean_absolute_percentage_error: 4.5395 - val_loss: 0.0803 - val_mean_absolute_percentage_error: 6.7985
# Epoch 222/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0534 - mean_absolute_percentage_error: 4.7715 - val_loss: 0.0864 - val_mean_absolute_percentage_error: 7.1887
# Epoch 223/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0482 - mean_absolute_percentage_error: 4.1597 - val_loss: 0.0794 - val_mean_absolute_percentage_error: 6.6235
# Epoch 224/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0518 - mean_absolute_percentage_error: 4.5943 - val_loss: 0.0731 - val_mean_absolute_percentage_error: 6.1913
# Epoch 225/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0509 - mean_absolute_percentage_error: 4.4869 - val_loss: 0.0715 - val_mean_absolute_percentage_error: 6.0467
# Epoch 226/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0514 - mean_absolute_percentage_error: 4.4365 - val_loss: 0.0887 - val_mean_absolute_percentage_error: 7.6876
# Epoch 227/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0473 - mean_absolute_percentage_error: 4.1626 - val_loss: 0.0676 - val_mean_absolute_percentage_error: 5.7254
# Epoch 228/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0466 - mean_absolute_percentage_error: 4.1149 - val_loss: 0.0771 - val_mean_absolute_percentage_error: 6.3616
# Epoch 229/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0510 - mean_absolute_percentage_error: 4.3642 - val_loss: 0.0956 - val_mean_absolute_percentage_error: 7.8844
# Epoch 230/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0511 - mean_absolute_percentage_error: 4.5466 - val_loss: 0.0973 - val_mean_absolute_percentage_error: 8.1550
# Epoch 231/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0472 - mean_absolute_percentage_error: 4.1154 - val_loss: 0.0742 - val_mean_absolute_percentage_error: 6.1935
# Epoch 232/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0494 - mean_absolute_percentage_error: 4.2315 - val_loss: 0.0741 - val_mean_absolute_percentage_error: 6.1548
# Epoch 233/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0516 - mean_absolute_percentage_error: 4.5870 - val_loss: 0.0792 - val_mean_absolute_percentage_error: 6.7788
# Epoch 234/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0526 - mean_absolute_percentage_error: 4.6450 - val_loss: 0.0805 - val_mean_absolute_percentage_error: 6.6042
# Epoch 235/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0485 - mean_absolute_percentage_error: 4.2158 - val_loss: 0.0893 - val_mean_absolute_percentage_error: 7.3948
# Epoch 236/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0534 - mean_absolute_percentage_error: 4.6916 - val_loss: 0.0861 - val_mean_absolute_percentage_error: 7.1941
# Epoch 237/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0557 - mean_absolute_percentage_error: 4.9791 - val_loss: 0.0677 - val_mean_absolute_percentage_error: 5.6845
# Epoch 238/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0496 - mean_absolute_percentage_error: 4.3774 - val_loss: 0.0717 - val_mean_absolute_percentage_error: 6.0475
# Epoch 239/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0577 - mean_absolute_percentage_error: 5.0272 - val_loss: 0.0757 - val_mean_absolute_percentage_error: 6.3199
# Epoch 240/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0544 - mean_absolute_percentage_error: 4.8272 - val_loss: 0.0767 - val_mean_absolute_percentage_error: 6.3992
# Epoch 241/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0456 - mean_absolute_percentage_error: 3.9386 - val_loss: 0.0804 - val_mean_absolute_percentage_error: 6.6873
# Epoch 242/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0479 - mean_absolute_percentage_error: 4.0417 - val_loss: 0.0956 - val_mean_absolute_percentage_error: 8.0264
# Epoch 243/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0496 - mean_absolute_percentage_error: 4.3287 - val_loss: 0.1075 - val_mean_absolute_percentage_error: 9.4256
# Epoch 244/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0535 - mean_absolute_percentage_error: 4.6095 - val_loss: 0.0758 - val_mean_absolute_percentage_error: 6.2543
# Epoch 245/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0518 - mean_absolute_percentage_error: 4.4748 - val_loss: 0.0671 - val_mean_absolute_percentage_error: 5.7023
# Epoch 246/2000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0536 - mean_absolute_percentage_error: 4.6491 - val_loss: 0.0714 - val_mean_absolute_percentage_error: 6.0982
# Epoch 247/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0506 - mean_absolute_percentage_error: 4.5471 - val_loss: 0.0738 - val_mean_absolute_percentage_error: 6.1734
# Epoch 248/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0480 - mean_absolute_percentage_error: 4.1526 - val_loss: 0.0801 - val_mean_absolute_percentage_error: 6.6195
# Epoch 249/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0522 - mean_absolute_percentage_error: 4.6695 - val_loss: 0.0993 - val_mean_absolute_percentage_error: 8.2511
# Epoch 250/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0444 - mean_absolute_percentage_error: 3.8991 - val_loss: 0.0910 - val_mean_absolute_percentage_error: 7.5857
# Epoch 251/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0508 - mean_absolute_percentage_error: 4.3986 - val_loss: 0.0775 - val_mean_absolute_percentage_error: 6.2813
# Epoch 252/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0477 - mean_absolute_percentage_error: 4.1921 - val_loss: 0.0720 - val_mean_absolute_percentage_error: 5.8307
# Epoch 253/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0461 - mean_absolute_percentage_error: 3.9808 - val_loss: 0.0947 - val_mean_absolute_percentage_error: 7.9929
# Epoch 254/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0495 - mean_absolute_percentage_error: 4.2143 - val_loss: 0.0780 - val_mean_absolute_percentage_error: 6.3586
# Epoch 255/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0547 - mean_absolute_percentage_error: 4.8421 - val_loss: 0.0711 - val_mean_absolute_percentage_error: 5.8648
# Epoch 256/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0545 - mean_absolute_percentage_error: 4.9280 - val_loss: 0.0696 - val_mean_absolute_percentage_error: 5.7183
# Epoch 257/2000
# ...
# Epoch 383/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0476 - mean_absolute_percentage_error: 4.1475 - val_loss: 0.0676 - val_mean_absolute_percentage_error: 5.6809
# Epoch 384/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0457 - mean_absolute_percentage_error: 3.9839 - val_loss: 0.0749 - val_mean_absolute_percentage_error: 6.0973
# Epoch 385/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0453 - mean_absolute_percentage_error: 3.9702 - val_loss: 0.0828 - val_mean_absolute_percentage_error: 6.9264
# Epoch 386/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0408 - mean_absolute_percentage_error: 3.5824 - val_loss: 0.0982 - val_mean_absolute_percentage_error: 8.3072
# Epoch 387/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0503 - mean_absolute_percentage_error: 4.5367 - val_loss: 0.0898 - val_mean_absolute_percentage_error: 7.5255
# Epoch 388/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0427 - mean_absolute_percentage_error: 3.7264 - val_loss: 0.0738 - val_mean_absolute_percentage_error: 6.1646
# Epoch 389/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0470 - mean_absolute_percentage_error: 4.1312 - val_loss: 0.0881 - val_mean_absolute_percentage_error: 7.3470
# Epoch 390/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0442 - mean_absolute_percentage_error: 3.9053 - val_loss: 0.0872 - val_mean_absolute_percentage_error: 7.1591
# Epoch 391/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0437 - mean_absolute_percentage_error: 3.8865 - val_loss: 0.0728 - val_mean_absolute_percentage_error: 5.8453
# Epoch 392/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0525 - mean_absolute_percentage_error: 4.7099 - val_loss: 0.0690 - val_mean_absolute_percentage_error: 5.6769
# Epoch 393/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0466 - mean_absolute_percentage_error: 4.1511 - val_loss: 0.0675 - val_mean_absolute_percentage_error: 5.5901
# Epoch 394/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0500 - mean_absolute_percentage_error: 4.4388 - val_loss: 0.0708 - val_mean_absolute_percentage_error: 5.8315
# Epoch 395/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0470 - mean_absolute_percentage_error: 4.1465 - val_loss: 0.0880 - val_mean_absolute_percentage_error: 7.1828
# Epoch 396/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0434 - mean_absolute_percentage_error: 3.7688 - val_loss: 0.0781 - val_mean_absolute_percentage_error: 6.3749
# Epoch 397/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0443 - mean_absolute_percentage_error: 4.0059 - val_loss: 0.0896 - val_mean_absolute_percentage_error: 7.3498
# Epoch 398/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0458 - mean_absolute_percentage_error: 4.0233 - val_loss: 0.0993 - val_mean_absolute_percentage_error: 8.0724
# Epoch 399/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0473 - mean_absolute_percentage_error: 4.1694 - val_loss: 0.0825 - val_mean_absolute_percentage_error: 6.5747
# Epoch 400/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0436 - mean_absolute_percentage_error: 3.9083 - val_loss: 0.0797 - val_mean_absolute_percentage_error: 6.3720
# Epoch 401/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0520 - mean_absolute_percentage_error: 4.6708 - val_loss: 0.0892 - val_mean_absolute_percentage_error: 7.4044
# Epoch 402/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0476 - mean_absolute_percentage_error: 4.2470 - val_loss: 0.0813 - val_mean_absolute_percentage_error: 6.6777
# Epoch 403/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0478 - mean_absolute_percentage_error: 4.2089 - val_loss: 0.0815 - val_mean_absolute_percentage_error: 6.6587
# Epoch 404/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0482 - mean_absolute_percentage_error: 4.2884 - val_loss: 0.0816 - val_mean_absolute_percentage_error: 6.6063
# Epoch 405/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0488 - mean_absolute_percentage_error: 4.2782 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 6.1921
# Epoch 406/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0466 - mean_absolute_percentage_error: 4.1326 - val_loss: 0.0686 - val_mean_absolute_percentage_error: 5.7409
# Epoch 407/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0411 - mean_absolute_percentage_error: 3.6741 - val_loss: 0.0969 - val_mean_absolute_percentage_error: 8.3672
# Epoch 408/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0541 - mean_absolute_percentage_error: 4.8549 - val_loss: 0.1054 - val_mean_absolute_percentage_error: 9.3511
# Epoch 409/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0517 - mean_absolute_percentage_error: 4.5020 - val_loss: 0.0691 - val_mean_absolute_percentage_error: 5.6682
# Epoch 410/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0539 - mean_absolute_percentage_error: 4.8383 - val_loss: 0.0669 - val_mean_absolute_percentage_error: 5.6384
# Epoch 411/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0448 - mean_absolute_percentage_error: 3.9265 - val_loss: 0.0744 - val_mean_absolute_percentage_error: 6.1177
# Epoch 412/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0456 - mean_absolute_percentage_error: 4.0760 - val_loss: 0.0906 - val_mean_absolute_percentage_error: 7.4917
# Epoch 413/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0450 - mean_absolute_percentage_error: 4.0061 - val_loss: 0.0724 - val_mean_absolute_percentage_error: 5.8434
# Epoch 414/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0475 - mean_absolute_percentage_error: 4.2262 - val_loss: 0.0717 - val_mean_absolute_percentage_error: 5.9019
# Epoch 415/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0442 - mean_absolute_percentage_error: 3.8663 - val_loss: 0.0839 - val_mean_absolute_percentage_error: 6.9692
# Epoch 416/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0471 - mean_absolute_percentage_error: 4.1888 - val_loss: 0.0768 - val_mean_absolute_percentage_error: 6.3342
# Epoch 417/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0485 - mean_absolute_percentage_error: 4.3373 - val_loss: 0.0920 - val_mean_absolute_percentage_error: 7.7592
# Epoch 418/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0458 - mean_absolute_percentage_error: 4.0653 - val_loss: 0.0924 - val_mean_absolute_percentage_error: 7.8461
# Epoch 419/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0466 - mean_absolute_percentage_error: 4.1389 - val_loss: 0.0927 - val_mean_absolute_percentage_error: 7.7826
# Epoch 420/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0463 - mean_absolute_percentage_error: 4.1608 - val_loss: 0.0767 - val_mean_absolute_percentage_error: 6.2274
# Epoch 421/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0470 - mean_absolute_percentage_error: 4.1599 - val_loss: 0.0757 - val_mean_absolute_percentage_error: 6.4440
# Epoch 422/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0485 - mean_absolute_percentage_error: 4.3708 - val_loss: 0.0810 - val_mean_absolute_percentage_error: 6.6034
# Epoch 423/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0448 - mean_absolute_percentage_error: 3.9145 - val_loss: 0.1152 - val_mean_absolute_percentage_error: 10.1074
# Epoch 424/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0476 - mean_absolute_percentage_error: 4.3613 - val_loss: 0.0980 - val_mean_absolute_percentage_error: 8.4121
# Epoch 425/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0437 - mean_absolute_percentage_error: 3.8383 - val_loss: 0.0825 - val_mean_absolute_percentage_error: 6.6373
# Epoch 426/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0427 - mean_absolute_percentage_error: 3.7889 - val_loss: 0.0795 - val_mean_absolute_percentage_error: 6.4127
# Epoch 427/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0415 - mean_absolute_percentage_error: 3.6655 - val_loss: 0.0792 - val_mean_absolute_percentage_error: 6.3967
# Epoch 428/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0446 - mean_absolute_percentage_error: 3.9270 - val_loss: 0.0924 - val_mean_absolute_percentage_error: 7.9369
# Epoch 429/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0447 - mean_absolute_percentage_error: 3.9018 - val_loss: 0.0844 - val_mean_absolute_percentage_error: 6.9448
# Epoch 430/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0402 - mean_absolute_percentage_error: 3.4781 - val_loss: 0.0785 - val_mean_absolute_percentage_error: 6.2753
# Epoch 431/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0434 - mean_absolute_percentage_error: 3.7493 - val_loss: 0.0847 - val_mean_absolute_percentage_error: 6.7891
# Epoch 432/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0424 - mean_absolute_percentage_error: 3.7181 - val_loss: 0.1010 - val_mean_absolute_percentage_error: 8.2055
# Epoch 433/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0470 - mean_absolute_percentage_error: 4.1013 - val_loss: 0.1098 - val_mean_absolute_percentage_error: 9.2561
# Epoch 434/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0448 - mean_absolute_percentage_error: 3.9568 - val_loss: 0.1000 - val_mean_absolute_percentage_error: 8.0748
# Epoch 435/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0431 - mean_absolute_percentage_error: 3.8229 - val_loss: 0.1009 - val_mean_absolute_percentage_error: 8.2007
# Epoch 436/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0459 - mean_absolute_percentage_error: 4.1060 - val_loss: 0.0994 - val_mean_absolute_percentage_error: 8.1713
# Epoch 437/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0467 - mean_absolute_percentage_error: 4.1336 - val_loss: 0.1154 - val_mean_absolute_percentage_error: 10.0865
# Epoch 438/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0464 - mean_absolute_percentage_error: 4.1613 - val_loss: 0.1057 - val_mean_absolute_percentage_error: 9.0914
# Epoch 439/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0446 - mean_absolute_percentage_error: 3.9184 - val_loss: 0.0915 - val_mean_absolute_percentage_error: 7.6597
# Epoch 440/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0441 - mean_absolute_percentage_error: 3.9137 - val_loss: 0.0779 - val_mean_absolute_percentage_error: 6.2300
# Epoch 441/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0458 - mean_absolute_percentage_error: 4.0904 - val_loss: 0.0820 - val_mean_absolute_percentage_error: 6.5768
# Epoch 442/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0419 - mean_absolute_percentage_error: 3.7361 - val_loss: 0.0868 - val_mean_absolute_percentage_error: 6.8837
# Epoch 443/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0418 - mean_absolute_percentage_error: 3.6824 - val_loss: 0.0943 - val_mean_absolute_percentage_error: 7.6744
# Epoch 444/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0456 - mean_absolute_percentage_error: 4.0099 - val_loss: 0.0854 - val_mean_absolute_percentage_error: 6.9010
# Epoch 445/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0420 - mean_absolute_percentage_error: 3.6676 - val_loss: 0.0820 - val_mean_absolute_percentage_error: 6.4832
# Epoch 446/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0486 - mean_absolute_percentage_error: 4.2362 - val_loss: 0.0766 - val_mean_absolute_percentage_error: 6.0429
# Epoch 447/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0460 - mean_absolute_percentage_error: 4.1182 - val_loss: 0.0899 - val_mean_absolute_percentage_error: 7.2701
# Epoch 448/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0417 - mean_absolute_percentage_error: 3.7639 - val_loss: 0.0808 - val_mean_absolute_percentage_error: 6.3649
# Epoch 449/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0441 - mean_absolute_percentage_error: 3.8372 - val_loss: 0.0876 - val_mean_absolute_percentage_error: 7.0705
# Epoch 450/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0426 - mean_absolute_percentage_error: 3.7926 - val_loss: 0.1000 - val_mean_absolute_percentage_error: 8.4881
# Epoch 451/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0422 - mean_absolute_percentage_error: 3.6398 - val_loss: 0.0816 - val_mean_absolute_percentage_error: 6.5482
# Epoch 452/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0409 - mean_absolute_percentage_error: 3.6054 - val_loss: 0.0731 - val_mean_absolute_percentage_error: 5.8364
# Epoch 453/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0481 - mean_absolute_percentage_error: 4.2938 - val_loss: 0.0838 - val_mean_absolute_percentage_error: 6.6750
# Epoch 454/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0430 - mean_absolute_percentage_error: 3.7967 - val_loss: 0.0919 - val_mean_absolute_percentage_error: 7.5670
# Epoch 455/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0431 - mean_absolute_percentage_error: 3.8963 - val_loss: 0.0758 - val_mean_absolute_percentage_error: 6.1099
# Epoch 456/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0434 - mean_absolute_percentage_error: 3.8593 - val_loss: 0.0796 - val_mean_absolute_percentage_error: 6.3734
# Epoch 457/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0447 - mean_absolute_percentage_error: 3.9265 - val_loss: 0.0976 - val_mean_absolute_percentage_error: 7.8935
# Epoch 458/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0486 - mean_absolute_percentage_error: 4.3029 - val_loss: 0.1036 - val_mean_absolute_percentage_error: 8.5265
# Epoch 459/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0462 - mean_absolute_percentage_error: 4.1266 - val_loss: 0.0760 - val_mean_absolute_percentage_error: 6.0363
# Epoch 460/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0430 - mean_absolute_percentage_error: 3.7960 - val_loss: 0.0737 - val_mean_absolute_percentage_error: 6.1075
# Epoch 461/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0487 - mean_absolute_percentage_error: 4.3330 - val_loss: 0.0838 - val_mean_absolute_percentage_error: 6.7716
# Epoch 462/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0458 - mean_absolute_percentage_error: 4.0513 - val_loss: 0.1006 - val_mean_absolute_percentage_error: 8.1744
# Epoch 463/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0431 - mean_absolute_percentage_error: 3.7897 - val_loss: 0.0964 - val_mean_absolute_percentage_error: 7.7510
# Epoch 464/2000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0473 - mean_absolute_percentage_error: 4.1995 - val_loss: 0.0997 - val_mean_absolute_percentage_error: 8.2254
# Epoch 465/2000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0411 - mean_absolute_percentage_error: 3.6401 - val_loss: 0.1099 - val_mean_absolute_percentage_error: 9.2487
# Epoch 466/2000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0457 - mean_absolute_percentage_error: 4.0218 - val_loss: 0.1127 - val_mean_absolute_percentage_error: 9.6045
# Epoch 467/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0412 - mean_absolute_percentage_error: 3.6621 - val_loss: 0.0883 - val_mean_absolute_percentage_error: 7.0962
# Restoring model weights from the end of the best epoch.
# Epoch 00467: early stopping

# %% [markdown]
# **Performance plot of the model: RMSE and MAPE**
#
# **Deutsch:**
#
# **Erstellung des Diagramms der Modellleistung: RMSE und MAPE**

# %%
 # Plot training & validation loss values
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %%
# Plot tht training and validation's MAPE
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history.history["mean_absolute_percentage_error"])
plt.plot(history.history["val_mean_absolute_percentage_error"])
plt.title("Model Accuracy with MAPE")
plt.ylabel("Loss (%)")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# **Predict the train dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Trainingdatensatzes zur Berechnung des Verlusts**

# %%
predictions_train = model.predict(X_train)
predictions_train
# Out:
# array([[0.18832146, 0.26210585, 0.17323904, 0.01858274, 0.05901034,
#         0.07002883, 0.16585338, 0.21027374, 0.03163308],
#        [0.25129023, 0.3517308 , 0.20959999, 0.04784588, 0.08382128,
#         0.10686015, 0.22805057, 0.25354102, 0.06393428],
#        [0.33514076, 0.4697971 , 0.25860265, 0.09096147, 0.11884562,
#         0.15879162, 0.31352696, 0.31455216, 0.11017355],
#        [0.41440576, 0.581938  , 0.3057286 , 0.13077526, 0.15316318,
#         0.20941347, 0.39652383, 0.37007928, 0.15609276],
#        [0.48628682, 0.6803628 , 0.35401773, 0.1738827 , 0.19175482,
#         0.2636761 , 0.47595447, 0.42414153, 0.20569779],
#        [0.5493202 , 0.76415396, 0.40238565, 0.21842116, 0.23242071,
#         0.3182783 , 0.54915977, 0.47460765, 0.25626212],
#        [0.59861696, 0.8099751 , 0.45214406, 0.26747906, 0.2810354 ,
#         0.3725679 , 0.60774076, 0.52025   , 0.30905938],
#        [0.64438826, 0.85573757, 0.5025349 , 0.31786156, 0.32827145,
#         0.4276666 , 0.6625916 , 0.567145  , 0.36287272],
#        [0.70037407, 0.9074886 , 0.56612116, 0.38549447, 0.39291966,
#         0.49553865, 0.73008424, 0.6281029 , 0.43344352],
#        [0.7548517 , 0.96208084, 0.628879  , 0.4505512 , 0.45735288,
#         0.56077075, 0.7990118 , 0.6862985 , 0.501994  ],
#        [0.8037321 , 0.9887841 , 0.6979096 , 0.5217334 , 0.5338796 ,
#         0.62829   , 0.8592304 , 0.7427398 , 0.57497966],
#        [0.842053  , 1.0032438 , 0.75852334, 0.582741  , 0.6020559 ,
#         0.6845316 , 0.9070383 , 0.78795755, 0.63702947],
#        [0.87423867, 0.9977212 , 0.81856924, 0.6437342 , 0.673681  ,
#         0.73525935, 0.9438963 , 0.82990974, 0.6973615 ]], dtype=float32)

# %%
prediction_unscaled_train = scaler_prediction.inverse_transform(predictions_train)

predicted_train_df = pd.DataFrame(prediction_unscaled_train, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_train_df['year'] = [x for x in range(2003, 2016)]
predicted_train_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1477.000488  ...  2003
# 1                     1626.882080  ...  2004
# 2                     1826.467529  ...  2005
# 3                     2015.138184  ...  2006
# 4                     2186.233154  ...  2007
# 5                     2336.268555  ...  2008
# 6                     2453.607178  ...  2009
# 7                     2562.554443  ...  2010
# 8                     2695.814941  ...  2011
# 9                     2825.485107  ...  2012
# 10                    2941.833008  ...  2013
# 11                    3033.046387  ...  2014
# 12                    3109.656494  ...  2015
#
# [13 rows x 10 columns]

# %% [markdown]
# **Predict the test dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Testdatensatzes für die Verlustberechnung**

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[0.90102184, 0.9871372 , 0.86999255, 0.69372606, 0.7383932 ,
#         0.7747641 , 0.9735112 , 0.8646743 , 0.74647397],
#        [0.9284069 , 0.97360456, 0.9251932 , 0.74923515, 0.80416834,
#         0.81727636, 1.0011349 , 0.903634  , 0.7982504 ],
#        [0.9609988 , 0.96451867, 0.98820764, 0.8126532 , 0.87890893,
#         0.86482847, 1.0353643 , 0.9489383 , 0.85750145],
#        [0.9951055 , 0.9489827 , 1.0625545 , 0.88706565, 0.96654844,
#         0.91879606, 1.0734555 , 0.9985671 , 0.9263442 ]], dtype=float32)

# %%
prediction_unscaled_test = scaler_prediction.inverse_transform(predictions)

predicted_test_df = pd.DataFrame(prediction_unscaled_test, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_test_df['year'] = [x for x in range(2016, 2020)]
predicted_test_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3173.406982            1960.554688  ...      76507.859375  2016
# 1                    3238.590332            1943.416138  ...      81118.992188  2017
# 2                    3316.167236            1931.909302  ...      86395.804688  2018
# 3                    3397.349854            1912.233765  ...      92526.835938  2019
#
# [4 rows x 10 columns]

# %% [markdown]
# **Calculate loss for testing data**
#
# **Deutsch:**
#
# **Verlustberechnung für Testdaten**

# %%
# create  the functions of mean absolute percentage error (MAPE) and root mean squared error (RMSE)
def mean_absolute_percentage_error(y_true, y_prediction): 
    y_true, y_prediction = np.array(y_true), np.array(y_prediction)
    return np.mean(np.abs((y_true - y_prediction) / y_true)) * 100

def root_mean_squared_error(y_true, y_prediction):
    mse = mean_squared_error(y_true, y_prediction)
    rmse = np.sqrt(mse)
    return rmse

# %%
# create a function of generating all the relevant errors
def calculate_performance(y_true, y_prediction):
    MSE = mean_squared_error(y_true, y_prediction)
    MAE = mean_absolute_error(y_true, y_prediction)
    MAPE = mean_absolute_percentage_error(y_true, y_prediction)
    RMSE = root_mean_squared_error(y_true, y_prediction)
    return round(MSE, 3), round(MAE, 3), round(MAPE, 3), round(RMSE, 3)

# %%
actual_arr=input_df.iloc[16:20,:].to_numpy()

# Get the predicted values for all 8 features
prediction_unscaled2 = scaler_prediction.inverse_transform(predictions)

MSE, MAE, MAPE, RMSE = calculate_performance(actual_arr, prediction_unscaled2)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 2266215.703
# Mean Absolute Error (MAE): 480.875
# Mean Absolute Percentage Error (MAPE): 3.52 %
# Root Mean Squared Error (RMSE): 1505.396

# %%
prediction_unscaled2
# Out:
# array([[ 3173.407  ,  1960.5547 ,   629.0171 ,   192.42702,   386.45905,
#           622.0756 ,  3141.6797 ,  1382.1031 , 76507.86   ],
#        [ 3238.5903 ,  1943.4161 ,   653.76105,   205.93153,   415.72925,
#           651.03546,  3198.7654 ,  1387.27   , 81118.99   ],
#        [ 3316.1672 ,  1931.9093 ,   682.0075 ,   221.3602 ,   448.98907,
#           683.4285 ,  3269.5022 ,  1393.2782 , 86395.805  ],
#        [ 3397.3499 ,  1912.2338 ,   715.33386,   239.46364,   487.989  ,
#           720.1919 ,  3348.2195 ,  1399.8599 , 92526.836  ]],
#       dtype=float32)

# %% [markdown]
# **Calculate loss of total energy consumption for prediction against actual values** (total energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Gesamtenergieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tec=predicted_test_df.iloc[:,0].to_numpy()
actual_tec=input_df.iloc[16:20,0].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tec, predicted_tec)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 2366.161
# Mean Absolute Error (MAE): 38.777
# Mean Absolute Percentage Error (MAPE): 1.23 %
# Root Mean Squared  Error (RMSE): 48.643

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tec)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tec)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtenergieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of coal consumption for prediction against actual values** (Coal consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Kohleverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_cc=predicted_test_df.iloc[:,1].to_numpy()
actual_cc=input_df.iloc[16:20,1].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_cc, predicted_cc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 2113.568
# Mean Absolute Error (MAE): 43.003
# Mean Absolute Percentage Error (MAPE): 2.25 %
# Root Mean Squared  Error (RMSE): 45.974

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_cc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_cc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Kohleverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of oil consumption for prediction against actual values** (Oil consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdölverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_oc=predicted_test_df.iloc[:,2].to_numpy()
actual_oc=input_df.iloc[16:20,2].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_oc, predicted_oc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 611.621
# Mean Absolute Error (MAE): 24.612
# Mean Absolute Percentage Error (MAPE): 3.81 %
# Root Mean Squared  Error (RMSE): 24.731

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_oc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_oc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdölverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of natural gas consumption for prediction against actual values** (Natural gas consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdgasverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gc=predicted_test_df.iloc[:,3].to_numpy()
actual_gc=input_df.iloc[16:20,3].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gc, predicted_gc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 365.937
# Mean Absolute Error (MAE): 16.295
# Mean Absolute Percentage Error (MAPE): 6.81 %
# Root Mean Squared  Error (RMSE): 19.129

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdgasverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of non fossil energy consumption for prediction against actual values** (non fossil energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des nichtfossilen Energieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_nfc=predicted_test_df.iloc[:,4].to_numpy()
actual_nfc=input_df.iloc[16:20,4].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_nfc, predicted_nfc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 95.513
# Mean Absolute Error (MAE): 8.59
# Mean Absolute Percentage Error (MAPE): 1.92 %
# Root Mean Squared  Error (RMSE): 9.773

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_nfc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_nfc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("nichtfossile Energieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of energy imports for prediction against actual values** (energy imports)
#
# **Deutsch:**
#
# **Verlustberechnung der Energieeinfuhr für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_imp=predicted_test_df.iloc[:,5].to_numpy()
actual_imp=input_df.iloc[16:20,5].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_imp, predicted_imp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 3513.676
# Mean Absolute Error (MAE): 51.551
# Mean Absolute Percentage Error (MAPE): 6.89 %
# Root Mean Squared  Error (RMSE): 59.276

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_imp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_imp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Energieeinfuhr (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of tpes for prediction against actual values** (total primary energy supply)
#
# **Deutsch:**
#
# **Verlustberechnung der Gesamtprimärenergieversorgung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tpes=predicted_test_df.iloc[:,6].to_numpy()
actual_tpes=input_df.iloc[16:20,6].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tpes, predicted_tpes)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 18870.849
# Mean Absolute Error (MAE): 132.392
# Mean Absolute Percentage Error (MAPE): 4.29 %
# Root Mean Squared  Error (RMSE): 137.371

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tpes)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tpes)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtprimärenergieversorgung (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of population for prediction against actual values** (population)
#
# **Deutsch:**
#
# **Verlustberechnung der Bevölkerung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_pop=predicted_test_df.iloc[:,7].to_numpy()
actual_pop=input_df.iloc[16:20,7].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_pop, predicted_pop)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 3.179
# Mean Absolute Error (MAE): 1.427
# Mean Absolute Percentage Error (MAPE): 0.1 %
# Root Mean Squared  Error (RMSE): 1.783

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_pop)
ax1.plot(predicted_test_df.iloc[:,-1], actual_pop)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bevölkerung (Millionen)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of GDP for prediction against actual values** (GDP)
#
# **Deutsch:**
#
# **Verlustberechnung des Bruttoinlandsprodukts für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gdp=predicted_test_df.iloc[:,8].to_numpy()
actual_gdp=input_df.iloc[16:20,8].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gdp, predicted_gdp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 20368000.826
# Mean Absolute Error (MAE): 4011.232
# Mean Absolute Percentage Error (MAPE): 4.41 %
# Root Mean Squared  Error (RMSE): 4513.092

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gdp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gdp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bruttoinlandsprodukt (Milliarden Yuan)", fontsize=18)

plt.show()

# %% [markdown]
# **Make future predictions**
#
# Predict the value of the next six years
#
# **Deutsch:**
#
# **Zukunftsprognosen erstellen**
#
# Vorhersage des Wertes für die nächsten sechs Jahre

# %%
# extract last three rows from dataset
temp_input=final_df[-3:].tolist()

# %%
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999]]

# %%
last_3_years = np.array(temp_input)
last_3_years.shape
# Out:
# (3, 9)

# %%
predicted_consumption_output =[]
for i in range(6):
  # Get the last 3 year consumption values and scale the data to be values between 0 and 1
  last_3_years = np.array(temp_input[-3:])
  last_3_years_scaled = last_3_years.reshape(1, 3, -1)
  # Create an empty list and Append past 3 years
  X_test_new = []
  X_test_new.append(last_3_years_scaled)
  # Convert the X_test data set to a numpy array and reshape the data
  prediction_consumption_scaled = model.predict(X_test_new)
  temp_input.extend(prediction_consumption_scaled.tolist())
  predicted_consumption_output.extend(prediction_consumption_scaled.tolist())

# %%
# add new predicted values into temp_input list
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999],
#  [1.0212035179138184,
#   0.9239177703857422,
#   1.1297866106033325,
#   0.9487800598144531,
#   1.0500433444976807,
#   0.9606277942657471,
#   1.1018956899642944,
#   1.03825044631958,
#   0.9835245013237],
#  [1.0419292449951172,
#   0.9111754894256592,
#   1.1714576482772827,
#   0.9860324859619141,
#   1.1074410676956177,
#   0.9867395758628845,
#   1.1221003532409668,
#   1.0645222663879395,
#   1.022356629371643],
#  [1.0587892532348633,
#   0.903367280960083,
#   1.200602650642395,
#   1.0124481916427612,
#   1.1482208967208862,
#   1.0048397779464722,
#   1.137263298034668,
#   1.0837278366088867,
#   1.050389289855957],
#  [1.0718348026275635,
#   0.9008382558822632,
#   1.219578742980957,
#   1.031065583229065,
#   1.1758195161819458,
#   1.017309546470642,
#   1.1489346027374268,
#   1.098469853401184,
#   1.070961594581604],
#  [1.080116868019104,
#   0.8940639495849609,
#   1.2383321523666382,
#   1.047808051109314,
#   1.1998540163040161,
#   1.0286431312561035,
#   1.156780481338501,
#   1.1100926399230957,
#   1.0878732204437256],
#  [1.0865187644958496,
#   0.8896700143814087,
#   1.2521052360534668,
#   1.0602765083312988,
#   1.2174296379089355,
#   1.037337303161621,
#   1.162948489189148,
#   1.1188724040985107,
#   1.1005687713623047]]

# %%
# rename temp_input with new inputs into prediction_arr
prediction_arr = np.array(temp_input)

# %%
prediction_arr
# Out:
# array([[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#         0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#        [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#         1.        , 1.        , 0.96478661, 0.91962137],
#        [1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.        ],
#        [1.02120352, 0.92391777, 1.12978661, 0.94878006, 1.05004334,
#         0.96062779, 1.10189569, 1.03825045, 0.9835245 ],
#        [1.04192924, 0.91117549, 1.17145765, 0.98603249, 1.10744107,
#         0.98673958, 1.12210035, 1.06452227, 1.02235663],
#        [1.05878925, 0.90336728, 1.20060265, 1.01244819, 1.1482209 ,
#         1.00483978, 1.1372633 , 1.08372784, 1.05038929],
#        [1.0718348 , 0.90083826, 1.21957874, 1.03106558, 1.17581952,
#         1.01730955, 1.1489346 , 1.09846985, 1.07096159],
#        [1.08011687, 0.89406395, 1.23833215, 1.04780805, 1.19985402,
#         1.02864313, 1.15678048, 1.11009264, 1.08787322],
#        [1.08651876, 0.88967001, 1.25210524, 1.06027651, 1.21742964,
#         1.0373373 , 1.16294849, 1.1188724 , 1.10056877]])

# %%
# transform the predicted value back to original form
prediction_unscaled = scaler_prediction.inverse_transform(prediction_arr)

# %%
predicted_consumption = prediction_unscaled.ravel()

# %%
predicted_consumption
# Out:
# array([  3190.789     ,   1899.7842638 ,    632.53951563,    209.41927228,
#           414.00076415,    700.273     ,   3064.9       ,   1390.08      ,
#         83203.59      ,   3303.475     ,   1912.9999275 ,    657.07314703,
#           245.92728745,    457.90272932,    775.509     ,   3196.42      ,
#          1395.38      ,  91928.11      ,   3409.        ,   1956.94088451,
#           687.29351129,    266.93887425,    502.87504711,    775.509     ,
#          3196.42      ,   1400.05      ,  99086.51      ,   3459.46971592,
#          1880.49028492,    745.47090835,    254.47783101,    525.14451761,
#           748.68818099,   3406.9925381 ,   1405.12277419,  97619.22680114,
#          3508.80216926,   1864.35278765,    764.15012721,    263.54078757,
#           550.68671341,    766.47583995,   3448.74648499,   1408.60694297,
#        101077.55787689,   3548.93323759,   1854.46406025,    777.21449777,
#           269.96733258,    568.8338858 ,    778.80591481,   3480.08146855,
#          1411.15398569, 103574.10457064,   3579.98493262,   1851.26116938,
#           785.72061141,    274.49666473,    581.11537194,    787.30047077,
#          3504.20080329,   1413.10907196, 105406.24317105,   3599.69833534,
#          1842.68183027,    794.12690648,    278.56985606,    591.810812  ,
#           795.02104473,   3520.41470371,   1414.65048591, 106912.36720289,
#          3614.93646223,   1837.11711877,    800.30074948,    281.6032447 ,
#           599.63202761,    800.94361896,   3533.16120033,   1415.81485823,
#        108043.01392437])

# %%
# reshape into proper format
predicted_consumption= predicted_consumption.reshape(-1,9)

# %%
predicted_consumption.shape
# Out:
# (9, 9)

# %% [markdown]
# **Table of actual values from 2017 to 2019 & prediction values from 2020 to 2025**
#
# **Deutsch:**
#
# **Tabelle mit realen Werten zwischen 2017 und 2019 sowie Vorhersagewerten zwischen 2020 und 2025**

# %%
# add column names and convert into dataframe for preparation of visualisation
prediction_df=pd.DataFrame(predicted_consumption ,columns=['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
prediction_df
# Out:
#    total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                    3190.789000  ...      83203.590000
# 1                    3303.475000  ...      91928.110000
# 2                    3409.000000  ...      99086.510000
# 3                    3459.469716  ...      97619.226801
# 4                    3508.802169  ...     101077.557877
# 5                    3548.933238  ...     103574.104571
# 6                    3579.984933  ...     105406.243171
# 7                    3599.698335  ...     106912.367203
# 8                    3614.936462  ...     108043.013924
#
# [9 rows x 9 columns]

# %% [markdown]
# **Preparation of predicted values for visualisation**
#
# **Deutsch:**
#
# **Aufbereitung der Vorhersagewerte für die Visualisierung**

# %%
# Generate list of sequence of years for predictions
year_range = range(2017,2026)

yearlist_predict = []

for y in year_range:
  yearlist_predict.append(y)

# %%
# Generate list of sequence of years for predictions
year_range = range(2000,2020)

yearlist_main = []

for y in year_range:
  yearlist_main.append(y)

# %%
# preparation for combination to original dataset copies
prediction_df['year']=yearlist_predict
prediction_df.head()
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3190.789000            1899.784264  ...      83203.590000  2017
# 1                    3303.475000            1912.999927  ...      91928.110000  2018
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3459.469716            1880.490285  ...      97619.226801  2020
# 4                    3508.802169            1864.352788  ...     101077.557877  2021
#
# [5 rows x 10 columns]

# %%
# make a copy from input_df and add a year column
energy_consumption_df = input_df.loc[:, :]
energy_consumption_df['year']=yearlist_main
energy_consumption_df.tail()
# Out:
#     total_energy_consumption_mtoe  ...  year
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [5 rows x 10 columns]

# %%
target_df=prediction_df.iloc[5:,:]
target_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 5                    3548.933238            1854.464060  ...     103574.104571  2022
# 6                    3579.984933            1851.261169  ...     105406.243171  2023
# 7                    3599.698335            1842.681830  ...     106912.367203  2024
# 8                    3614.936462            1837.117119  ...     108043.013924  2025
#
# [4 rows x 10 columns]

# %%
# this is the prediction dataframe between 2019 and 2025
visual_df=prediction_df.iloc[2:,:]
visual_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3459.469716            1880.490285  ...      97619.226801  2020
# 4                    3508.802169            1864.352788  ...     101077.557877  2021
# 5                    3548.933238            1854.464060  ...     103574.104571  2022
# 6                    3579.984933            1851.261169  ...     105406.243171  2023
# 7                    3599.698335            1842.681830  ...     106912.367203  2024
# 8                    3614.936462            1837.117119  ...     108043.013924  2025
#
# [7 rows x 10 columns]

# %% [markdown]
# **Combination of original dataset and prediction table**
#
# **Deutsch:**
#
# **Zusammensetzung des originalen Datensatz und der Vorhersagetabelle**

# %%
# append the predicted dataframe to the original dataset copies
combined_energy_consumption_df= pd.concat([energy_consumption_df, prediction_df.iloc[3:,:]], axis=0)
combined_energy_consumption_df.reset_index(drop=True, inplace=True)
combined_energy_consumption_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1028.748000  ...  2000
# 1                     1088.829000  ...  2001
# 2                     1187.039000  ...  2002
# 3                     1379.581000  ...  2003
# 4                     1611.967000  ...  2004
# 5                     1829.583000  ...  2005
# 6                     2005.269000  ...  2006
# 7                     2180.094000  ...  2007
# 8                     2244.277000  ...  2008
# 9                     2352.882000  ...  2009
# 10                    2524.536000  ...  2010
# 11                    2709.301000  ...  2011
# 12                    2814.966000  ...  2012
# 13                    2918.391000  ...  2013
# 14                    2998.338000  ...  2014
# 15                    3038.791000  ...  2015
# 16                    3090.444000  ...  2016
# 17                    3190.789000  ...  2017
# 18                    3303.475000  ...  2018
# 19                    3409.000000  ...  2019
# 20                    3459.469716  ...  2020
# 21                    3508.802169  ...  2021
# 22                    3548.933238  ...  2022
# 23                    3579.984933  ...  2023
# 24                    3599.698335  ...  2024
# 25                    3614.936462  ...  2025
#
# [26 rows x 10 columns]

# %% [markdown]
# **Visualise the prediction**
#
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Gesamtenergieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['total_energy_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Gesamtenergieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,0], color='g', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,0], color='y', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Trainingdaten)')
#plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['Energy_consumption'], color='orange', label='Training predictions')
#plt.plot(input_df.iloc[:,-1], input_df.iloc[:, 0], color='b', label='Actual Energy Consumption')
plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,0], color='b', marker='x', label='Ist-Gesamtenergieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')
#plt.axvline(x = min(target_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Gesamtenergieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Kohleverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['coal_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Kohleverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,1], color='g', marker='x', label='Vorhersage - Kohleverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,1], color='y', marker='x', label='Vorhersage - Kohleverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,1], color='b', marker='x', label='Ist-Kohleverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Kohleverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Kohleverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdölverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['oil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdölverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,2], color='g', marker='x', label='Vorhersage - Erdölverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,2], color='y', marker='x', label='Vorhersage - Erdölverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,2], color='b', marker='x', label='Ist-Erdölverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdölverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdölverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdgasverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['gas_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdgasverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,3], color='g', marker='x', label='Vorhersage - Erdgasverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,3], color='y', marker='x', label='Vorhersage - Erdgasverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,3], color='b', marker='x', label='Ist-Erdgasverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdgasverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdgasverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Nichtfossiler Energieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['non_fossil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger nichtfossile Energieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,4], color='g', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,4], color='y', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,4], color='b', marker='x', label='Ist-Nichtfossiler Energieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Nichtfossile Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Nichtfossiler Energieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
