# %% [markdown]
# <a href="https://colab.research.google.com/github/tyronecheng07/Energy-Consumption-Forecast/blob/main/MLP_model_single_layer_energy_consumption_forecast_china.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Total Energy Consumption Forecast- MLP-Model Single Layer Multivariate**
#
# ##**Goal and Description**
# A good prediction of the energy data allows stateholders, researcher and politician make better decision and to be well informed with the future possible scenarios. The main focus of this study is to forecast the total energy consumption of China for the next 6 years. Using a set of different variables as inputs and the energy consumption as output with a period of 20 years from 2000 to 2019 to perform the timeseries forecasting.
#
# **Deutsch:**
# #**Vorhersage des Gesamtenergieverbrauchs Chinas- MLP-Modell (1 Schicht) Multivariate**
#
# ##**Zielsetzung und Beschreibung**
#
# Eine gute Vorhersage der Energiedaten ermöglicht es Entscheidungsträgern, Forschern und auch Politikern, bessere Entscheidungen zu treffen und über die möglichen zukünftigen Entwicklungen gut informiert zu sein. Das Schwerpunktthema dieser Studie ist die Vorhersage des Gesamtenergieverbrauchs von China für die nächsten 6 Jahre. Die Zeitreihenprognose wird mit einer Reihe von verschiedenen Variablen als Eingaben und dem Energieverbrauch als Ausgabe mit einem Zeitraum von 20 Jahren von 2000 bis 2019 durchgeführt.

# %% [markdown]
# Prepared by Kuan Yew Cheng, 2021
#
# Raw data collected from China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# and from the database: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics and https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
#
# **Deutsch:**
#
# Vorbereitet von Kuan Yew Cheng, 2021
#
# Rohdaten entnommen aus China statistical Yearbook 2020: http://www.stats.gov.cn/tjsj/ndsj/2020/indexeh.htm
#
# auch von der Datenbank: https://data.stats.gov.cn/easyquery.htm?cn=C01, https://www.iea.org/data-and-statistics und https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html

# %% [markdown]
# **Import the libraries**
#
# **Deutsch:**
#
# **Importieren der Pythonbibliotheken**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import TimeDistributed
from tensorflow.keras.layers import Dropout
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.layers.core import Activation
import tensorflow as tf
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras import backend
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import LeakyReLU
from keras.backend import set_epsilon
from scipy.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# **Convert data from Excel worksheet to CSV format**
#
# **Deutsch:**
#
# **Konvertieren von Daten aus einem Excel-Arbeitsblatt in das CSV-Format**

# %%
#energy_df = pd.read_excel('Energy_Dataset_China.xlsx', sheet_name=None)
#energy_df['for_processing3'].to_csv('final_energy_data_3.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
energy_df = pd.read_excel('/content/drive/MyDrive/Energy China/Dataset for Bachelorarbeit/Energy_Dataset_China.xlsx', sheet_name=None)
energy_df['for_processing4'].to_csv('final_energy_data_4.csv')

# %% [markdown]
# **Reading and preprocessing the csv file**
#
# **Deutsch:**
#
# **Lesen und Vorverarbeiten der CSV-Datei**

# %%
energy_df = pd.read_csv('final_energy_data_4.csv', index_col=[0])

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Dataset of total energy Consumption(Mtoe) and other variables of China**
#
# **Deutsch:**
#
# **Datensatz des Gesamtenergieverbrauchs (Mtoe) und anderer Variablen von China**

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           20 non-null     int64
#  1   total_energy_consumption_mtoe  20 non-null     float64
#  2   coal_consumption_mtoe          20 non-null     float64
#  3   oil_consumption_mtoe           20 non-null     float64
#  4   gas_consumption_mtoe           20 non-null     float64
#  5   non_fossil_consumption_mtoe    20 non-null     float64
#  6   imports_mtoe                   20 non-null     float64
#  7   tpes_mtoe                      20 non-null     float64
#  8   population_million             20 non-null     float64
#  9   gdp_billion_yuan               20 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 1.7 KB

# %%
energy_df
# Out:
#     year  total_energy_consumption_mtoe  ...  population_million  gdp_billion_yuan
# 0   2000                       1028.748  ...             1267.43          10028.01
# 1   2001                       1088.829  ...             1276.27          11086.31
# 2   2002                       1187.039  ...             1284.53          12171.74
# 3   2003                       1379.581  ...             1292.27          13742.20
# 4   2004                       1611.967  ...             1299.88          16184.02
# 5   2005                       1829.583  ...             1307.56          18731.89
# 6   2006                       2005.269  ...             1314.48          21943.85
# 7   2007                       2180.094  ...             1321.29          27009.23
# 8   2008                       2244.277  ...             1328.02          31924.46
# 9   2009                       2352.882  ...             1334.50          34851.77
# 10  2010                       2524.536  ...             1340.91          41211.93
# 11  2011                       2709.301  ...             1347.35          48794.02
# 12  2012                       2814.966  ...             1354.04          53858.00
# 13  2013                       2918.391  ...             1360.72          59296.32
# 14  2014                       2998.338  ...             1367.82          64356.31
# 15  2015                       3038.791  ...             1374.62          68885.82
# 16  2016                       3090.444  ...             1382.71          74639.51
# 17  2017                       3190.789  ...             1390.08          83203.59
# 18  2018                       3303.475  ...             1395.38          91928.11
# 19  2019                       3409.000  ...             1400.05          99086.51
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualise data of years against each column**
#
# **Deutsch:**
#
# **Visualisierung der Jahresdaten gegenüber jeder Spalte**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")
plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.show()

# %% [markdown]
# Comment: Some of the plots showed abnormal drops since there were missing values in the dataset which displayed as 0.
#
# **Deutsch:**
#
# Kommentar: Einige der Grafiken zeigten abnormale Absenkungen, da es fehlende Werte im Datensatz gab, die als 0 angezeigt wurden.

# %% [markdown]
# **Arrange the columns**
#
# Shifting the ***year*** column to the last column and adding a new column ***prediction*** into the energy_df
#
# **Deutsch:**
#
# **Anordnen der Spalten**
#
# Verschieben der **Jahres**-Spalte in die letzte Spalte und Hinzufügung einer neuen **Vorhersage**-spalte in der energy_df

# %%
features = ['total_energy_consumption_mtoe', 'coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe', 'imports_mtoe','tpes_mtoe', 'population_million', 'gdp_billion_yuan', 'year']
energy_df = energy_df[features]
energy_df_ext = energy_df.copy()
energy_df_ext['prediction'] = energy_df_ext['total_energy_consumption_mtoe']
energy_df_ext.tail()
# Out:
#     total_energy_consumption_mtoe  coal_consumption_mtoe  ...  year  prediction
# 15                       3038.791            1920.657806  ...  2015    3038.791
# 16                       3090.444            1895.791743  ...  2016    3090.444
# 17                       3190.789            1899.784264  ...  2017    3190.789
# 18                       3303.475            1912.999927  ...  2018    3303.475
# 19                       3409.000            1956.940885  ...  2019    3409.000
#
# [5 rows x 11 columns]

# %% [markdown]
# **Check zero values**
#
# **Deutsch:**
#
# **0-werte überprüfen**

# %%
energy_df.isin([0]).sum()
# Out:
# total_energy_consumption_mtoe    0
# coal_consumption_mtoe            0
# oil_consumption_mtoe             0
# gas_consumption_mtoe             0
# non_fossil_consumption_mtoe      0
# imports_mtoe                     1
# tpes_mtoe                        1
# population_million               0
# gdp_billion_yuan                 0
# year                             0
# dtype: int64

# %% [markdown]
# **Replace the zero values with null**
#
# **Deutsch:**
#
# **Ersetzen Sie die 0-Werte durch Nullwerte**

# %%
cols = ["imports_mtoe","tpes_mtoe"]
energy_df[cols] = energy_df[cols].replace(['0', 0], np.nan)

# %% [markdown]
# **Interpolate the missing values by using linear interpolation**
#
# **Deutsch:**
#
# **Interpolierung der fehlenden Werte mit Hilfe der linearen Interpolation**

# %%
energy_df.interpolate(method='linear', limit_direction ='both', inplace=True)

energy_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                        1028.748  ...  2000
# 1                        1088.829  ...  2001
# 2                        1187.039  ...  2002
# 3                        1379.581  ...  2003
# 4                        1611.967  ...  2004
# 5                        1829.583  ...  2005
# 6                        2005.269  ...  2006
# 7                        2180.094  ...  2007
# 8                        2244.277  ...  2008
# 9                        2352.882  ...  2009
# 10                       2524.536  ...  2010
# 11                       2709.301  ...  2011
# 12                       2814.966  ...  2012
# 13                       2918.391  ...  2013
# 14                       2998.338  ...  2014
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [20 rows x 10 columns]

# %% [markdown]
# **Visualize data of years against each column after interpolation**
#
# **Deutsch:**
#
# **Visualisierung der Daten von Jahren gegenüber jeder Spalte nach der Interpolation**

# %%
x = energy_df['year']
y1 = energy_df['total_energy_consumption_mtoe']
y3 = energy_df['imports_mtoe']
y5 = energy_df['tpes_mtoe']
y6 = energy_df['population_million']
y7 = energy_df['gdp_billion_yuan']
y10 = energy_df['coal_consumption_mtoe']
y11 = energy_df['oil_consumption_mtoe']
y12 = energy_df['gas_consumption_mtoe']
y13 = energy_df['non_fossil_consumption_mtoe']

plt.figure()
plt.title("total_energy_consumption_mtoe 2000 to 2019")
plt.plot(x, y1, 'g-')
plt.xlabel("Years")
plt.ylabel("Energy comsumption mtoe")

plt.figure()
plt.title("Coal consumption 2000 to 2019")
plt.plot(x, y10, 'k-')
plt.xlabel("Years")
plt.ylabel("Coal consumption mtoe")

plt.figure()
plt.title("Oil consumption 2000 to 2019")
plt.plot(x, y11, 'm-')
plt.xlabel("Years")
plt.ylabel("Oil consumption mtoe")

plt.figure()
plt.title("Gas consumption 2000 to 2019")
plt.plot(x, y12, 'c-')
plt.xlabel("Years")
plt.ylabel("gas consumption mtoe")

plt.figure()
plt.title("Non fossil consumption 2000 to 2019")
plt.plot(x, y13, 'r-')
plt.xlabel("Years")
plt.ylabel("electricity_consumption_billion_kwh")

plt.figure()
plt.title("GDP China 2000 to 2019")
plt.plot(x, y7, 'k-')
plt.xlabel("Years")
plt.ylabel("gdp_billion yuan")

plt.figure()
plt.title("energy imports 2000 to 2019")
plt.plot(x, y3, 'y-')
plt.legend(["Imports", "Exports"], loc="upper left")
plt.xlabel("Years")
plt.ylabel("Amount of Resources")

plt.figure()
plt.title("total primary energy supply 2000 to 2019")
plt.plot(x, y5, 'c-')
plt.xlabel("Years")
plt.ylabel("tpes_mtoe")

plt.figure()
plt.title("Population 2000 to 2019")
plt.plot(x, y6, 'm-')
plt.xlabel("Years")
plt.ylabel("population million")

plt.show()

# %% [markdown]
# **Check Correlations**
#
# **Deutsch:**
#
# **Korrelationen prüfen**

# %%
pearsoncorr = energy_df.corr(method='pearson')
pearsoncorr
# Out:
#                                total_energy_consumption_mtoe  ...      year
# total_energy_consumption_mtoe                       1.000000  ...  0.987076
# coal_consumption_mtoe                               0.967508  ...  0.915922
# oil_consumption_mtoe                                0.982699  ...  0.997376
# gas_consumption_mtoe                                0.930097  ...  0.971747
# non_fossil_consumption_mtoe                         0.919665  ...  0.968318
# imports_mtoe                                        0.957505  ...  0.986707
# tpes_mtoe                                           0.997467  ...  0.981646
# population_million                                  0.989195  ...  0.999361
# gdp_billion_yuan                                    0.945927  ...  0.982514
# year                                                0.987076  ...  1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# **Correlation Matrix with Pearson coefficient**
#
# **Deutsch:**
#
# **Korrelations-Matrix mit Pearson-Korrelationskoeffizient**

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# **Calculation of P-value**
#
# **Deutsch:**
#
# **Berechnung vom P-Wert**

# %%
def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 12)
    return pvalues

# %%
calculate_pvalues(energy_df)
# Out:
#                               total_energy_consumption_mtoe  ...        year
# total_energy_consumption_mtoe                             0  ...           0
# coal_consumption_mtoe                                 3e-12  ...  1.4652e-08
# oil_consumption_mtoe                                      0  ...           0
# gas_consumption_mtoe                              2.932e-09  ...       1e-12
# non_fossil_consumption_mtoe                       9.861e-09  ...       3e-12
# imports_mtoe                                        3.7e-11  ...           0
# tpes_mtoe                                                 0  ...           0
# population_million                                        0  ...           0
# gdp_billion_yuan                                   3.08e-10  ...           0
# year                                                      0  ...           0
#
# [10 rows x 10 columns]

# %% [markdown]
# All the values are with a  p-value < 0.01, the variables are statistically significant and the null hypothese can be rejected
#
# **Deutsch:**
#
# Alle Werte wurden mit dem P-Wert < 0,01 berechnet. Dieses Variablen waren statistisch signifikant und die Nullhypothese lässt sich ablehnen.

# %% [markdown]
# **Create a new DataFrame without exports_mtoe and year**
#
# **Deutsch:**
#
# **Erstellung eines neuen DataFrames ohne exports_mtoe und Jahr**

# %%
input_df = energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']]

# %%
input_df
# Out:
#     total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                        1028.748  ...          10028.01
# 1                        1088.829  ...          11086.31
# 2                        1187.039  ...          12171.74
# 3                        1379.581  ...          13742.20
# 4                        1611.967  ...          16184.02
# 5                        1829.583  ...          18731.89
# 6                        2005.269  ...          21943.85
# 7                        2180.094  ...          27009.23
# 8                        2244.277  ...          31924.46
# 9                        2352.882  ...          34851.77
# 10                       2524.536  ...          41211.93
# 11                       2709.301  ...          48794.02
# 12                       2814.966  ...          53858.00
# 13                       2918.391  ...          59296.32
# 14                       2998.338  ...          64356.31
# 15                       3038.791  ...          68885.82
# 16                       3090.444  ...          74639.51
# 17                       3190.789  ...          83203.59
# 18                       3303.475  ...          91928.11
# 19                       3409.000  ...          99086.51
#
# [20 rows x 9 columns]

# %% [markdown]
# **Display our feature column: total_energy_consumption_mtoe**
#
# **Deutsch:**
#
# **Feature-Spalte anzeigen: total_energy_consumption_mtoe**

# %%
input_df.iloc[:,0]
# Out:
# 0     1028.748
# 1     1088.829
# 2     1187.039
# 3     1379.581
# 4     1611.967
# 5     1829.583
# 6     2005.269
# 7     2180.094
# 8     2244.277
# 9     2352.882
# 10    2524.536
# 11    2709.301
# 12    2814.966
# 13    2918.391
# 14    2998.338
# 15    3038.791
# 16    3090.444
# 17    3190.789
# 18    3303.475
# 19    3409.000
# Name: total_energy_consumption_mtoe, dtype: float64

# %% [markdown]
# **Basic Statistics**
#
# **Deutsch:**
#
# **Basis-Statistik**

# %%
input_df.describe()
# Out:
#        total_energy_consumption_mtoe  ...  gdp_billion_yuan
# count                      20.000000  ...         20.000000
# mean                     2345.315000  ...      44146.680000
# std                       777.438682  ...      28823.738016
# min                      1028.748000  ...      10028.010000
# 25%                      1775.179000  ...      18094.922500
# 50%                      2438.709000  ...      38031.850000
# 75%                      3008.451250  ...      65488.687500
# max                      3409.000000  ...      99086.510000
#
# [8 rows x 9 columns]

# %% [markdown]
# **Feature Scaling: Min Max Scaling**
#
# **Deutsch:**
#
# **Feature-Skalierung: Min Max Scaling**

# %%
# Calculate the number of rows in the data
nrows = input_df.shape[0]
input_df_unscaled = np.array(input_df)
input_df_unscaled = np.reshape(input_df_unscaled, (nrows, -1))
print(input_df_unscaled.shape)

#Feature Scaling
# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
final_df = scaler.fit_transform(input_df_unscaled)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_prediction = MinMaxScaler()
#consumption_df = pd.DataFrame(energy_df_ext['total_energy_consumption_mtoe'])
consumption_df = pd.DataFrame(energy_df[['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan']])
consumption_df_scaled = scaler_prediction.fit_transform(consumption_df)
# Out:
# (20, 9)

# %%
final_df[:,0]
# Out:
# array([0.        , 0.02524145, 0.06650178, 0.14739322, 0.24502406,
#        0.33644967, 0.4102595 , 0.48370761, 0.5106724 , 0.55629992,
#        0.62841581, 0.70603995, 0.75043231, 0.79388359, 0.82747121,
#        0.84446647, 0.86616711, 0.90832441, 0.95566646, 1.        ])

# %% [markdown]
# **Convert into a supervised learning problem**
#
# **Deutsch:**
#
# **In ein Format* des überwachten Lernens umwandeln**

# %%
###
*    Dieser Teil des Codes geändert aus dem ipynb-Dokument von JonJae:
*    Titel: FeedInMngmt_LSTM_NN
*    Autor: JonJae
*    Datum: 2020
*    Verfügbarkeit: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb
*   (Quelle: https://github.com/JonJae/TimeSeriesPrediction_FeedInMngmt/blob/main/FeedInMngmt_LSTM_NN.ipynb abgerufen am Februar 2021)
###

#Global Settings
sequence_length = 3   # Number of past years that we want to predict the future values
n_out = 1            # Number of years that we wamt to forecast into the future

# Split the training data into x_train and y_train data sets
# Get the number of rows to train the model on 80% of the data 
train_data_len = math.ceil(final_df.shape[0] * 0.8) #16 train data point

# Create the training data
train_data = final_df[0:train_data_len, :]
X_train, y_train = [], []
in_start = 0
# step over the entire history five time step at a time
for _ in range(train_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(train_data):
		X_train.append(train_data[in_start:in_end, :])
		y_train.append(train_data[in_end:out_end, :])
	# move along one batch
	in_start += 1
    
# Convert the X_train and y_train into numpy arrays
X_train, y_train = np.array(X_train), np.array(y_train)

# Create the test data
test_data = final_df[train_data_len - sequence_length:, :]

# Seperate the test data into X_test and y_test
X_test, y_test = [], []
test_data_len = test_data.shape[0]
in_start = 0
# step over the entire history five time step at a time
for _ in range(test_data_len):
	# define the end of the input sequence
	in_end = in_start + sequence_length
	out_end = in_end + n_out
	# ensure we have enough data for this instance
	if out_end <= len(test_data):
		X_test.append(test_data[in_start:in_end, :])
		y_test.append(test_data[in_end:out_end, :])
	# move along one batch
	in_start += 1

X_test, y_test = np.array(X_test), np.array(y_test)

# Convert the X_train and y_train to numpy arrays
X_test = np.array(X_test); y_test = np.array(y_test)
    
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13, 3, 9) (13, 1, 9)
# (4, 3, 9) (4, 1, 9)

# %% [markdown]
# **Take a look on test and train data after transformation**
#
# **Deutsch:**
#
# **Schauen wir nun, wie die Training- und Testdaten nach der Transformation aussiehen.**

# %%
X_train
# Out:
# array([[[0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.00879609, 0.        , 0.        , 0.        ],
#         [0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103]],
#
#        [[0.02524145, 0.03079585, 0.0157633 , 0.01051812, 0.02897953,
#          0.        , 0.01859621, 0.06665661, 0.0118832 ],
#         [0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.06650178, 0.08606178, 0.05993428, 0.01626449, 0.03773642,
#          0.02361379, 0.05609833, 0.12893983, 0.02407103],
#         [0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506],
#         [0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322],
#         [0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216],
#         [0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ],
#         [0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489],
#         [0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592],
#         [0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544],
#         [0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097],
#         [0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703],
#         [0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831],
#         [0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]]])

# %%
y_train
# Out:
# array([[[0.14739322, 0.21045907, 0.12409692, 0.0296884 , 0.04430549,
#          0.06758395, 0.14021921, 0.18730207, 0.04170506]],
#
#        [[0.24502406, 0.33721802, 0.23461735, 0.05294624, 0.08437733,
#          0.13483908, 0.23458905, 0.24468406, 0.06912322]],
#
#        [[0.33644967, 0.49040605, 0.24396911, 0.07767554, 0.10932553,
#          0.13720252, 0.31528393, 0.30259388, 0.09773216]],
#
#        [[0.4102595 , 0.59313973, 0.3018127 , 0.11673839, 0.13103024,
#          0.1818817 , 0.39626431, 0.35477304, 0.1337979 ]],
#
#        [[0.48370761, 0.69584946, 0.34379814, 0.16308345, 0.16145945,
#          0.22024128, 0.46825869, 0.40612276, 0.19067489]],
#
#        [[0.5106724 , 0.71518101, 0.35725755, 0.20287511, 0.24723003,
#          0.23935427, 0.49555539, 0.45686925, 0.24586592]],
#
#        [[0.55629992, 0.7758244 , 0.3939963 , 0.23187521, 0.24569304,
#          0.34775371, 0.56471414, 0.50573066, 0.27873544]],
#
#        [[0.62841581, 0.82496947, 0.51948124, 0.30027153, 0.30725673,
#          0.45419047, 0.68052067, 0.55406424, 0.35015097]],
#
#        [[0.70603995, 0.9482143 , 0.55655104, 0.39059814, 0.31447489,
#          0.50136668, 0.7704822 , 0.60262404, 0.43528703]],
#
#        [[0.75043231, 0.96702624, 0.60545074, 0.44533793, 0.42109379,
#          0.56753257, 0.81779778, 0.65306892, 0.49214831]],
#
#        [[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]]])

# %%
X_test
# Out:
# array([[[0.79388359, 1.        , 0.6545798 , 0.5190226 , 0.47148425,
#          0.61602409, 0.86176478, 0.7034384 , 0.55321289],
#         [0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ]],
#
#        [[0.82747121, 0.98877601, 0.69942332, 0.57694402, 0.57668734,
#          0.66336471, 0.88785173, 0.75697482, 0.61002936],
#         [0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.84446647, 0.95563433, 0.78200942, 0.60163117, 0.63931892,
#          0.65995314, 0.90080569, 0.80824913, 0.6608893 ],
#         [0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504],
#         [0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#         [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]]])

# %% [markdown]
# **Let's see how y_test looks like**
#
# **Deutsch:**
#
# **Schauen wir uns an, wie y_test aussieht**

# %%
y_test
# Out:
# array([[[0.86616711, 0.93599991, 0.81588978, 0.65405384, 0.71854441,
#          0.78881171, 0.8908519 , 0.86925049, 0.72549504]],
#
#        [[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#          0.88955567, 0.9363577 , 0.9248228 , 0.82165745]],
#
#        [[0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#          1.        , 1.        , 0.96478661, 0.91962137]],
#
#        [[1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#          1.        , 1.        , 1.        , 1.        ]]])

# %% [markdown]
# **Change the shape of the training dataset to suit the MLP Model's input dimension**
#
# **Deutsch:**
#
# **Änderung der Form des Trainingsdatensatzes zur Anpassung an die Eingangsdimension des MLP-Modells**

# %%
# flatten input
n_input = X_train.shape[1] * X_train.shape[2]
X_train1 = X_train.reshape((X_train.shape[0], n_input))
# flatten output
n_output = y_train.shape[1] * y_train.shape[2]
y_train1 = y_train.reshape((y_train.shape[0], n_output))

# %%
# flatten input
n_input1 = X_test.shape[1] * X_test.shape[2]
X_test1 = X_test.reshape((X_test.shape[0], n_input1))
# flatten output
n_output1 = y_test.shape[1] * y_test.shape[2]
y_test1 = y_test.reshape((y_test.shape[0], n_output1))

# %% [markdown]
# **Build the MLP-Model**
#
# **Deutsch:**
#
# **Aufbau des MLP-Modells**

# %%
# set the denominator of mape function permanently as 1 to ensure mathematical operation error free 
set_epsilon(1)

# define model
model_2=Sequential()

# Custom fuction of root mean square error
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# Initializing the Neural Network based on multilayered-perceptron 
# Adding 1st dense layer
model_2.add(Dense(units=50, input_dim=n_input, activation='tanh')) #input_shape=(X_train1.shape[1], X_train1.shape[2])
model_2.add(Dropout(0.25))

# Adding a hidden dense layer
#model_2.add(Dense(units=50, activation='tanh'))

# Adding Dropout
#model_2.add(Dropout(0.25))

#model_2.add(Dense(30))

# Output layer
model_2.add(Dense(n_output))

# Compiling the Neural Network
model_2.compile(optimizer=Adam(learning_rate=0.0002), loss=rmse, metrics='mean_absolute_percentage_error')

# %%
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                1400
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 459
# =================================================================
# Total params: 1,859
# Trainable params: 1,859
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Start training with max 2000 epochs**
#
# **Deutsch:**
#
# **Training mit max. 2000 Epochen**

# %%
epochs = 2000
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=60, restore_best_weights=True)
history_2 = model_2.fit(X_train1, y_train1, validation_data=(X_test1, y_test1), batch_size=2, 
                    epochs=epochs, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/2000
# 7/7 [==============================] - 1s 69ms/step - loss: 0.3788 - mean_absolute_percentage_error: 32.6795 - val_loss: 0.7804 - val_mean_absolute_percentage_error: 70.6324
# Epoch 2/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3594 - mean_absolute_percentage_error: 30.5958 - val_loss: 0.7183 - val_mean_absolute_percentage_error: 64.5325
# Epoch 3/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3418 - mean_absolute_percentage_error: 29.6674 - val_loss: 0.6599 - val_mean_absolute_percentage_error: 58.5073
# Epoch 4/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3134 - mean_absolute_percentage_error: 27.4140 - val_loss: 0.6035 - val_mean_absolute_percentage_error: 52.4645
# Epoch 5/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2962 - mean_absolute_percentage_error: 25.4592 - val_loss: 0.5510 - val_mean_absolute_percentage_error: 46.8831
# Epoch 6/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2736 - mean_absolute_percentage_error: 22.5201 - val_loss: 0.5012 - val_mean_absolute_percentage_error: 42.4224
# Epoch 7/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2650 - mean_absolute_percentage_error: 22.0407 - val_loss: 0.4561 - val_mean_absolute_percentage_error: 38.4995
# Epoch 8/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2331 - mean_absolute_percentage_error: 20.1029 - val_loss: 0.4130 - val_mean_absolute_percentage_error: 34.8177
# Epoch 9/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2054 - mean_absolute_percentage_error: 17.6978 - val_loss: 0.3738 - val_mean_absolute_percentage_error: 31.1472
# Epoch 10/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2055 - mean_absolute_percentage_error: 17.7413 - val_loss: 0.3388 - val_mean_absolute_percentage_error: 28.5596
# Epoch 11/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2156 - mean_absolute_percentage_error: 17.1095 - val_loss: 0.3099 - val_mean_absolute_percentage_error: 27.0900
# Epoch 12/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2208 - mean_absolute_percentage_error: 18.0041 - val_loss: 0.2859 - val_mean_absolute_percentage_error: 25.6978
# Epoch 13/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1972 - mean_absolute_percentage_error: 16.4287 - val_loss: 0.2649 - val_mean_absolute_percentage_error: 23.7341
# Epoch 14/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1799 - mean_absolute_percentage_error: 14.2095 - val_loss: 0.2507 - val_mean_absolute_percentage_error: 21.8168
# Epoch 15/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1706 - mean_absolute_percentage_error: 14.1707 - val_loss: 0.2426 - val_mean_absolute_percentage_error: 20.0775
# Epoch 16/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1667 - mean_absolute_percentage_error: 13.9278 - val_loss: 0.2374 - val_mean_absolute_percentage_error: 18.7792
# Epoch 17/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1518 - mean_absolute_percentage_error: 12.3045 - val_loss: 0.2367 - val_mean_absolute_percentage_error: 18.0023
# Epoch 18/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1489 - mean_absolute_percentage_error: 12.4902 - val_loss: 0.2372 - val_mean_absolute_percentage_error: 17.5124
# Epoch 19/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1588 - mean_absolute_percentage_error: 12.7475 - val_loss: 0.2387 - val_mean_absolute_percentage_error: 17.8256
# Epoch 20/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1628 - mean_absolute_percentage_error: 13.3018 - val_loss: 0.2392 - val_mean_absolute_percentage_error: 18.4158
# Epoch 21/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1620 - mean_absolute_percentage_error: 13.2403 - val_loss: 0.2439 - val_mean_absolute_percentage_error: 19.2121
# Epoch 22/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1614 - mean_absolute_percentage_error: 13.3523 - val_loss: 0.2412 - val_mean_absolute_percentage_error: 18.6351
# Epoch 23/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1593 - mean_absolute_percentage_error: 13.0649 - val_loss: 0.2340 - val_mean_absolute_percentage_error: 17.3916
# Epoch 24/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1648 - mean_absolute_percentage_error: 13.2299 - val_loss: 0.2287 - val_mean_absolute_percentage_error: 17.1501
# Epoch 25/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1612 - mean_absolute_percentage_error: 12.9464 - val_loss: 0.2241 - val_mean_absolute_percentage_error: 17.2958
# Epoch 26/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1512 - mean_absolute_percentage_error: 12.3284 - val_loss: 0.2145 - val_mean_absolute_percentage_error: 16.7975
# Epoch 27/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1483 - mean_absolute_percentage_error: 12.4018 - val_loss: 0.2048 - val_mean_absolute_percentage_error: 16.0671
# Epoch 28/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1614 - mean_absolute_percentage_error: 13.5206 - val_loss: 0.2037 - val_mean_absolute_percentage_error: 16.0131
# Epoch 29/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1580 - mean_absolute_percentage_error: 13.4976 - val_loss: 0.2121 - val_mean_absolute_percentage_error: 16.7635
# Epoch 30/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_percentage_error: 12.5379 - val_loss: 0.2224 - val_mean_absolute_percentage_error: 17.4435
# Epoch 31/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1427 - mean_absolute_percentage_error: 12.3439 - val_loss: 0.2297 - val_mean_absolute_percentage_error: 18.0715
# Epoch 32/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1507 - mean_absolute_percentage_error: 12.4550 - val_loss: 0.2289 - val_mean_absolute_percentage_error: 17.8914
# Epoch 33/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1487 - mean_absolute_percentage_error: 12.1345 - val_loss: 0.2267 - val_mean_absolute_percentage_error: 17.4614
# Epoch 34/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1524 - mean_absolute_percentage_error: 12.5577 - val_loss: 0.2187 - val_mean_absolute_percentage_error: 16.9920
# Epoch 35/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1381 - mean_absolute_percentage_error: 10.8712 - val_loss: 0.2140 - val_mean_absolute_percentage_error: 16.7218
# Epoch 36/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1422 - mean_absolute_percentage_error: 11.4620 - val_loss: 0.2116 - val_mean_absolute_percentage_error: 16.3609
# Epoch 37/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1301 - mean_absolute_percentage_error: 10.4607 - val_loss: 0.2056 - val_mean_absolute_percentage_error: 16.0889
# Epoch 38/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1341 - mean_absolute_percentage_error: 11.1491 - val_loss: 0.2036 - val_mean_absolute_percentage_error: 15.8277
# Epoch 39/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1292 - mean_absolute_percentage_error: 10.6886 - val_loss: 0.1988 - val_mean_absolute_percentage_error: 15.3922
# Epoch 40/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1456 - mean_absolute_percentage_error: 12.0804 - val_loss: 0.2001 - val_mean_absolute_percentage_error: 15.3489
# Epoch 41/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1424 - mean_absolute_percentage_error: 11.4986 - val_loss: 0.2066 - val_mean_absolute_percentage_error: 16.0281
# Epoch 42/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1204 - mean_absolute_percentage_error: 9.6405 - val_loss: 0.2103 - val_mean_absolute_percentage_error: 16.4006
# Epoch 43/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1352 - mean_absolute_percentage_error: 11.2975 - val_loss: 0.2051 - val_mean_absolute_percentage_error: 16.0112
# Epoch 44/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1218 - mean_absolute_percentage_error: 9.9061 - val_loss: 0.1906 - val_mean_absolute_percentage_error: 14.6636
# Epoch 45/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1354 - mean_absolute_percentage_error: 11.0971 - val_loss: 0.1790 - val_mean_absolute_percentage_error: 13.4584
# Epoch 46/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1245 - mean_absolute_percentage_error: 10.2627 - val_loss: 0.1752 - val_mean_absolute_percentage_error: 12.9210
# Epoch 47/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1074 - mean_absolute_percentage_error: 8.9701 - val_loss: 0.1750 - val_mean_absolute_percentage_error: 12.9061
# Epoch 48/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1224 - mean_absolute_percentage_error: 10.0835 - val_loss: 0.1770 - val_mean_absolute_percentage_error: 13.0993
# Epoch 49/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1133 - mean_absolute_percentage_error: 9.6844 - val_loss: 0.1780 - val_mean_absolute_percentage_error: 13.0460
# Epoch 50/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1314 - mean_absolute_percentage_error: 11.2361 - val_loss: 0.1808 - val_mean_absolute_percentage_error: 13.2197
# Epoch 51/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1269 - mean_absolute_percentage_error: 10.8138 - val_loss: 0.1848 - val_mean_absolute_percentage_error: 13.6591
# Epoch 52/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1208 - mean_absolute_percentage_error: 9.9635 - val_loss: 0.1895 - val_mean_absolute_percentage_error: 14.3003
# Epoch 53/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1132 - mean_absolute_percentage_error: 9.3737 - val_loss: 0.1907 - val_mean_absolute_percentage_error: 14.5749
# Epoch 54/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1220 - mean_absolute_percentage_error: 9.8562 - val_loss: 0.1887 - val_mean_absolute_percentage_error: 14.3058
# Epoch 55/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1179 - mean_absolute_percentage_error: 10.0614 - val_loss: 0.1878 - val_mean_absolute_percentage_error: 14.0173
# Epoch 56/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1133 - mean_absolute_percentage_error: 9.2196 - val_loss: 0.1838 - val_mean_absolute_percentage_error: 13.6352
# Epoch 57/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1205 - mean_absolute_percentage_error: 9.9436 - val_loss: 0.1740 - val_mean_absolute_percentage_error: 13.2102
# Epoch 58/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1224 - mean_absolute_percentage_error: 9.8038 - val_loss: 0.1741 - val_mean_absolute_percentage_error: 13.3214
# Epoch 59/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1123 - mean_absolute_percentage_error: 9.3666 - val_loss: 0.1741 - val_mean_absolute_percentage_error: 13.5331
# Epoch 60/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1144 - mean_absolute_percentage_error: 9.4101 - val_loss: 0.1697 - val_mean_absolute_percentage_error: 13.4336
# Epoch 61/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1158 - mean_absolute_percentage_error: 9.4819 - val_loss: 0.1675 - val_mean_absolute_percentage_error: 13.3973
# Epoch 62/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1177 - mean_absolute_percentage_error: 9.7151 - val_loss: 0.1689 - val_mean_absolute_percentage_error: 13.7868
# Epoch 63/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1081 - mean_absolute_percentage_error: 8.8543 - val_loss: 0.1723 - val_mean_absolute_percentage_error: 14.3867
# Epoch 64/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1174 - mean_absolute_percentage_error: 9.4695 - val_loss: 0.1735 - val_mean_absolute_percentage_error: 14.8345
# Epoch 65/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1052 - mean_absolute_percentage_error: 8.8215 - val_loss: 0.1716 - val_mean_absolute_percentage_error: 14.6253
# Epoch 66/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1105 - mean_absolute_percentage_error: 9.2417 - val_loss: 0.1633 - val_mean_absolute_percentage_error: 13.7513
# Epoch 67/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1185 - mean_absolute_percentage_error: 9.4716 - val_loss: 0.1535 - val_mean_absolute_percentage_error: 12.5767
# Epoch 68/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1148 - mean_absolute_percentage_error: 9.7554 - val_loss: 0.1472 - val_mean_absolute_percentage_error: 11.5933
# Epoch 69/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1174 - mean_absolute_percentage_error: 9.2432 - val_loss: 0.1438 - val_mean_absolute_percentage_error: 11.0067
# Epoch 70/2000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1127 - mean_absolute_percentage_error: 9.4695 - val_loss: 0.1414 - val_mean_absolute_percentage_error: 10.9262
# Epoch 71/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1139 - mean_absolute_percentage_error: 9.1869 - val_loss: 0.1400 - val_mean_absolute_percentage_error: 10.5860
# Epoch 72/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0947 - mean_absolute_percentage_error: 8.2508 - val_loss: 0.1364 - val_mean_absolute_percentage_error: 10.6658
# Epoch 73/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1096 - mean_absolute_percentage_error: 8.8693 - val_loss: 0.1336 - val_mean_absolute_percentage_error: 10.9151
# Epoch 74/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1168 - mean_absolute_percentage_error: 9.5449 - val_loss: 0.1299 - val_mean_absolute_percentage_error: 10.7624
# Epoch 75/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1043 - mean_absolute_percentage_error: 8.7814 - val_loss: 0.1346 - val_mean_absolute_percentage_error: 11.0826
# Epoch 76/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1069 - mean_absolute_percentage_error: 8.9994 - val_loss: 0.1412 - val_mean_absolute_percentage_error: 11.5226
# Epoch 77/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0889 - mean_absolute_percentage_error: 7.3209 - val_loss: 0.1439 - val_mean_absolute_percentage_error: 11.5322
# Epoch 78/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1167 - mean_absolute_percentage_error: 9.5789 - val_loss: 0.1430 - val_mean_absolute_percentage_error: 11.1797
# Epoch 79/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1137 - mean_absolute_percentage_error: 9.2998 - val_loss: 0.1407 - val_mean_absolute_percentage_error: 10.7686
# Epoch 80/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1152 - mean_absolute_percentage_error: 9.3010 - val_loss: 0.1356 - val_mean_absolute_percentage_error: 10.6728
# Epoch 81/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1203 - mean_absolute_percentage_error: 10.1148 - val_loss: 0.1352 - val_mean_absolute_percentage_error: 11.1174
# Epoch 82/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0906 - mean_absolute_percentage_error: 7.4639 - val_loss: 0.1352 - val_mean_absolute_percentage_error: 11.3234
# Epoch 83/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0938 - mean_absolute_percentage_error: 7.7987 - val_loss: 0.1296 - val_mean_absolute_percentage_error: 10.8386
# Epoch 84/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1030 - mean_absolute_percentage_error: 8.4887 - val_loss: 0.1262 - val_mean_absolute_percentage_error: 10.4780
# Epoch 85/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0958 - mean_absolute_percentage_error: 7.9072 - val_loss: 0.1292 - val_mean_absolute_percentage_error: 10.8272
# Epoch 86/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0958 - mean_absolute_percentage_error: 7.7595 - val_loss: 0.1379 - val_mean_absolute_percentage_error: 11.0564
# Epoch 87/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0959 - mean_absolute_percentage_error: 7.8592 - val_loss: 0.1445 - val_mean_absolute_percentage_error: 10.7136
# Epoch 88/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1032 - mean_absolute_percentage_error: 8.6055 - val_loss: 0.1500 - val_mean_absolute_percentage_error: 10.5449
# Epoch 89/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0861 - mean_absolute_percentage_error: 7.0737 - val_loss: 0.1546 - val_mean_absolute_percentage_error: 10.9206
# Epoch 90/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0856 - mean_absolute_percentage_error: 6.9461 - val_loss: 0.1482 - val_mean_absolute_percentage_error: 10.9435
# Epoch 91/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1059 - mean_absolute_percentage_error: 8.7796 - val_loss: 0.1414 - val_mean_absolute_percentage_error: 10.7843
# Epoch 92/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0950 - mean_absolute_percentage_error: 7.9196 - val_loss: 0.1429 - val_mean_absolute_percentage_error: 10.9652
# Epoch 93/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0858 - mean_absolute_percentage_error: 7.0285 - val_loss: 0.1375 - val_mean_absolute_percentage_error: 10.5831
# Epoch 94/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0929 - mean_absolute_percentage_error: 7.5416 - val_loss: 0.1329 - val_mean_absolute_percentage_error: 10.3677
# Epoch 95/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1027 - mean_absolute_percentage_error: 8.2850 - val_loss: 0.1253 - val_mean_absolute_percentage_error: 9.9882
# Epoch 96/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0846 - mean_absolute_percentage_error: 7.0849 - val_loss: 0.1179 - val_mean_absolute_percentage_error: 9.4662
# Epoch 97/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1005 - mean_absolute_percentage_error: 8.5381 - val_loss: 0.1131 - val_mean_absolute_percentage_error: 9.0136
# Epoch 98/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0841 - mean_absolute_percentage_error: 6.6929 - val_loss: 0.1143 - val_mean_absolute_percentage_error: 8.8939
# Epoch 99/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1053 - mean_absolute_percentage_error: 8.6090 - val_loss: 0.1176 - val_mean_absolute_percentage_error: 9.4033
# Epoch 100/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0860 - mean_absolute_percentage_error: 7.2014 - val_loss: 0.1271 - val_mean_absolute_percentage_error: 10.0852
# Epoch 101/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0962 - mean_absolute_percentage_error: 7.7457 - val_loss: 0.1354 - val_mean_absolute_percentage_error: 10.7886
# Epoch 102/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0912 - mean_absolute_percentage_error: 7.2851 - val_loss: 0.1437 - val_mean_absolute_percentage_error: 11.5132
# Epoch 103/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0988 - mean_absolute_percentage_error: 8.0965 - val_loss: 0.1492 - val_mean_absolute_percentage_error: 11.9953
# Epoch 104/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0858 - mean_absolute_percentage_error: 7.3582 - val_loss: 0.1473 - val_mean_absolute_percentage_error: 11.8928
# Epoch 105/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0913 - mean_absolute_percentage_error: 7.4875 - val_loss: 0.1419 - val_mean_absolute_percentage_error: 11.3275
# Epoch 106/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0928 - mean_absolute_percentage_error: 7.4190 - val_loss: 0.1346 - val_mean_absolute_percentage_error: 10.4123
# Epoch 107/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0791 - mean_absolute_percentage_error: 6.5035 - val_loss: 0.1285 - val_mean_absolute_percentage_error: 9.8795
# Epoch 108/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0850 - mean_absolute_percentage_error: 7.1708 - val_loss: 0.1244 - val_mean_absolute_percentage_error: 10.2266
# Epoch 109/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0929 - mean_absolute_percentage_error: 7.8668 - val_loss: 0.1274 - val_mean_absolute_percentage_error: 10.7737
# Epoch 110/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0850 - mean_absolute_percentage_error: 6.9583 - val_loss: 0.1308 - val_mean_absolute_percentage_error: 10.9593
# Epoch 111/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0910 - mean_absolute_percentage_error: 7.6279 - val_loss: 0.1341 - val_mean_absolute_percentage_error: 10.8268
# Epoch 112/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0953 - mean_absolute_percentage_error: 7.9150 - val_loss: 0.1396 - val_mean_absolute_percentage_error: 11.1960
# Epoch 113/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0922 - mean_absolute_percentage_error: 7.4815 - val_loss: 0.1476 - val_mean_absolute_percentage_error: 11.5302
# Epoch 114/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0753 - mean_absolute_percentage_error: 6.0807 - val_loss: 0.1460 - val_mean_absolute_percentage_error: 11.3488
# Epoch 115/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0808 - mean_absolute_percentage_error: 6.5654 - val_loss: 0.1459 - val_mean_absolute_percentage_error: 11.5410
# Epoch 116/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0835 - mean_absolute_percentage_error: 6.7838 - val_loss: 0.1430 - val_mean_absolute_percentage_error: 11.2976
# Epoch 117/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0906 - mean_absolute_percentage_error: 7.5029 - val_loss: 0.1386 - val_mean_absolute_percentage_error: 11.0071
# Epoch 118/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0864 - mean_absolute_percentage_error: 6.7276 - val_loss: 0.1363 - val_mean_absolute_percentage_error: 10.8902
# Epoch 119/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0838 - mean_absolute_percentage_error: 6.7351 - val_loss: 0.1345 - val_mean_absolute_percentage_error: 10.8615
# Epoch 120/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0927 - mean_absolute_percentage_error: 7.6636 - val_loss: 0.1290 - val_mean_absolute_percentage_error: 10.2851
# Epoch 121/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0946 - mean_absolute_percentage_error: 7.7347 - val_loss: 0.1210 - val_mean_absolute_percentage_error: 9.7042
# Epoch 122/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0826 - mean_absolute_percentage_error: 6.6634 - val_loss: 0.1175 - val_mean_absolute_percentage_error: 9.6535
# Epoch 123/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0723 - mean_absolute_percentage_error: 5.9895 - val_loss: 0.1201 - val_mean_absolute_percentage_error: 9.9918
# Epoch 124/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0891 - mean_absolute_percentage_error: 7.5694 - val_loss: 0.1231 - val_mean_absolute_percentage_error: 10.2769
# Epoch 125/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0906 - mean_absolute_percentage_error: 7.6192 - val_loss: 0.1300 - val_mean_absolute_percentage_error: 10.8187
# Epoch 126/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0791 - mean_absolute_percentage_error: 6.5332 - val_loss: 0.1315 - val_mean_absolute_percentage_error: 11.0045
# Epoch 127/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0810 - mean_absolute_percentage_error: 6.9140 - val_loss: 0.1313 - val_mean_absolute_percentage_error: 11.0565
# Epoch 128/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0914 - mean_absolute_percentage_error: 7.5769 - val_loss: 0.1255 - val_mean_absolute_percentage_error: 10.4997
# Epoch 129/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0907 - mean_absolute_percentage_error: 7.5916 - val_loss: 0.1191 - val_mean_absolute_percentage_error: 9.7794
# Epoch 130/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0808 - mean_absolute_percentage_error: 6.7374 - val_loss: 0.1218 - val_mean_absolute_percentage_error: 9.7329
# Epoch 131/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0899 - mean_absolute_percentage_error: 7.4684 - val_loss: 0.1249 - val_mean_absolute_percentage_error: 9.9715
# Epoch 132/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0790 - mean_absolute_percentage_error: 6.4921 - val_loss: 0.1262 - val_mean_absolute_percentage_error: 9.9341
# Epoch 133/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0920 - mean_absolute_percentage_error: 7.6089 - val_loss: 0.1257 - val_mean_absolute_percentage_error: 9.7910
# Epoch 134/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0819 - mean_absolute_percentage_error: 6.6002 - val_loss: 0.1184 - val_mean_absolute_percentage_error: 9.1929
# Epoch 135/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0841 - mean_absolute_percentage_error: 7.1089 - val_loss: 0.1156 - val_mean_absolute_percentage_error: 8.9567
# Epoch 136/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0874 - mean_absolute_percentage_error: 7.0634 - val_loss: 0.1144 - val_mean_absolute_percentage_error: 8.6524
# Epoch 137/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0780 - mean_absolute_percentage_error: 6.5250 - val_loss: 0.1150 - val_mean_absolute_percentage_error: 8.6285
# Epoch 138/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0815 - mean_absolute_percentage_error: 6.6336 - val_loss: 0.1142 - val_mean_absolute_percentage_error: 8.8218
# Epoch 139/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0748 - mean_absolute_percentage_error: 6.2991 - val_loss: 0.1089 - val_mean_absolute_percentage_error: 8.2737
# Epoch 140/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0778 - mean_absolute_percentage_error: 6.4835 - val_loss: 0.1052 - val_mean_absolute_percentage_error: 7.9854
# Epoch 141/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0821 - mean_absolute_percentage_error: 6.6950 - val_loss: 0.1033 - val_mean_absolute_percentage_error: 8.0842
# Epoch 142/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0844 - mean_absolute_percentage_error: 7.1243 - val_loss: 0.1062 - val_mean_absolute_percentage_error: 8.3159
# Epoch 143/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0771 - mean_absolute_percentage_error: 6.5279 - val_loss: 0.1097 - val_mean_absolute_percentage_error: 8.5059
# Epoch 144/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0782 - mean_absolute_percentage_error: 6.4892 - val_loss: 0.1118 - val_mean_absolute_percentage_error: 8.9039
# Epoch 145/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0899 - mean_absolute_percentage_error: 7.6329 - val_loss: 0.1113 - val_mean_absolute_percentage_error: 8.9691
# Epoch 146/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0742 - mean_absolute_percentage_error: 5.9793 - val_loss: 0.1130 - val_mean_absolute_percentage_error: 9.1024
# Epoch 147/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0848 - mean_absolute_percentage_error: 6.6835 - val_loss: 0.1122 - val_mean_absolute_percentage_error: 8.8128
# Epoch 148/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0899 - mean_absolute_percentage_error: 7.2607 - val_loss: 0.1104 - val_mean_absolute_percentage_error: 8.6579
# Epoch 149/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0841 - mean_absolute_percentage_error: 7.0133 - val_loss: 0.1089 - val_mean_absolute_percentage_error: 8.4907
# Epoch 150/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0739 - mean_absolute_percentage_error: 6.1322 - val_loss: 0.1088 - val_mean_absolute_percentage_error: 8.5868
# Epoch 151/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0809 - mean_absolute_percentage_error: 6.7732 - val_loss: 0.1074 - val_mean_absolute_percentage_error: 8.6498
# Epoch 152/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0804 - mean_absolute_percentage_error: 6.6417 - val_loss: 0.1071 - val_mean_absolute_percentage_error: 8.5726
# Epoch 153/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0828 - mean_absolute_percentage_error: 6.9647 - val_loss: 0.1106 - val_mean_absolute_percentage_error: 8.8024
# Epoch 154/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0738 - mean_absolute_percentage_error: 6.1227 - val_loss: 0.1100 - val_mean_absolute_percentage_error: 8.8207
# Epoch 155/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0811 - mean_absolute_percentage_error: 6.7348 - val_loss: 0.1080 - val_mean_absolute_percentage_error: 8.7603
# Epoch 156/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0895 - mean_absolute_percentage_error: 7.5184 - val_loss: 0.1117 - val_mean_absolute_percentage_error: 8.9902
# Epoch 157/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0928 - mean_absolute_percentage_error: 7.9465 - val_loss: 0.1191 - val_mean_absolute_percentage_error: 9.7569
# Epoch 158/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0684 - mean_absolute_percentage_error: 5.6739 - val_loss: 0.1230 - val_mean_absolute_percentage_error: 10.2054
# Epoch 159/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0809 - mean_absolute_percentage_error: 6.7379 - val_loss: 0.1289 - val_mean_absolute_percentage_error: 10.4888
# Epoch 160/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0785 - mean_absolute_percentage_error: 6.4973 - val_loss: 0.1238 - val_mean_absolute_percentage_error: 10.0096
# Epoch 161/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0824 - mean_absolute_percentage_error: 7.0941 - val_loss: 0.1096 - val_mean_absolute_percentage_error: 8.9126
# Epoch 162/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0748 - mean_absolute_percentage_error: 6.2908 - val_loss: 0.0997 - val_mean_absolute_percentage_error: 8.3658
# Epoch 163/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0751 - mean_absolute_percentage_error: 6.1347 - val_loss: 0.0982 - val_mean_absolute_percentage_error: 8.1401
# Epoch 164/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0704 - mean_absolute_percentage_error: 5.7958 - val_loss: 0.0904 - val_mean_absolute_percentage_error: 7.3666
# Epoch 165/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0865 - mean_absolute_percentage_error: 7.1042 - val_loss: 0.0930 - val_mean_absolute_percentage_error: 7.4891
# Epoch 166/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0763 - mean_absolute_percentage_error: 6.2938 - val_loss: 0.0997 - val_mean_absolute_percentage_error: 7.7630
# Epoch 167/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0833 - mean_absolute_percentage_error: 6.8932 - val_loss: 0.0985 - val_mean_absolute_percentage_error: 7.7159
# Epoch 168/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0818 - mean_absolute_percentage_error: 6.6771 - val_loss: 0.0984 - val_mean_absolute_percentage_error: 8.0547
# Epoch 169/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0748 - mean_absolute_percentage_error: 6.3722 - val_loss: 0.1035 - val_mean_absolute_percentage_error: 8.7623
# Epoch 170/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0810 - mean_absolute_percentage_error: 6.7558 - val_loss: 0.1046 - val_mean_absolute_percentage_error: 9.0667
# Epoch 171/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0739 - mean_absolute_percentage_error: 6.1375 - val_loss: 0.1086 - val_mean_absolute_percentage_error: 9.1402
# Epoch 172/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0885 - mean_absolute_percentage_error: 7.3103 - val_loss: 0.1168 - val_mean_absolute_percentage_error: 9.6204
# Epoch 173/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0794 - mean_absolute_percentage_error: 6.6324 - val_loss: 0.1188 - val_mean_absolute_percentage_error: 9.6171
# Epoch 174/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0674 - mean_absolute_percentage_error: 5.5654 - val_loss: 0.1182 - val_mean_absolute_percentage_error: 9.3180
# Epoch 175/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0827 - mean_absolute_percentage_error: 6.9623 - val_loss: 0.1142 - val_mean_absolute_percentage_error: 8.8643
# Epoch 176/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0757 - mean_absolute_percentage_error: 6.2828 - val_loss: 0.1090 - val_mean_absolute_percentage_error: 8.7112
# Epoch 177/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0698 - mean_absolute_percentage_error: 5.8763 - val_loss: 0.1075 - val_mean_absolute_percentage_error: 8.7769
# Epoch 178/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0720 - mean_absolute_percentage_error: 5.8883 - val_loss: 0.1000 - val_mean_absolute_percentage_error: 8.3040
# Epoch 179/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0654 - mean_absolute_percentage_error: 5.5328 - val_loss: 0.0900 - val_mean_absolute_percentage_error: 7.5261
# Epoch 180/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0744 - mean_absolute_percentage_error: 6.1148 - val_loss: 0.0823 - val_mean_absolute_percentage_error: 6.7905
# Epoch 181/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0875 - mean_absolute_percentage_error: 7.3566 - val_loss: 0.0808 - val_mean_absolute_percentage_error: 6.8656
# Epoch 182/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0625 - mean_absolute_percentage_error: 5.2447 - val_loss: 0.0849 - val_mean_absolute_percentage_error: 7.2284
# Epoch 183/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0824 - mean_absolute_percentage_error: 6.8339 - val_loss: 0.0900 - val_mean_absolute_percentage_error: 7.6214
# Epoch 184/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0810 - mean_absolute_percentage_error: 6.9849 - val_loss: 0.0914 - val_mean_absolute_percentage_error: 7.8748
# Epoch 185/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0719 - mean_absolute_percentage_error: 6.0187 - val_loss: 0.0864 - val_mean_absolute_percentage_error: 7.4302
# Epoch 186/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0640 - mean_absolute_percentage_error: 5.3629 - val_loss: 0.0810 - val_mean_absolute_percentage_error: 6.8707
# Epoch 187/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0745 - mean_absolute_percentage_error: 6.1899 - val_loss: 0.0743 - val_mean_absolute_percentage_error: 6.3197
# Epoch 188/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0824 - mean_absolute_percentage_error: 6.9046 - val_loss: 0.0694 - val_mean_absolute_percentage_error: 5.6848
# Epoch 189/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0683 - mean_absolute_percentage_error: 5.6888 - val_loss: 0.0683 - val_mean_absolute_percentage_error: 5.5516
# Epoch 190/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0647 - mean_absolute_percentage_error: 5.2343 - val_loss: 0.0654 - val_mean_absolute_percentage_error: 5.3340
# Epoch 191/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0777 - mean_absolute_percentage_error: 6.2756 - val_loss: 0.0672 - val_mean_absolute_percentage_error: 5.2170
# Epoch 192/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0796 - mean_absolute_percentage_error: 6.7737 - val_loss: 0.0748 - val_mean_absolute_percentage_error: 5.7554
# Epoch 193/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0820 - mean_absolute_percentage_error: 6.8093 - val_loss: 0.0822 - val_mean_absolute_percentage_error: 6.5182
# Epoch 194/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0794 - mean_absolute_percentage_error: 6.5447 - val_loss: 0.0927 - val_mean_absolute_percentage_error: 7.3309
# Epoch 195/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0663 - mean_absolute_percentage_error: 5.4520 - val_loss: 0.0977 - val_mean_absolute_percentage_error: 7.6975
# Epoch 196/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0745 - mean_absolute_percentage_error: 6.4127 - val_loss: 0.0932 - val_mean_absolute_percentage_error: 7.3106
# Epoch 197/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0764 - mean_absolute_percentage_error: 6.6062 - val_loss: 0.0830 - val_mean_absolute_percentage_error: 6.3964
# Epoch 198/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0721 - mean_absolute_percentage_error: 6.0295 - val_loss: 0.0745 - val_mean_absolute_percentage_error: 5.9279
# Epoch 199/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0767 - mean_absolute_percentage_error: 6.3861 - val_loss: 0.0734 - val_mean_absolute_percentage_error: 6.1075
# Epoch 200/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0620 - mean_absolute_percentage_error: 5.1634 - val_loss: 0.0742 - val_mean_absolute_percentage_error: 6.2248
# Epoch 201/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0779 - mean_absolute_percentage_error: 6.4953 - val_loss: 0.0685 - val_mean_absolute_percentage_error: 5.8048
# Epoch 202/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0697 - mean_absolute_percentage_error: 5.6879 - val_loss: 0.0691 - val_mean_absolute_percentage_error: 5.9601
# Epoch 203/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0779 - mean_absolute_percentage_error: 6.6648 - val_loss: 0.0784 - val_mean_absolute_percentage_error: 6.4783
# Epoch 204/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0728 - mean_absolute_percentage_error: 6.0424 - val_loss: 0.0833 - val_mean_absolute_percentage_error: 6.8871
# Epoch 205/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0654 - mean_absolute_percentage_error: 5.5172 - val_loss: 0.0884 - val_mean_absolute_percentage_error: 7.3493
# Epoch 206/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0783 - mean_absolute_percentage_error: 6.6249 - val_loss: 0.0838 - val_mean_absolute_percentage_error: 7.0441
# Epoch 207/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0801 - mean_absolute_percentage_error: 6.5572 - val_loss: 0.0783 - val_mean_absolute_percentage_error: 6.6754
# Epoch 208/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0726 - mean_absolute_percentage_error: 6.0479 - val_loss: 0.0826 - val_mean_absolute_percentage_error: 7.0466
# Epoch 209/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0755 - mean_absolute_percentage_error: 6.3285 - val_loss: 0.0839 - val_mean_absolute_percentage_error: 7.1530
# Epoch 210/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0687 - mean_absolute_percentage_error: 5.8227 - val_loss: 0.0808 - val_mean_absolute_percentage_error: 6.8088
# Epoch 211/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0685 - mean_absolute_percentage_error: 5.5384 - val_loss: 0.0777 - val_mean_absolute_percentage_error: 6.4932
# Epoch 212/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0728 - mean_absolute_percentage_error: 6.0886 - val_loss: 0.0777 - val_mean_absolute_percentage_error: 6.3797
# Epoch 213/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0688 - mean_absolute_percentage_error: 5.8398 - val_loss: 0.0759 - val_mean_absolute_percentage_error: 6.1315
# Epoch 214/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0707 - mean_absolute_percentage_error: 6.0190 - val_loss: 0.0706 - val_mean_absolute_percentage_error: 5.9899
# Epoch 215/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0660 - mean_absolute_percentage_error: 5.5687 - val_loss: 0.0681 - val_mean_absolute_percentage_error: 5.9903
# Epoch 216/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0663 - mean_absolute_percentage_error: 5.6596 - val_loss: 0.0695 - val_mean_absolute_percentage_error: 6.1405
# Epoch 217/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0750 - mean_absolute_percentage_error: 6.1386 - val_loss: 0.0753 - val_mean_absolute_percentage_error: 6.5418
# Epoch 218/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0773 - mean_absolute_percentage_error: 6.5082 - val_loss: 0.0752 - val_mean_absolute_percentage_error: 6.3588
# Epoch 219/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0726 - mean_absolute_percentage_error: 5.9881 - val_loss: 0.0668 - val_mean_absolute_percentage_error: 5.5870
# Epoch 220/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0728 - mean_absolute_percentage_error: 6.3094 - val_loss: 0.0697 - val_mean_absolute_percentage_error: 5.4079
# Epoch 221/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0777 - mean_absolute_percentage_error: 6.4981 - val_loss: 0.0716 - val_mean_absolute_percentage_error: 5.5079
# Epoch 222/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0706 - mean_absolute_percentage_error: 5.8149 - val_loss: 0.0711 - val_mean_absolute_percentage_error: 5.7503
# Epoch 223/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0744 - mean_absolute_percentage_error: 6.2268 - val_loss: 0.0749 - val_mean_absolute_percentage_error: 6.3626
# Epoch 224/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0755 - mean_absolute_percentage_error: 6.5038 - val_loss: 0.0724 - val_mean_absolute_percentage_error: 6.2178
# Epoch 225/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0629 - mean_absolute_percentage_error: 5.1346 - val_loss: 0.0751 - val_mean_absolute_percentage_error: 6.3993
# Epoch 226/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0731 - mean_absolute_percentage_error: 5.8773 - val_loss: 0.0762 - val_mean_absolute_percentage_error: 6.4142
# Epoch 227/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0724 - mean_absolute_percentage_error: 6.1546 - val_loss: 0.0755 - val_mean_absolute_percentage_error: 6.0961
# Epoch 228/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0655 - mean_absolute_percentage_error: 5.3052 - val_loss: 0.0779 - val_mean_absolute_percentage_error: 6.2029
# Epoch 229/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0653 - mean_absolute_percentage_error: 5.3692 - val_loss: 0.0753 - val_mean_absolute_percentage_error: 6.3064
# Epoch 230/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0637 - mean_absolute_percentage_error: 5.1431 - val_loss: 0.0738 - val_mean_absolute_percentage_error: 6.3886
# Epoch 231/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0720 - mean_absolute_percentage_error: 5.8747 - val_loss: 0.0723 - val_mean_absolute_percentage_error: 6.3536
# Epoch 232/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0688 - mean_absolute_percentage_error: 5.5562 - val_loss: 0.0717 - val_mean_absolute_percentage_error: 6.3659
# Epoch 233/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0686 - mean_absolute_percentage_error: 5.7468 - val_loss: 0.0676 - val_mean_absolute_percentage_error: 5.9882
# Epoch 234/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0657 - mean_absolute_percentage_error: 5.4386 - val_loss: 0.0622 - val_mean_absolute_percentage_error: 5.5089
# Epoch 235/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0737 - mean_absolute_percentage_error: 6.1233 - val_loss: 0.0635 - val_mean_absolute_percentage_error: 5.7389
# Epoch 236/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0805 - mean_absolute_percentage_error: 6.5090 - val_loss: 0.0671 - val_mean_absolute_percentage_error: 5.8479
# Epoch 237/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0743 - mean_absolute_percentage_error: 6.1140 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 6.0782
# Epoch 238/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0728 - mean_absolute_percentage_error: 6.1535 - val_loss: 0.0768 - val_mean_absolute_percentage_error: 6.2876
# Epoch 239/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0619 - mean_absolute_percentage_error: 5.2319 - val_loss: 0.0737 - val_mean_absolute_percentage_error: 6.2261
# Epoch 240/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0555 - mean_absolute_percentage_error: 4.6179 - val_loss: 0.0723 - val_mean_absolute_percentage_error: 6.1825
# Epoch 241/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0717 - mean_absolute_percentage_error: 6.0964 - val_loss: 0.0745 - val_mean_absolute_percentage_error: 6.3267
# Epoch 242/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0825 - mean_absolute_percentage_error: 7.1628 - val_loss: 0.0760 - val_mean_absolute_percentage_error: 6.1971
# Epoch 243/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0734 - mean_absolute_percentage_error: 6.1312 - val_loss: 0.0773 - val_mean_absolute_percentage_error: 6.2702
# Epoch 244/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0633 - mean_absolute_percentage_error: 5.1922 - val_loss: 0.0806 - val_mean_absolute_percentage_error: 6.6003
# Epoch 245/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0700 - mean_absolute_percentage_error: 5.7532 - val_loss: 0.0840 - val_mean_absolute_percentage_error: 6.9525
# Epoch 246/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0658 - mean_absolute_percentage_error: 5.3826 - val_loss: 0.0788 - val_mean_absolute_percentage_error: 6.7602
# Epoch 247/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0687 - mean_absolute_percentage_error: 5.7830 - val_loss: 0.0703 - val_mean_absolute_percentage_error: 6.0720
# Epoch 248/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0699 - mean_absolute_percentage_error: 5.9070 - val_loss: 0.0659 - val_mean_absolute_percentage_error: 5.5826
# Epoch 249/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0699 - mean_absolute_percentage_error: 5.7094 - val_loss: 0.0666 - val_mean_absolute_percentage_error: 5.5911
# Epoch 250/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0669 - mean_absolute_percentage_error: 5.6674 - val_loss: 0.0599 - val_mean_absolute_percentage_error: 5.1503
# Epoch 251/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0634 - mean_absolute_percentage_error: 5.2199 - val_loss: 0.0567 - val_mean_absolute_percentage_error: 4.7808
# Epoch 252/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0651 - mean_absolute_percentage_error: 5.4136 - val_loss: 0.0580 - val_mean_absolute_percentage_error: 4.6914
# Epoch 253/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0667 - mean_absolute_percentage_error: 5.5339 - val_loss: 0.0628 - val_mean_absolute_percentage_error: 4.9446
# Epoch 254/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0632 - mean_absolute_percentage_error: 5.2579 - val_loss: 0.0561 - val_mean_absolute_percentage_error: 4.8217
# Epoch 255/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0622 - mean_absolute_percentage_error: 5.0094 - val_loss: 0.0507 - val_mean_absolute_percentage_error: 4.5190
# Epoch 256/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0614 - mean_absolute_percentage_error: 5.0195 - val_loss: 0.0551 - val_mean_absolute_percentage_error: 4.8295
# Epoch 257/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0597 - mean_absolute_percentage_error: 4.9180 - val_loss: 0.0679 - val_mean_absolute_percentage_error: 5.8460
# Epoch 258/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0665 - mean_absolute_percentage_error: 5.6211 - val_loss: 0.0792 - val_mean_absolute_percentage_error: 6.8168
# Epoch 259/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0594 - mean_absolute_percentage_error: 5.0288 - val_loss: 0.0804 - val_mean_absolute_percentage_error: 6.9079
# Epoch 260/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0704 - mean_absolute_percentage_error: 5.8618 - val_loss: 0.0684 - val_mean_absolute_percentage_error: 5.9420
# Epoch 261/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0575 - mean_absolute_percentage_error: 4.7464 - val_loss: 0.0646 - val_mean_absolute_percentage_error: 5.5765
# Epoch 262/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0635 - mean_absolute_percentage_error: 5.1525 - val_loss: 0.0697 - val_mean_absolute_percentage_error: 6.0452
# Epoch 263/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0689 - mean_absolute_percentage_error: 5.6278 - val_loss: 0.0777 - val_mean_absolute_percentage_error: 6.8110
# Epoch 264/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0575 - mean_absolute_percentage_error: 4.7794 - val_loss: 0.0840 - val_mean_absolute_percentage_error: 7.2304
# Epoch 265/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0717 - mean_absolute_percentage_error: 6.0136 - val_loss: 0.0789 - val_mean_absolute_percentage_error: 6.7620
# Epoch 266/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0546 - mean_absolute_percentage_error: 4.4735 - val_loss: 0.0787 - val_mean_absolute_percentage_error: 6.6304
# Epoch 267/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0648 - mean_absolute_percentage_error: 5.3368 - val_loss: 0.0693 - val_mean_absolute_percentage_error: 5.9339
# Epoch 268/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0747 - mean_absolute_percentage_error: 6.3434 - val_loss: 0.0605 - val_mean_absolute_percentage_error: 5.2827
# Epoch 269/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0752 - mean_absolute_percentage_error: 6.3119 - val_loss: 0.0570 - val_mean_absolute_percentage_error: 4.9562
# Epoch 270/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0692 - mean_absolute_percentage_error: 5.9142 - val_loss: 0.0574 - val_mean_absolute_percentage_error: 4.9454
# Epoch 271/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0648 - mean_absolute_percentage_error: 5.4219 - val_loss: 0.0631 - val_mean_absolute_percentage_error: 5.3601
# Epoch 272/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0713 - mean_absolute_percentage_error: 6.1133 - val_loss: 0.0588 - val_mean_absolute_percentage_error: 5.2195
# Epoch 273/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0633 - mean_absolute_percentage_error: 5.2444 - val_loss: 0.0620 - val_mean_absolute_percentage_error: 5.5388
# Epoch 274/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0644 - mean_absolute_percentage_error: 5.3484 - val_loss: 0.0652 - val_mean_absolute_percentage_error: 5.6765
# Epoch 275/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0598 - mean_absolute_percentage_error: 4.7107 - val_loss: 0.0749 - val_mean_absolute_percentage_error: 6.4432
# Epoch 276/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0644 - mean_absolute_percentage_error: 5.3140 - val_loss: 0.0795 - val_mean_absolute_percentage_error: 6.7130
# Epoch 277/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0584 - mean_absolute_percentage_error: 4.9338 - val_loss: 0.0787 - val_mean_absolute_percentage_error: 6.6394
# Epoch 278/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0594 - mean_absolute_percentage_error: 5.0672 - val_loss: 0.0647 - val_mean_absolute_percentage_error: 5.4878
# Epoch 279/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0538 - mean_absolute_percentage_error: 4.4720 - val_loss: 0.0530 - val_mean_absolute_percentage_error: 4.7317
# Epoch 280/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0810 - mean_absolute_percentage_error: 6.9010 - val_loss: 0.0550 - val_mean_absolute_percentage_error: 4.7817
# Epoch 281/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0605 - mean_absolute_percentage_error: 5.0038 - val_loss: 0.0545 - val_mean_absolute_percentage_error: 4.7928
# Epoch 282/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0618 - mean_absolute_percentage_error: 5.1570 - val_loss: 0.0538 - val_mean_absolute_percentage_error: 4.7809
# Epoch 283/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0667 - mean_absolute_percentage_error: 5.6373 - val_loss: 0.0541 - val_mean_absolute_percentage_error: 4.8670
# Epoch 284/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0604 - mean_absolute_percentage_error: 5.1744 - val_loss: 0.0534 - val_mean_absolute_percentage_error: 4.8011
# Epoch 285/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0605 - mean_absolute_percentage_error: 4.8814 - val_loss: 0.0608 - val_mean_absolute_percentage_error: 5.1710
# Epoch 286/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0673 - mean_absolute_percentage_error: 5.4826 - val_loss: 0.0739 - val_mean_absolute_percentage_error: 6.0323
# Epoch 287/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0639 - mean_absolute_percentage_error: 5.3204 - val_loss: 0.0790 - val_mean_absolute_percentage_error: 6.2512
# Epoch 288/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0699 - mean_absolute_percentage_error: 5.7270 - val_loss: 0.0870 - val_mean_absolute_percentage_error: 6.9344
# Epoch 289/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0677 - mean_absolute_percentage_error: 5.6770 - val_loss: 0.0820 - val_mean_absolute_percentage_error: 6.6061
# Epoch 290/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0676 - mean_absolute_percentage_error: 5.7722 - val_loss: 0.0676 - val_mean_absolute_percentage_error: 5.4128
# Epoch 291/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0688 - mean_absolute_percentage_error: 5.6806 - val_loss: 0.0622 - val_mean_absolute_percentage_error: 5.0821
# Epoch 292/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0692 - mean_absolute_percentage_error: 5.7472 - val_loss: 0.0554 - val_mean_absolute_percentage_error: 4.8273
# Epoch 293/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0570 - mean_absolute_percentage_error: 4.7344 - val_loss: 0.0658 - val_mean_absolute_percentage_error: 5.6259
# Epoch 294/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0589 - mean_absolute_percentage_error: 4.5944 - val_loss: 0.0738 - val_mean_absolute_percentage_error: 6.2429
# Epoch 295/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0613 - mean_absolute_percentage_error: 5.1825 - val_loss: 0.0650 - val_mean_absolute_percentage_error: 5.6214
# Epoch 296/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0623 - mean_absolute_percentage_error: 5.2724 - val_loss: 0.0606 - val_mean_absolute_percentage_error: 5.2863
# Epoch 297/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0661 - mean_absolute_percentage_error: 5.5015 - val_loss: 0.0588 - val_mean_absolute_percentage_error: 5.2644
# Epoch 298/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0722 - mean_absolute_percentage_error: 5.8541 - val_loss: 0.0605 - val_mean_absolute_percentage_error: 5.3674
# Epoch 299/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0682 - mean_absolute_percentage_error: 5.7838 - val_loss: 0.0712 - val_mean_absolute_percentage_error: 5.9728
# Epoch 300/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0609 - mean_absolute_percentage_error: 5.0340 - val_loss: 0.0680 - val_mean_absolute_percentage_error: 5.9186
# Epoch 301/2000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0671 - mean_absolute_percentage_error: 5.8197 - val_loss: 0.0652 - val_mean_absolute_percentage_error: 5.7765
# Epoch 302/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0620 - mean_absolute_percentage_error: 5.0143 - val_loss: 0.0704 - val_mean_absolute_percentage_error: 6.0962
# Epoch 303/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0642 - mean_absolute_percentage_error: 5.2856 - val_loss: 0.0681 - val_mean_absolute_percentage_error: 6.0690
# Epoch 304/2000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0651 - mean_absolute_percentage_error: 5.3930 - val_loss: 0.0645 - val_mean_absolute_percentage_error: 5.7387
# Epoch 305/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0621 - mean_absolute_percentage_error: 5.0299 - val_loss: 0.0639 - val_mean_absolute_percentage_error: 5.6787
# Epoch 306/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0532 - mean_absolute_percentage_error: 4.2461 - val_loss: 0.0718 - val_mean_absolute_percentage_error: 6.2548
# Epoch 307/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0532 - mean_absolute_percentage_error: 4.2385 - val_loss: 0.0763 - val_mean_absolute_percentage_error: 6.4704
# Epoch 308/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0540 - mean_absolute_percentage_error: 4.3179 - val_loss: 0.0672 - val_mean_absolute_percentage_error: 5.7380
# Epoch 309/2000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0648 - mean_absolute_percentage_error: 5.4823 - val_loss: 0.0588 - val_mean_absolute_percentage_error: 5.0454
# Epoch 310/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0526 - mean_absolute_percentage_error: 4.4011 - val_loss: 0.0587 - val_mean_absolute_percentage_error: 5.0382
# Epoch 311/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0704 - mean_absolute_percentage_error: 5.8539 - val_loss: 0.0631 - val_mean_absolute_percentage_error: 5.4750
# Epoch 312/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0653 - mean_absolute_percentage_error: 5.4075 - val_loss: 0.0694 - val_mean_absolute_percentage_error: 5.6902
# Epoch 313/2000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0617 - mean_absolute_percentage_error: 5.0705 - val_loss: 0.0640 - val_mean_absolute_percentage_error: 5.1881
# Epoch 314/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0609 - mean_absolute_percentage_error: 5.0817 - val_loss: 0.0564 - val_mean_absolute_percentage_error: 4.5602
# Epoch 315/2000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0613 - mean_absolute_percentage_error: 5.0352 - val_loss: 0.0603 - val_mean_absolute_percentage_error: 4.6461
# Restoring model weights from the end of the best epoch.
# Epoch 00315: early stopping

# %% [markdown]
# **Performance plot of the model: RMSE and MAPE**
#
# **Deutsch:**
#
# **Erstellung des Diagramms der Modellleistung: RMSE und MAPE**

# %%
 # Plot training & validation loss values (RMSE)
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history_2.history["loss"])
plt.plot(history_2.history["val_loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %%
# Plot tht training and validation's MAPE
fig, ax = plt.subplots(figsize=(5, 5), sharex=True)
plt.plot(history_2.history["mean_absolute_percentage_error"])
plt.plot(history_2.history["val_mean_absolute_percentage_error"])
plt.title("Model Accuracy with MAPE")
plt.ylabel("Loss (%)")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# **Predict the train dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Trainingdatensatzes für die Verlustberechnung**

# %%
predictions_train = model_2.predict(X_train1)
predictions_train
# Out:
# array([[0.18493083, 0.2410998 , 0.15414333, 0.03848641, 0.05663413,
#         0.05270702, 0.16892055, 0.17785004, 0.02766224],
#        [0.255433  , 0.33394963, 0.19521648, 0.05052922, 0.08416662,
#         0.11031521, 0.22653955, 0.2545669 , 0.06722083],
#        [0.3450502 , 0.42946982, 0.26195675, 0.06815873, 0.12030306,
#         0.18110576, 0.31939444, 0.325689  , 0.11567569],
#        [0.36621532, 0.5484416 , 0.31954458, 0.1237065 , 0.15123242,
#         0.23223825, 0.35601676, 0.37691   , 0.17076819],
#        [0.4212835 , 0.6561812 , 0.31882542, 0.16328456, 0.17741294,
#         0.26212177, 0.44136083, 0.38934404, 0.20780466],
#        [0.4659001 , 0.7093754 , 0.37014613, 0.1768648 , 0.21187809,
#         0.27981246, 0.4965534 , 0.42351028, 0.24508868],
#        [0.4991599 , 0.7466645 , 0.41660157, 0.23776433, 0.24310382,
#         0.32434112, 0.5343675 , 0.43665606, 0.29853478],
#        [0.5611245 , 0.7844207 , 0.4432998 , 0.30585042, 0.31311014,
#         0.38072997, 0.5852421 , 0.44386044, 0.34135756],
#        [0.6352987 , 0.8029283 , 0.5195661 , 0.3052122 , 0.3734481 ,
#         0.42290345, 0.703132  , 0.56644845, 0.4101714 ],
#        [0.6701122 , 0.8667773 , 0.60762626, 0.3759286 , 0.4620355 ,
#         0.5221641 , 0.7463753 , 0.6580594 , 0.4793021 ],
#        [0.7275732 , 0.93177557, 0.6576419 , 0.4644861 , 0.48916033,
#         0.5819691 , 0.80906916, 0.69876   , 0.5474506 ],
#        [0.7919995 , 0.93791294, 0.69423145, 0.53111863, 0.56951106,
#         0.6565954 , 0.82690704, 0.7045456 , 0.58164084],
#        [0.8335132 , 0.9623946 , 0.7740807 , 0.61668277, 0.6229143 ,
#         0.7122471 , 0.88338685, 0.7779721 , 0.65345454]], dtype=float32)

# %%
prediction_unscaled_train = scaler_prediction.inverse_transform(predictions_train)

predicted_train_df = pd.DataFrame(prediction_unscaled_train, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_train_df['year'] = [x for x in range(2003, 2016)]
predicted_train_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1468.929932  ...  2003
# 1                     1636.742920  ...  2004
# 2                     1850.054443  ...  2005
# 3                     1900.432739  ...  2006
# 4                     2031.508911  ...  2007
# 5                     2137.707520  ...  2008
# 6                     2216.874268  ...  2009
# 7                     2364.365723  ...  2010
# 8                     2540.918945  ...  2011
# 9                     2623.783936  ...  2012
# 10                    2760.555664  ...  2013
# 11                    2913.906494  ...  2014
# 12                    3012.719482  ...  2015
#
# [13 rows x 10 columns]

# %% [markdown]
# **Predict the test dataset for loss calculation**
#
# **Deutsch:**
#
# **Vorhersage des Testdatensatzes für die Verlustberechnung**

# %%
# predict the test data which is from 2016 to 2019
x_input = X_test.reshape((-1, n_input))
predictions = model_2.predict(x_input)
predictions
# Out:
# array([[0.8994278 , 0.95969915, 0.83139664, 0.70208406, 0.69618505,
#         0.8010123 , 0.9323511 , 0.8109775 , 0.6948873 ],
#        [0.9812112 , 0.9396148 , 0.92080367, 0.786713  , 0.8041628 ,
#         0.8441176 , 0.9875407 , 0.8455607 , 0.77776784],
#        [1.0209612 , 0.9181169 , 0.97818303, 0.8478632 , 0.9190415 ,
#         0.9250985 , 1.0670688 , 0.93176436, 0.8369913 ],
#        [1.057543  , 0.92551935, 1.0545886 , 0.9453964 , 1.009683  ,
#         1.0219185 , 1.1143286 , 1.0337973 , 0.9127619 ]], dtype=float32)

# %%
# convert back the predicted value to original format
prediction_unscaled_test = scaler_prediction.inverse_transform(predictions)

# arrange the valus in a dataframe
predicted_test_df = pd.DataFrame(prediction_unscaled_test, columns = ['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
predicted_test_df['year'] = [x for x in range(2016, 2020)]
predicted_test_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3169.612793            1925.805664  ...      71913.632812  2016
# 1                    3364.277832            1900.369751  ...      79294.851562  2017
# 2                    3458.892822            1873.143677  ...      84569.203125  2018
# 3                    3545.966797            1882.518555  ...      91317.210938  2019
#
# [4 rows x 10 columns]

# %% [markdown]
# **Calculate loss for testing data**
#
# **Deutsch:**
#
# **Verlustberechnung für Testdaten**

# %%
# create  the functions of mean absolute percentage error (MAPE) and root mean squared error (RMSE)
def mean_absolute_percentage_error(y_true, y_prediction): 
    y_true, y_prediction = np.array(y_true), np.array(y_prediction)
    return np.mean(np.abs((y_true - y_prediction) / y_true)) * 100

def root_mean_squared_error(y_true, y_prediction):
    mse = mean_squared_error(y_true, y_prediction)
    rmse = np.sqrt(mse)
    return rmse

# %%
# create a function of generating all the relevant errors
def calculate_performance(y_true, y_prediction):
    MSE = mean_squared_error(y_true, y_prediction)
    MAE = mean_absolute_error(y_true, y_prediction)
    MAPE = mean_absolute_percentage_error(y_true, y_prediction)
    RMSE = root_mean_squared_error(y_true, y_prediction)
    return round(MSE, 3), round(MAE, 3), round(MAPE, 3), round(RMSE, 3)

# %%
# rearrange the shape of test data's input for  inputing in the model
x_input2 = X_test.reshape((-1, n_input))
actual_arr=input_df.iloc[16:20,:].to_numpy()

# Get the predicted values
predictions = model_2.predict(x_input2)
prediction_unscaled2 = scaler_prediction.inverse_transform(predictions)

MSE, MAE, MAPE, RMSE = calculate_performance(actual_arr, prediction_unscaled2)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 3816981.789
# Mean Absolute Error (MAE): 647.059
# Mean Absolute Percentage Error (MAPE): 3.33 %
# Root Mean Squared Error (RMSE): 1953.71

# %% [markdown]
# **Calculate loss of total energy consumption for prediction against actual values** (total energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Gesamtenergieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tec=predicted_test_df.iloc[:,0].to_numpy()
actual_tec=input_df.iloc[16:20,0].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tec, predicted_tec)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 19820.169
# Mean Absolute Error (MAE): 136.261
# Mean Absolute Percentage Error (MAPE): 4.18 %
# Root Mean Squared  Error (RMSE): 140.784

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tec)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tec)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtenergieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of coal consumption for prediction against actual values** (Coal consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Kohleverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_cc=predicted_test_df.iloc[:,1].to_numpy()
actual_cc=input_df.iloc[16:20,1].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_cc, predicted_cc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 2007.096
# Mean Absolute Error (MAE): 36.219
# Mean Absolute Percentage Error (MAPE): 1.88 %
# Root Mean Squared  Error (RMSE): 44.801

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_cc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_cc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Kohleverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of oil consumption for prediction against actual values** (Oil consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdölverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_oc=predicted_test_df.iloc[:,2].to_numpy()
actual_oc=input_df.iloc[16:20,2].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_oc, predicted_oc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 358.904
# Mean Absolute Error (MAE): 17.779
# Mean Absolute Percentage Error (MAPE): 2.72 %
# Root Mean Squared  Error (RMSE): 18.945

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_oc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_oc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdölverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of natural gas consumption for prediction against actual values** (Natural gas consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des Erdgasverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gc=predicted_test_df.iloc[:,3].to_numpy()
actual_gc=input_df.iloc[16:20,3].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gc, predicted_gc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 150.185
# Mean Absolute Error (MAE): 11.65
# Mean Absolute Percentage Error (MAPE): 5.14 %
# Root Mean Squared  Error (RMSE): 12.255

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Erdgasverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of non fossil energy consumption for prediction against actual values** (non fossil energy consumption)
#
# **Deutsch:**
#
# **Verlustberechnung des nichtfossilen Energieverbrauchs für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_nfc=predicted_test_df.iloc[:,4].to_numpy()
actual_nfc=input_df.iloc[16:20,4].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_nfc, predicted_nfc)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 50.143
# Mean Absolute Error (MAE): 6.233
# Mean Absolute Percentage Error (MAPE): 1.47 %
# Root Mean Squared  Error (RMSE): 7.081

# %% [markdown]
# **Plot the curve of predicted values against actual values**
#
# **Deutsch:**
#
# **Aufzeichnung der Kurve der vorhergesagten Werte im Vergleich zu den tatsächlichen Werten**

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_nfc)
ax1.plot(predicted_test_df.iloc[:,-1], actual_nfc)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("nichtfossile Energieverbrauch (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of energy imports for prediction against actual values** (energy imports)
#
# **Deutsch:**
#
# **Verlustberechnung der Energieeinfuhr für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_imp=predicted_test_df.iloc[:,5].to_numpy()
actual_imp=input_df.iloc[16:20,5].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_imp, predicted_imp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 963.384
# Mean Absolute Error (MAE): 26.305
# Mean Absolute Percentage Error (MAPE): 3.56 %
# Root Mean Squared  Error (RMSE): 31.038

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_imp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_imp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Energieeinfuhr (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of tpes for prediction against actual values** (total primary energy supply)
#
# **Deutsch:**
#
# **Verlustberechnung der Gesamtprimärenergieversorgung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_tpes=predicted_test_df.iloc[:,6].to_numpy()
actual_tpes=input_df.iloc[16:20,6].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_tpes, predicted_tpes)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 23393.615
# Mean Absolute Error (MAE): 141.6
# Mean Absolute Percentage Error (MAPE): 4.52 %
# Root Mean Squared  Error (RMSE): 152.95

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_tpes)
ax1.plot(predicted_test_df.iloc[:,-1], actual_tpes)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Gesamtprimärenergieversorgung (Mtoe)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of population for prediction against actual values** (population)
#
# **Deutsch:**
#
# **Verlustberechnung der Bevölkerung für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_pop=predicted_test_df.iloc[:,7].to_numpy()
actual_pop=input_df.iloc[16:20,7].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_pop, predicted_pop)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 52.372
# Mean Absolute Error (MAE): 6.775
# Mean Absolute Percentage Error (MAPE): 0.49 %
# Root Mean Squared  Error (RMSE): 7.237

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_pop)
ax1.plot(predicted_test_df.iloc[:,-1], actual_pop)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bevölkerung (Millionen)", fontsize=18)

plt.show()

# %% [markdown]
# **Calculate loss of GDP for prediction against actual values** (GDP)
#
# **Deutsch:**
#
# **Verlustberechnung des Bruttoinlandsprodukts für die Vorhersage gegenüber den tatsächlichen Werten**

# %%
predicted_gdp=predicted_test_df.iloc[:,8].to_numpy()
actual_gdp=input_df.iloc[16:20,8].to_numpy()

MSE, MAE, MAPE, RMSE = calculate_performance(actual_gdp, predicted_gdp)
print('Mean Squared Error (MSE): ' + str(MSE))
print('Mean Absolute Error (MAE): ' + str(MAE))
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE,2)) + ' %')
print('Root Mean Squared  Error (RMSE): ' + str(RMSE))
# Out:
# Mean Squared Error (MSE): 34306040.233
# Mean Absolute Error (MAE): 5440.705
# Mean Absolute Percentage Error (MAPE): 6.05 %
# Root Mean Squared  Error (RMSE): 5857.136

# %%
# Visualize the data
fig, ax1 = plt.subplots(figsize=(22, 10)) #, sharex=True)
plt.title("Vorhersage vs Istwerte", fontsize=20)
ax1.plot(predicted_test_df.iloc[:,-1], predicted_gdp)
ax1.plot(predicted_test_df.iloc[:,-1], actual_gdp)
plt.legend(["Vorhersage von Testdaten", "Istwerte"], loc="upper left")
plt.xlabel("Jahr", fontsize=18)
plt.ylabel("Bruttoinlandsprodukt (Milliarden Yuan)", fontsize=18)

plt.show()

# %% [markdown]
# **Make future predictions**
#
# Predict the value of the next six years
#
# **Deutsch:**
#
# **Zukunftsprognosen erstellen**
#
# Vorhersage des Wertes für die nächsten sechs Jahre

# %%
# extract last three rows from dataset
temp_input=final_df[-3:].tolist()

# %%
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999]]

# %%
predicted_consumption_output =[]
for i in range(6):
  # Get the last 3 year consumption values and scale the data to be values between 0 and 1
  last_5_years = np.array(temp_input[-3:])
  last_5_years_scaled = last_5_years.reshape(-1, n_input)
  # Create an empty list and Append past 5 years
  X_test_new = []
  X_test_new.append(last_5_years_scaled)
  # Convert the X_test data set to a numpy array and reshape the data
  prediction_consumption_scaled = model_2.predict(X_test_new)
  temp_input.extend(prediction_consumption_scaled.tolist())
  predicted_consumption_output.extend(prediction_consumption_scaled.tolist())

# %%
# add new predicted values into temp_input list
temp_input
# Out:
# [[0.9083244127092426,
#   0.9391524313449705,
#   0.8778505764506643,
#   0.7635711140367123,
#   0.8002841442059427,
#   0.889555674298163,
#   0.9363576976119619,
#   0.9248228019906488,
#   0.8216574498784509],
#  [0.955666458845534,
#   0.9495876120285202,
#   0.9325820877707891,
#   0.9136338588993295,
#   0.8989394385343805,
#   1.0,
#   1.0,
#   0.9647866083546983,
#   0.9196213724686583],
#  [1.0,
#   0.9842836996763308,
#   1.0000000000000002,
#   0.9999999999999999,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.9999999999999999],
#  [1.077663779258728,
#   0.948577880859375,
#   1.1254997253417969,
#   1.0464314222335815,
#   1.065337896347046,
#   1.1077362298965454,
#   1.1334422826766968,
#   1.1395453214645386,
#   0.9527351260185242],
#  [1.1982476711273193,
#   1.054376482963562,
#   1.1506372690200806,
#   1.1926463842391968,
#   1.100935935974121,
#   1.1979925632476807,
#   1.1649067401885986,
#   1.165358304977417,
#   0.9988685250282288],
#  [1.2806249856948853,
#   1.1224415302276611,
#   1.2433571815490723,
#   1.2709170579910278,
#   1.166703462600708,
#   1.2363500595092773,
#   1.1913093328475952,
#   1.2963346242904663,
#   1.0466148853302002],
#  [1.3469997644424438,
#   1.2229949235916138,
#   1.2827630043029785,
#   1.399282693862915,
#   1.159976601600647,
#   1.3566491603851318,
#   1.2591243982315063,
#   1.3896949291229248,
#   1.0836901664733887],
#  [1.454504132270813,
#   1.3198812007904053,
#   1.3145999908447266,
#   1.502953290939331,
#   1.1949514150619507,
#   1.4126429557800293,
#   1.2903029918670654,
#   1.4183058738708496,
#   1.1297333240509033],
#  [1.5216171741485596,
#   1.4064301252365112,
#   1.3409112691879272,
#   1.5636000633239746,
#   1.1621524095535278,
#   1.468516230583191,
#   1.3194504976272583,
#   1.5140389204025269,
#   1.169431447982788]]

# %%
# rename temp_input with new inputs into prediction_arr
prediction_arr = np.array(temp_input)

# %%
prediction_arr
# Out:
# array([[0.90832441, 0.93915243, 0.87785058, 0.76357111, 0.80028414,
#         0.88955567, 0.9363577 , 0.9248228 , 0.82165745],
#        [0.95566646, 0.94958761, 0.93258209, 0.91363386, 0.89893944,
#         1.        , 1.        , 0.96478661, 0.91962137],
#        [1.        , 0.9842837 , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.        ],
#        [1.07766378, 0.94857788, 1.12549973, 1.04643142, 1.0653379 ,
#         1.10773623, 1.13344228, 1.13954532, 0.95273513],
#        [1.19824767, 1.05437648, 1.15063727, 1.19264638, 1.10093594,
#         1.19799256, 1.16490674, 1.1653583 , 0.99886853],
#        [1.28062499, 1.12244153, 1.24335718, 1.27091706, 1.16670346,
#         1.23635006, 1.19130933, 1.29633462, 1.04661489],
#        [1.34699976, 1.22299492, 1.282763  , 1.39928269, 1.1599766 ,
#         1.35664916, 1.2591244 , 1.38969493, 1.08369017],
#        [1.45450413, 1.3198812 , 1.31459999, 1.50295329, 1.19495142,
#         1.41264296, 1.29030299, 1.41830587, 1.12973332],
#        [1.52161717, 1.40643013, 1.34091127, 1.56360006, 1.16215241,
#         1.46851623, 1.3194505 , 1.51403892, 1.16943145]])

# %%
# transform the predicted value back to original form
prediction_unscaled = scaler_prediction.inverse_transform(prediction_arr)

# %%
predicted_consumption = prediction_unscaled.ravel()

# %%
predicted_consumption
# Out:
# array([  3190.789     ,   1899.7842638 ,    632.53951563,    209.41927228,
#           414.00076415,    700.273     ,   3064.9       ,   1390.08      ,
#         83203.59      ,   3303.475     ,   1912.9999275 ,    657.07314703,
#           245.92728745,    457.90272932,    775.509     ,   3196.42      ,
#          1395.38      ,  91928.11      ,   3409.        ,   1956.94088451,
#           687.29351129,    266.93887425,    502.87504711,    775.509     ,
#          3196.42      ,   1400.05      ,  99086.51      ,   3593.85936591,
#          1911.72115064,    743.5492939 ,    278.2349429 ,    531.95064887,
#           848.90021264,   3472.18514927,   1418.55650053,  94877.17122052,
#          3880.8794157 ,   2045.71008548,    754.81730416,    313.80685021,
#           547.79190611,    910.38391   ,   3537.20802394,   1421.97981841,
#         98985.74253623,   4076.95818345,   2131.91125451,    796.37939706,
#           332.84893122,    577.05869491,    936.51349674,   3591.7703018 ,
#          1439.34989787, 103237.96176518,   4234.94688331,   2259.25738011,
#           814.04322375,    364.07836518,    574.06521727,   1018.46268784,
#          3731.91352517,   1451.7313415 , 106539.83069087,   4490.83436985,
#          2381.95927621,    828.3142876 ,    389.29986659,    589.6291366 ,
#          1056.60633319,   3796.34564784,   1455.52572499, 110640.36523999,
#          4650.580322  ,   2491.56940307,    840.10842939,    404.05431672,
#           575.03345973,   1094.66787847,   3856.58042587,   1468.22184162,
#        114175.82061018])

# %%
# reshape into proper format
predicted_consumption= predicted_consumption.reshape(-1,9)

# %%
predicted_consumption.shape
# Out:
# (9, 9)

# %% [markdown]
# **Table of actual values from 2017 to 2019 & prediction values from 2020 to 2025**
#
# **Deutsch:**
#
# **Tabelle mit realen Werten zwischen 2017 und 2019 sowie Vorhersagewerten zwischen 2020 und 2025**

# %%
# add column names and convert into dataframe for preparation of visualisation
prediction_df=pd.DataFrame(predicted_consumption ,columns=['total_energy_consumption_mtoe','coal_consumption_mtoe','oil_consumption_mtoe','gas_consumption_mtoe','non_fossil_consumption_mtoe','imports_mtoe', 'tpes_mtoe', 'population_million', 'gdp_billion_yuan'])
prediction_df
# Out:
#    total_energy_consumption_mtoe  ...  gdp_billion_yuan
# 0                    3190.789000  ...      83203.590000
# 1                    3303.475000  ...      91928.110000
# 2                    3409.000000  ...      99086.510000
# 3                    3593.859366  ...      94877.171221
# 4                    3880.879416  ...      98985.742536
# 5                    4076.958183  ...     103237.961765
# 6                    4234.946883  ...     106539.830691
# 7                    4490.834370  ...     110640.365240
# 8                    4650.580322  ...     114175.820610
#
# [9 rows x 9 columns]

# %% [markdown]
# **Preparation of predicted values for visualisation**
#
# **Deutsch:**
#
# **Aufbereitung der Vorhersagewerte für die Visualisierung**

# %%
# Generate list of sequence of days for predictions
year_range = range(2017,2026)

yearlist_predict = []

for y in year_range:
  yearlist_predict.append(y)

# %%
# Generate list of sequence of days for predictions
year_range = range(2000,2020)

yearlist_main = []

for y in year_range:
  yearlist_main.append(y)

# %%
# preparation for combination it to original dataset copies
prediction_df['year']=yearlist_predict
prediction_df.head()
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 0                    3190.789000            1899.784264  ...      83203.590000  2017
# 1                    3303.475000            1912.999927  ...      91928.110000  2018
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3593.859366            1911.721151  ...      94877.171221  2020
# 4                    3880.879416            2045.710085  ...      98985.742536  2021
#
# [5 rows x 10 columns]

# %%
# make a copy from input_df and add a year column
energy_consumption_df = input_df.loc[:, :]
energy_consumption_df['year']=yearlist_main
energy_consumption_df.tail()
# Out:
#     total_energy_consumption_mtoe  ...  year
# 15                       3038.791  ...  2015
# 16                       3090.444  ...  2016
# 17                       3190.789  ...  2017
# 18                       3303.475  ...  2018
# 19                       3409.000  ...  2019
#
# [5 rows x 10 columns]

# %%
target_df=prediction_df.iloc[5:,:]
target_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 5                    4076.958183            2131.911255  ...     103237.961765  2022
# 6                    4234.946883            2259.257380  ...     106539.830691  2023
# 7                    4490.834370            2381.959276  ...     110640.365240  2024
# 8                    4650.580322            2491.569403  ...     114175.820610  2025
#
# [4 rows x 10 columns]

# %%
# this is the prediction dataframe between 2019 and 2025
visual_df=prediction_df.iloc[2:,:]
visual_df
# Out:
#    total_energy_consumption_mtoe  coal_consumption_mtoe  ...  gdp_billion_yuan  year
# 2                    3409.000000            1956.940885  ...      99086.510000  2019
# 3                    3593.859366            1911.721151  ...      94877.171221  2020
# 4                    3880.879416            2045.710085  ...      98985.742536  2021
# 5                    4076.958183            2131.911255  ...     103237.961765  2022
# 6                    4234.946883            2259.257380  ...     106539.830691  2023
# 7                    4490.834370            2381.959276  ...     110640.365240  2024
# 8                    4650.580322            2491.569403  ...     114175.820610  2025
#
# [7 rows x 10 columns]

# %% [markdown]
# **Combination of original dataset and prediction table**
#
# **Deutsch:**
#
# **Zusammensetzung des originalen Datensatz und der Vorhersagetabelle**

# %%
# append the predicted dataframe to the original dataset copies
combined_energy_consumption_df= pd.concat([energy_consumption_df, prediction_df.iloc[3:,:]], axis=0)
combined_energy_consumption_df.reset_index(drop=True, inplace=True)
combined_energy_consumption_df
# Out:
#     total_energy_consumption_mtoe  ...  year
# 0                     1028.748000  ...  2000
# 1                     1088.829000  ...  2001
# 2                     1187.039000  ...  2002
# 3                     1379.581000  ...  2003
# 4                     1611.967000  ...  2004
# 5                     1829.583000  ...  2005
# 6                     2005.269000  ...  2006
# 7                     2180.094000  ...  2007
# 8                     2244.277000  ...  2008
# 9                     2352.882000  ...  2009
# 10                    2524.536000  ...  2010
# 11                    2709.301000  ...  2011
# 12                    2814.966000  ...  2012
# 13                    2918.391000  ...  2013
# 14                    2998.338000  ...  2014
# 15                    3038.791000  ...  2015
# 16                    3090.444000  ...  2016
# 17                    3190.789000  ...  2017
# 18                    3303.475000  ...  2018
# 19                    3409.000000  ...  2019
# 20                    3593.859366  ...  2020
# 21                    3880.879416  ...  2021
# 22                    4076.958183  ...  2022
# 23                    4234.946883  ...  2023
# 24                    4490.834370  ...  2024
# 25                    4650.580322  ...  2025
#
# [26 rows x 10 columns]

# %% [markdown]
# **Visualise the prediction**
#
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Gesamtenergieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['total_energy_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Gesamtenergieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,0], color='g', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,0], color='y', marker='x', label='Vorhersage - Gesamtenergieverbrauch (Trainingdaten)')
#plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['Energy_consumption'], color='orange', label='Training predictions')
#plt.plot(input_df.iloc[:,-1], input_df.iloc[:, 0], color='b', label='Actual Energy Consumption')
plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,0], color='b', marker='x', label='Ist-Gesamtenergieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')
#plt.axvline(x = min(target_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Gesamtenergieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Kohleverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['coal_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Kohleverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,1], color='g', marker='x', label='Vorhersage - Kohleverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,1], color='y', marker='x', label='Vorhersage - Kohleverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,1], color='b', marker='x', label='Ist-Kohleverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Kohleverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Kohleverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdölverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['oil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdölverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,2], color='g', marker='x', label='Vorhersage - Erdölverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,2], color='y', marker='x', label='Vorhersage - Erdölverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,2], color='b', marker='x', label='Ist-Erdölverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdölverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdölverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Erdgasverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['gas_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger Erdgasverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,3], color='g', marker='x', label='Vorhersage - Erdgasverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,3], color='y', marker='x', label='Vorhersage - Erdgasverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,3], color='b', marker='x', label='Ist-Erdgasverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Erdgasverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Erdgasverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# **Deutsch:**
#
# **Visualisierung der Vorhersage** (Nichtfossiler Energieverbrauch)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

plt.plot(visual_df['year'], visual_df['non_fossil_consumption_mtoe'], color='r', marker='x', label='Vorhersage - künftiger nichtfossile Energieverbrauch')
plt.plot(predicted_test_df.iloc[:,-1], predicted_test_df.iloc[:,4], color='g', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Testdaten)')
plt.plot(predicted_train_df.iloc[:,-1], predicted_train_df.iloc[:,4], color='y', marker='x', label='Vorhersage - Nichtfossiler Energieverbrauch (Trainingdaten)')

plt.plot(combined_energy_consumption_df.iloc[:20,-1], combined_energy_consumption_df.iloc[:20,4], color='b', marker='x', label='Ist-Nichtfossiler Energieverbrauch')
plt.axvline(x = min(visual_df['year']), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Vorhersage und Ist-Nichtfossile Energieverbrauch Chinas', family='Arial', fontsize=12)
plt.xlabel('Year', family='Arial', fontsize=10)
plt.ylabel('Nichtfossiler Energieverbrauch (Mtoe)', family='DejaVu Sans', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
